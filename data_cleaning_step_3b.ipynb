# %% [markdown]
# **U1 (Target Use Case):**
# One could use this dataset to investigate whether different neighborhoods (indicated by zip code or geographic regions) have distinct food safety patterns, such as passing rate, complaint rate, risks, violations, and violation types, and further stratify the data by other factors (such as facility types and time range).

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# **Note:** later we will need to replace the path to read the intermediate data after OpenRefine.

# %%
input_data = pd.read_csv("raw_input/Food_Inspections.csv")
input_data.head()
# Out:
#    Inspection ID                 DBA Name                 AKA Name  License #  \
# 0        2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517328.0
# 1        2079129              JET'S PIZZA              JET'S PIZZA  2522268.0
# 2        2079125                ROOM 1520                ROOM 1520  2446638.0
# 3        2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517338.0
# 4        2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS  2549079.0
#
#     Facility Type             Risk               Address     City State  \
# 0      Restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL
# 1      Restaurant  Risk 2 (Medium)    1025 W MADISON ST   CHICAGO    IL
# 2   Special Event     Risk 3 (Low)     301 N JUSTINE ST   CHICAGO    IL
# 3      Restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL
# 4  CHARTER SCHOOL    Risk 1 (High)  2245 N MCVICKER AVE   CHICAGO    IL
#
#        Zip Inspection Date        Inspection Type    Results  \
# 0  60616.0         8/28/17                License       Pass
# 1  60607.0         8/28/17                License  Not Ready
# 2  60607.0         8/28/17  License Re-Inspection  Not Ready
# 3  60616.0         8/28/17                License       Pass
# 4  60639.0         8/28/17  License Re-Inspection       Pass
#
#                                           Violations   Latitude  Longitude  \
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711
#
#                                    Location
# 0  (41.853650885040594, -87.62053358114167)
# 1   (41.88157249576794, -87.65305233593274)
# 2   (41.88657652150854, -87.66532812140231)
# 3  (41.853650885040594, -87.62053358114167)
# 4   (41.921675488910864, -87.7767113569357)

# %%
input_data.dtypes
# Out:
# Inspection ID        int64
# DBA Name            object
# AKA Name            object
# License #          float64
# Facility Type       object
# Risk                object
# Address             object
# City                object
# State               object
# Zip                float64
# Inspection Date     object
# Inspection Type     object
# Results             object
# Violations          object
# Latitude           float64
# Longitude          float64
# Location            object
# dtype: object

# %%
input_data['Inspection ID'] = input_data['Inspection ID'].astype(str)
input_data['License #'] = input_data['License #'].astype(str)
input_data['License #'] = input_data['License #'].str.strip('.0')
input_data['Zip'] = input_data['Zip'].astype(str)
input_data['Zip'] = input_data['Zip'].str.strip('.0')
input_data['Inspection Date'] = pd.to_datetime(input_data['Inspection Date'])
input_data.dtypes
# Out:
# Inspection ID              object
# DBA Name                   object
# AKA Name                   object
# License #                  object
# Facility Type              object
# Risk                       object
# Address                    object
# City                       object
# State                      object
# Zip                        object
# Inspection Date    datetime64[ns]
# Inspection Type            object
# Results                    object
# Violations                 object
# Latitude                  float64
# Longitude                 float64
# Location                   object
# dtype: object

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Inspection ID    153810 non-null  object
#  1   DBA Name         153810 non-null  object
#  2   AKA Name         151267 non-null  object
#  3   License #        153810 non-null  object
#  4   Facility Type    149250 non-null  object
#  5   Risk             153744 non-null  object
#  6   Address          153810 non-null  object
#  7   City             153651 non-null  object
#  8   State            153802 non-null  object
#  9   Zip              153810 non-null  object
#  10  Inspection Date  153810 non-null  datetime64[ns]
#  11  Inspection Type  153809 non-null  object
#  12  Results          153810 non-null  object
#  13  Violations       123012 non-null  object
#  14  Latitude         153266 non-null  float64
#  15  Longitude        153266 non-null  float64
#  16  Location         153266 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(14)
# memory usage: 19.9+ MB

# %%
input_data.isnull().sum()
# Out:
# Inspection ID          0
# DBA Name               0
# AKA Name            2543
# License #              0
# Facility Type       4560
# Risk                  66
# Address                0
# City                 159
# State                  8
# Zip                    0
# Inspection Date        0
# Inspection Type        1
# Results                0
# Violations         30798
# Latitude             544
# Longitude            544
# Location             544
# dtype: int64

# %%
input_data.head()
# Out:
#   Inspection ID                 DBA Name                 AKA Name License #  \
# 0       2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO   2517328
# 1       2079129              JET'S PIZZA              JET'S PIZZA   2522268
# 2       2079125                ROOM 1520                ROOM 1520   2446638
# 3       2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO   2517338
# 4       2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS   2549079
#
#     Facility Type             Risk               Address     City State  \
# 0      Restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL
# 1      Restaurant  Risk 2 (Medium)    1025 W MADISON ST   CHICAGO    IL
# 2   Special Event     Risk 3 (Low)     301 N JUSTINE ST   CHICAGO    IL
# 3      Restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL
# 4  CHARTER SCHOOL    Risk 1 (High)  2245 N MCVICKER AVE   CHICAGO    IL
#
#      Zip Inspection Date        Inspection Type    Results  \
# 0  60616      2017-08-28                License       Pass
# 1  60607      2017-08-28                License  Not Ready
# 2  60607      2017-08-28  License Re-Inspection  Not Ready
# 3  60616      2017-08-28                License       Pass
# 4  60639      2017-08-28  License Re-Inspection       Pass
#
#                                           Violations   Latitude  Longitude  \
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711
#
#                                    Location
# 0  (41.853650885040594, -87.62053358114167)
# 1   (41.88157249576794, -87.65305233593274)
# 2   (41.88657652150854, -87.66532812140231)
# 3  (41.853650885040594, -87.62053358114167)
# 4   (41.921675488910864, -87.7767113569357)

# %%
len(set(input_data['Inspection ID'])) == len(list(input_data['Inspection ID']))
# Out:
# True

# %%
# double check that there are no duplicates
len(input_data.drop_duplicates()) == len(input_data)
# Out:
# True

# %%
list(input_data)
# Out:
# ['Inspection ID',
#  'DBA Name',
#  'AKA Name',
#  'License #',
#  'Facility Type',
#  'Risk',
#  'Address',
#  'City',
#  'State',
#  'Zip',
#  'Inspection Date',
#  'Inspection Type',
#  'Results',
#  'Violations',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
num_inspection = len(input_data)
print(f"How many inspection records are there in total? {num_inspection}")
num_license = len(set(input_data['License #']))
print(f"How many unique license numbers are there? {num_license}")
num_facility = len(input_data[['License #', 'AKA Name']].drop_duplicates())
print(f"How many unique food facilities are there? {num_facility}")
num_dates = len(set(input_data['Inspection Date']))
print(f"How many unique inspection dates are there? {num_dates}")
# Out:
# How many inspection records are there in total? 153810
# How many unique license numbers are there? 32752
# How many unique food facilities are there? 33886
# How many unique inspection dates are there? 1946

# %% [markdown]
# ## 1. data cleaning

# %%
input_data['Violations'].values[2]
# Out:
# '8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  CLEAN, PROPER TEMPERATURE, CONCENTRATION, EXPOSURE TIME - Comments: NO DISH WASHING FACILITIES ON SITE, (NO THREE COMPARTMENT SINK, WITH GREASE TRAP, OR DISHMACHINE), INSTRUCTED TO PROVIDE, | 11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIGNED, AND MAINTAINED - Comments:  NO EXPOSED HAND SINK FOR REAR SERVICE AREA, INSTRUCTED TO PROVIDE,\n | 18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME OF INSPECTION, INSTRUCTED TO PROVIDE, UPON NEXT VISIT,'

# %% [markdown]
# ### **Note:** The same license number and DBA Name can have multiple AKA Names, for example:

# %%
temp = input_data[['License #', 'DBA Name', 'AKA Name', 'Facility Type']].drop_duplicates().groupby(
    by=['License #', 'DBA Name'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False).reset_index(drop=True)
temp
# Out:
#       License #                             DBA Name  count
# 0         14616            ILLINOIS SPORTSERVICE INC     58
# 1       1354323           SPORTSERVICE SOLDIER FIELD     45
# 2       1974745                    THE UNITED CENTER     45
# 3       1574001    LEVY RESTAURANTS AT WRIGLEY FIELD     19
# 4         14616           ILLINOIS SPORTSERVICE INC.     17
# ...         ...                                  ...    ...
# 33640   1981546             ST.NICHOLAS OF TOLENTINE      1
# 33641   1981525              REACH CHRISTIAN ACADEMY      1
# 33642   1981517                  ST GENEVIEVE SCHOOL      1
# 33643   1981489          MONTCLARE SENIOR RESIDENCES      1
# 33644       nan  ST. DEMETRIOS GREEK ORTHODOX CHURCH      1
#
# [33645 rows x 3 columns]

# %%
len(temp[temp['count']>1])
# Out:
# 164

# %%
input_data[(input_data['License #']=='14616')][['License #', 'DBA Name', 'AKA Name', 'Facility Type']].drop_duplicates()
# Out:
#        License #                     DBA Name  \
# 2210       14616  ILLINOIS SPORTSERVICE, INC.
# 123258     14616   ILLINOIS SPORTSERVICE INC.
# 123266     14616   ILLINOIS SPORTSERVICE INC.
# 128247     14616  ILLINOIS SPORTSERVICE, INC.
# 128494     14616   ILLINOIS SPORTSERVICE INC.
# ...          ...                          ...
# 150012     14616    ILLINOIS SPORTSERVICE INC
# 150038     14616    ILLINOIS SPORTSERVICE INC
# 150043     14616    ILLINOIS SPORTSERVICE INC
# 150061     14616    ILLINOIS SPORTSERVICE INC
# 150070     14616    ILLINOIS SPORTSERVICE INC
#
#                                                  AKA Name Facility Type
# 2210                                GUARANTEED RATE FIELD       STADIUM
# 123258                                    MAIN COMMISSARY    COMMISSARY
# 123266    SHERM LOLLARS GUARD THE PLATE GRILLE STAND #524    Restaurant
# 128247                           TEX-MEX 3 - STEAK (#544)         KIOSK
# 128494                                BBQ BRISKET  (#531)         KIOSK
# ...                                                   ...           ...
# 150012                           DIPPING DOTS (SEC. #132)    Restaurant
# 150038                                    GO GO WHITE SOX    Restaurant
# 150043                                     NACHO 8 (#544)    Restaurant
# 150061                       HOT DOG VIENNA BEEF 7 (#557)    Restaurant
# 150070  SWEET SPOT (BIG ED WALSH'S ITALIAN BEEF AND PI...    Restaurant
#
# [86 rows x 4 columns]

# %% [markdown]
# ### Are there any redundant inspection entries on the same day for the same facility?

# %%
temp2 = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type']]
inspection_counts2 = temp2.groupby(by=['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False)
inspection_counts2.head(20)
# Out:
#       License #                                 DBA Name  \
# 12956   1354323               SPORTSERVICE SOLDIER FIELD
# 12952   1354323               SPORTSERVICE SOLDIER FIELD
# 60260   2013962                          KENDALL COLLEGE
# 12937   1354323               SPORTSERVICE SOLDIER FIELD
# 12916   1354323               SPORTSERVICE SOLDIER FIELD
# 12924   1354323               SPORTSERVICE SOLDIER FIELD
# 12913   1354323               SPORTSERVICE SOLDIER FIELD
# 8373    1246854                         SAVE-A-LOT  #855
# 12920   1354323               SPORTSERVICE SOLDIER FIELD
# 26790   1621492                                   SUBWAY
# 12955   1354323               SPORTSERVICE SOLDIER FIELD
# 12954   1354323               SPORTSERVICE SOLDIER FIELD
# 69706   2065013                          FRANK'S  FRANKS
# 42281   1878494                     Lincoln Park Academy
# 95432   2216157  AMERICAN KIDZ ACADEMY, LLC-LINCOLN PARK
# 12908   1354323               SPORTSERVICE SOLDIER FIELD
# 90134   2188929                  SUPERMERCADO LA TAPATIA
# 58219    200321                           FALAFIL  SHACK
# 47652    192701                               TONY'S SUB
# 44458   1894583                             BLUE SKY INN
#
#                                  AKA Name Inspection Date  \
# 12956                      GRIDIRON GRILL      2013-11-14
# 12952                      GRIDIRON GRILL      2010-06-07
# 60260            LAB KITCHEN B-ROOM 120B.      2013-09-09
# 12937                       BREWS BROTHER      2010-06-07
# 12916                     1ST DOWN FRANKS      2013-11-14
# 12924                      2ND CITY PIZZA      2013-11-14
# 12913                     1ST DOWN FRANKS      2010-06-07
# 8373                     SAVE-A-LOT  #855      2014-12-22
# 12920                      2ND CITY PIZZA      2010-06-07
# 26790                              SUBWAY      2010-03-22
# 12955                      GRIDIRON GRILL      2011-05-24
# 12954                      GRIDIRON GRILL      2011-05-23
# 69706                     FRANK'S  FRANKS      2012-02-16
# 42281                Lincoln Park Academy      2010-05-03
# 95432                                 NaN      2015-01-22
# 12908                      1ST DOWN FRANK      2010-06-07
# 90134  SUPERMERCADO LA TAPATIA CARNICERIA      2012-10-30
# 58219                                 NaN      2012-07-20
# 47652                          TONY'S SUB      2010-11-15
# 44458                        BLUE SKY INN      2012-09-05
#
#                 Inspection Type  count
# 12956                   Canvass      7
# 12952                   Canvass      5
# 60260                   Canvass      3
# 12937                   Canvass      3
# 12916                   Canvass      3
# 12924                   Canvass      3
# 12913                   Canvass      3
# 8373                    Canvass      3
# 12920                   Canvass      3
# 26790  Suspected Food Poisoning      3
# 12955                   Canvass      3
# 12954                   Canvass      3
# 69706                   Canvass      3
# 42281                   Canvass      2
# 95432                   Canvass      2
# 12908                   Canvass      2
# 90134                   License      2
# 58219                   Canvass      2
# 47652      Short Form Complaint      2
# 44458                   Canvass      2

# %%
print("How many unique food facilities/inspection date combinations have multiple inspections on that date?")
num_facility_date_multiple_inspections = len(inspection_counts2[inspection_counts2['count']>1])
num_facility_date_comb = len(inspection_counts2)
print(f"{num_facility_date_multiple_inspections} out of {num_facility_date_comb} ({round(100*num_facility_date_multiple_inspections/num_facility_date_comb, 2)}%)")

print("How many inspection records are involved ?")
num_inspection_involved = inspection_counts2[inspection_counts2['count']>1]['count'].sum()
print(f"{num_inspection_involved} out of {num_inspection} ({round(100*num_inspection_involved/num_inspection, 2)}%)")

print("How many unique license numbers are involved?")
num_license_involved = len(inspection_counts2[inspection_counts2['count']>1][['License #']].drop_duplicates())
print(f"{num_license_involved} out of {num_license} ({round(100*num_license_involved/num_license, 2)}%)")

print("How many unique food facilities are involved?")
num_facility_involved = len(inspection_counts2[inspection_counts2['count']>1][['License #', 'AKA Name']].drop_duplicates())
print(f"{num_facility_involved} out of {num_facility} ({round(100*num_facility_involved/num_facility, 2)}%)")

print("How many unique inspection dates are involved?")
num_dates_involved = len(inspection_counts2[inspection_counts2['count']>1][['Inspection Date']].drop_duplicates())
print(f"{num_dates_involved} out of {num_dates} ({round(100*num_dates_involved/num_dates, 2)}%)")
# Out:
# How many unique food facilities/inspection date combinations have multiple inspections on that date?
# 285 out of 153506 (0.19%)
# How many inspection records are involved ?
# 589 out of 153810 (0.38%)
# How many unique license numbers are involved?
# 247 out of 32752 (0.75%)
# How many unique food facilities are involved?
# 261 out of 33886 (0.77%)
# How many unique inspection dates are involved?
# 234 out of 1946 (12.02%)

# %% [markdown]
# What's happening there? Take one example to look into the details:

# %%
input_data[(input_data['License #']=='1354323') & (input_data['AKA Name']=='GRIDIRON GRILL') & (input_data['Inspection Date']=='11/14/13')]
# Out:
#       Inspection ID                    DBA Name        AKA Name License #  \
# 79430       1375402  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 79725       1375455  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 79730       1375451  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 79827       1375416  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 79831       1375414  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 79840       1375409  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 79842       1375407  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
#
#       Facility Type             Risk                   Address     City State  \
# 79430    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 79725    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 79730    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 79827    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 79831    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 79840    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 79842    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
#
#          Zip Inspection Date Inspection Type          Results Violations  \
# 79430  60605      2013-11-14         Canvass  Out of Business        NaN
# 79725  60605      2013-11-14         Canvass  Out of Business        NaN
# 79730  60605      2013-11-14         Canvass  Out of Business        NaN
# 79827  60605      2013-11-14         Canvass  Out of Business        NaN
# 79831  60605      2013-11-14         Canvass  Out of Business        NaN
# 79840  60605      2013-11-14         Canvass  Out of Business        NaN
# 79842  60605      2013-11-14         Canvass  Out of Business        NaN
#
#         Latitude  Longitude                                  Location
# 79430  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)
# 79725  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)
# 79730  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)
# 79827  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)
# 79831  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)
# 79840  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)
# 79842  41.862628 -87.615031  (41.862628294037634, -87.61503109411332)

# %% [markdown]
# We see that all of the Results are "Out of Business"!

# %%
temp2_ = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results', 'Violations']]
inspection_counts2_ = temp2_.groupby(by=['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results', 'Violations'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False)
inspection_counts2_.head(20)
# Out:
#        License #                                    DBA Name  \
# 12995    1354323                  SPORTSERVICE SOLDIER FIELD
# 12955    1354323                  SPORTSERVICE SOLDIER FIELD
# 69824    2065013                             FRANK'S  FRANKS
# 12994    1354323                  SPORTSERVICE SOLDIER FIELD
# 8389     1246854                            SAVE-A-LOT  #855
# 12945    1354323                  SPORTSERVICE SOLDIER FIELD
# 60369    2013962                             KENDALL COLLEGE
# 130427     26334                 PARADISE GARDEN PRODUCE INC
# 58052    2002692                         CHICAGO  MINI  MART
# 148334     66351                               ASPIRA HAUGAN
# 6545     1197541           GIORDANO'S RESTAURANT & PIZZAERIA
# 57467    1997806                            SUPER MAS MARKET
# 65937    2042893                            CO-OP SAUCE LLC.
# 114555   2363627  HOMEWOOD SUITES BY HILTON CHICAGO DOWNTOWN
# 36291    1801694                                THE BASEMENT
# 122306   2437593                               DUNKIN DONUTS
# 13063    1354323                  SPORTSERVICE SOLDIER FIELD
# 97                                           COMPLETELY NUTS
# 96                                           COMPLETELY NUTS
# 119410   2411206                          Half Acre Beer Co.
#
#                                  AKA Name Inspection Date Inspection Type  \
# 12995                      GRIDIRON GRILL      2013-11-14         Canvass
# 12955                      2ND CITY PIZZA      2013-11-14         Canvass
# 69824                     FRANK'S  FRANKS      2012-02-16         Canvass
# 12994                      GRIDIRON GRILL      2011-05-24         Canvass
# 8389                     SAVE-A-LOT  #855      2014-12-22         Canvass
# 12945                     1ST DOWN FRANKS      2013-11-14         Canvass
# 60369            LAB KITCHEN B-ROOM 120B.      2013-09-09         Canvass
# 130427        PARADISE GARDEN PRODUCE INC      2014-12-04         Canvass
# 58052                                 NaN      2016-12-08         Canvass
# 148334        ASPIRA HAUGAN MIDDLE SCHOOL      2010-01-20         Canvass
# 6545    GIORDANO'S RESTAURANT & PIZZAERIA      2015-12-07         Canvass
# 57467                    SUPER MAS MARKET      2013-01-03         Canvass
# 65937                    CO-OP SAUCE LLC.      2013-10-29         Canvass
# 114555                    HOMEWOOD SUITES      2016-08-03         Canvass
# 36291                        THE BASEMENT      2010-03-12       Complaint
# 122306                      DUNKIN DONUTS      2016-05-19         License
# 13063                       SKYLINE SUITE      2013-09-19         Canvass
# 97                        COMPLETELY NUTS      2012-06-14         Canvass
# 96                        COMPLETELY NUTS      2011-06-03         License
# 119410                 Half Acre Beer Co.      2015-07-10         License
#
#                 Results                                         Violations  \
# 12995   Out of Business                                                NaN
# 12955   Out of Business                                                NaN
# 69824   Out of Business                                                NaN
# 12994              Pass                                                NaN
# 8389    Out of Business                                                NaN
# 12945   Out of Business                                                NaN
# 60369   Out of Business                                                NaN
# 130427  Out of Business                                                NaN
# 58052   Out of Business                                                NaN
# 148334             Pass                                                NaN
# 6545    Out of Business                                                NaN
# 57467   Out of Business                                                NaN
# 65937   Out of Business                                                NaN
# 114555             Pass                                                NaN
# 36291              Fail                                                NaN
# 122306             Fail  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 13063   Out of Business                                                NaN
# 97                 Pass                                                NaN
# 96                 Pass                                                NaN
# 119410             Pass                                                NaN
#
#         count
# 12995       7
# 12955       3
# 69824       3
# 12994       3
# 8389        3
# 12945       3
# 60369       3
# 130427      2
# 58052       2
# 148334      2
# 6545        2
# 57467       2
# 65937       2
# 114555      2
# 36291       2
# 122306      2
# 13063       2
# 97          2
# 96          2
# 119410      2

# %% [markdown]
# Let's exclude the "Out of Business" Results:

# %%
temp3 = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results']]
inspection_counts3 = temp3[temp3['Results'] != 'Out of Business'].groupby(
    by=['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type'], dropna=False)\
    .size().rename('count').reset_index().sort_values(by='count', ascending=False)
inspection_counts3.head(20)
# Out:
#        License #                                    DBA Name  \
# 11458    1354323                  SPORTSERVICE SOLDIER FIELD
# 11461    1354323                  SPORTSERVICE SOLDIER FIELD
# 11460    1354323                  SPORTSERVICE SOLDIER FIELD
# 11448    1354323                  SPORTSERVICE SOLDIER FIELD
# 23495    1621492                                      SUBWAY
# 11435    1354323                  SPORTSERVICE SOLDIER FIELD
# 11430    1354323                  SPORTSERVICE SOLDIER FIELD
# 59566    2049216                      URBAN INDIA RESTAURANT
# 45495    1959931                  Chicago DQ Grill and Chill
# 68224    2102689              Yuki Hana Japanese Cuisine & S
# 50746    1997768                 NEW SUNRISE GYROS RESTURANT
# 85763      22171            Newton Bateman Elementary School
# 120633     29507                             POLK STREET CO.
# 126664      3943              L'APPETITO IMP ITALIAN FDS INC
# 42075     192701                                  TONY'S SUB
# 15990    1479601                  LA HACIENDITA TAQUERIA INC
# 103271   2363627  HOMEWOOD SUITES BY HILTON CHICAGO DOWNTOWN
# 97630     231423                              VHC LOWER, LLC
# 97629     231423                              VHC LOWER, LLC
# 97628     231423                              VHC LOWER, LLC
#
#                                              AKA Name Inspection Date  \
# 11458                                  GRIDIRON GRILL      2010-06-07
# 11461                                  GRIDIRON GRILL      2011-05-24
# 11460                                  GRIDIRON GRILL      2011-05-23
# 11448                                   BREWS BROTHER      2010-06-07
# 23495                                          SUBWAY      2010-03-22
# 11435                                  2ND CITY PIZZA      2010-06-07
# 11430                                 1ST DOWN FRANKS      2010-06-07
# 59566                          URBAN INDIA RESTAURANT      2010-08-10
# 45495                      Chicago DQ Grill and Chill      2012-03-01
# 68224                                       Yuki Hana      2011-12-01
# 50746                     NEW SUNRISE GYROS RESTURANT      2010-03-02
# 85763                Newton Bateman Elementary School      2017-04-24
# 120633                                POLK STREET CO.      2014-09-09
# 126664                                     L'APPETITO      2010-09-28
# 42075                                      TONY'S SUB      2010-11-15
# 15990                          LA HACIENDITA TAQUERIA      2012-02-09
# 103271                                HOMEWOOD SUITES      2016-08-03
# 97630   3RD FLOOR - BANQUET/MEETING ROOMS(LL KITCHEN)      2016-07-25
# 97629   3RD FLOOR - BANQUET/MEETING ROOMS(LL KITCHEN)      2015-10-23
# 97628   3RD FLOOR - BANQUET/MEETING ROOMS(LL KITCHEN)      2014-12-11
#
#                  Inspection Type  count
# 11458                    Canvass      5
# 11461                    Canvass      3
# 11460                    Canvass      3
# 11448                    Canvass      3
# 23495   Suspected Food Poisoning      3
# 11435                    Canvass      3
# 11430                    Canvass      3
# 59566                    License      2
# 45495                    Canvass      2
# 68224     Task Force Liquor 1475      2
# 50746       Short Form Complaint      2
# 85763                    Canvass      2
# 120633                   Canvass      2
# 126664                   Canvass      2
# 42075       Short Form Complaint      2
# 15990                    Canvass      2
# 103271                   Canvass      2
# 97630                    Canvass      2
# 97629                    Canvass      2
# 97628                    License      2

# %%
print("How many unique food facilities/inspection date combinations have multiple inspections on that date?")
num_facility_date_multiple_inspections = len(inspection_counts3[inspection_counts3['count']>1])
num_facility_date_comb = len(inspection_counts3)
print(f"{num_facility_date_multiple_inspections} out of {num_facility_date_comb} ({round(100*num_facility_date_multiple_inspections/num_facility_date_comb, 2)}%)")

print("How many inspection records are involved ?")
num_inspection_involved = inspection_counts3[inspection_counts3['count']>1]['count'].sum()
print(f"{num_inspection_involved} out of {num_inspection} ({round(100*num_inspection_involved/num_inspection, 2)}%)")

print("How many unique license numbers are involved?")
num_license_involved = len(inspection_counts3[inspection_counts3['count']>1][['License #']].drop_duplicates())
print(f"{num_license_involved} out of {num_license} ({round(100*num_license_involved/num_license, 2)}%)")

print("How many unique food facilities are involved?")
num_facility_involved = len(inspection_counts3[inspection_counts3['count']>1][['License #', 'AKA Name']].drop_duplicates())
print(f"{num_facility_involved} out of {num_facility} ({round(100*num_facility_involved/num_facility, 2)}%)")

print("How many unique inspection dates are involved?")
num_dates_involved = len(inspection_counts3[inspection_counts3['count']>1][['Inspection Date']].drop_duplicates())
print(f"{num_dates_involved} out of {num_dates} ({round(100*num_dates_involved/num_dates, 2)}%)")
# Out:
# How many unique food facilities/inspection date combinations have multiple inspections on that date?
# 190 out of 139817 (0.14%)
# How many inspection records are involved ?
# 389 out of 153810 (0.25%)
# How many unique license numbers are involved?
# 160 out of 32752 (0.49%)
# How many unique food facilities are involved?
# 172 out of 33886 (0.51%)
# How many unique inspection dates are involved?
# 157 out of 1946 (8.07%)

# %% [markdown]
# take an example:

# %%
input_data[(input_data['License #']=='1354323') & (input_data['AKA Name']=='GRIDIRON GRILL') & (input_data['Inspection Date']=='6/7/10')]
# Out:
#        Inspection ID                    DBA Name        AKA Name License #  \
# 146428        250633  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146436        197469  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146445        112420  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146450        160390  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146493        197476  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
#
#        Facility Type             Risk                   Address     City  \
# 146428    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO
# 146436    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO
# 146445    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO
# 146450    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO
# 146493    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO
#
#        State    Zip Inspection Date Inspection Type Results  \
# 146428    IL  60605      2010-06-07         Canvass    Pass
# 146436    IL  60605      2010-06-07         Canvass    Pass
# 146445    IL  60605      2010-06-07         Canvass    Pass
# 146450    IL  60605      2010-06-07         Canvass    Pass
# 146493    IL  60605      2010-06-07         Canvass    Pass
#
#                                                Violations   Latitude  \
# 146428  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.862628
# 146436  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.862628
# 146445  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.862628
# 146450  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.862628
# 146493  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.862628
#
#         Longitude                                  Location
# 146428 -87.615031  (41.862628294037634, -87.61503109411332)
# 146436 -87.615031  (41.862628294037634, -87.61503109411332)
# 146445 -87.615031  (41.862628294037634, -87.61503109411332)
# 146450 -87.615031  (41.862628294037634, -87.61503109411332)
# 146493 -87.615031  (41.862628294037634, -87.61503109411332)

# %% [markdown]
# The "Violations" are different!

# %%
input_data.loc[146428, 'Violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \n \nMUST DETAIL CLEAN FLOORS UNDER GRILL AND REMOVE FOOD DEBRIS AND GREASE BUILD UP.  '

# %%
input_data.loc[146493, 'Violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \nSTANDING WATER NEXT TO GREASE TRAP. INSTRUCTED TO CLEAN AND MAINTAIN. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned. \nPEELING PAINT NOTED ON WALL NEXT TO DEEP FRYER, INSTRUCTED MANAGER TO REMOVE AND MAINTAIN.'

# %% [markdown]
# Let's also consider results and violatoins:

# %%
temp4 = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results', 'Violations']]
inspection_counts4 = temp4[temp4['Results'] != 'Out of Business'].groupby(
    by=['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results', 'Violations'], dropna=False)\
    .size().rename('count').reset_index().sort_values(by='count', ascending=False)
inspection_counts4.head(20)
# Out:
#        License #                                    DBA Name  \
# 11496    1354323                  SPORTSERVICE SOLDIER FIELD
# 98422    2320537                           TACO  BELL #30409
# 23548    1621492                                      SUBWAY
# 11476    1354323                  SPORTSERVICE SOLDIER FIELD
# 77896    2158267                          PICOSITO GRILL-BAR
# 11465    1354323                  SPORTSERVICE SOLDIER FIELD
# 110774   2437593                               DUNKIN DONUTS
# 51717    2003567                  LEONIDAS CAFE CHOCOLATERIE
# 11457    1354323                  SPORTSERVICE SOLDIER FIELD
# 7610     1248767                                       SATAY
# 11452    1354323                  SPORTSERVICE SOLDIER FIELD
# 59658    2049216                      URBAN INDIA RESTAURANT
# 58300    2042583                         1234 BBQ RIBS INC.,
# 103397   2363627  HOMEWOOD SUITES BY HILTON CHICAGO DOWNTOWN
# 109293   2423352                                 KHYBER PASS
# 52083    2004423                          LOOMIS FOOD MARKET
# 83                                            CHURRO FACTORY
# 90                                           COMPLETELY NUTS
# 91                                           COMPLETELY NUTS
# 65820    2087939                               Mabuhay Grill
#
#                           AKA Name Inspection Date           Inspection Type  \
# 11496               GRIDIRON GRILL      2011-05-24                   Canvass
# 98422                    TACO BELL      2014-04-03                   License
# 23548                       SUBWAY      2010-03-22  Suspected Food Poisoning
# 11476                BREWS BROTHER      2010-06-07                   Canvass
# 77896           PICOSITO GRILL-BAR      2017-06-21                   Canvass
# 11465               2ND CITY PIZZA      2011-05-24                   Canvass
# 110774               DUNKIN DONUTS      2016-05-19                   License
# 51717   LEONIDAS CAFE CHOCOLATERIE      2010-03-31                   License
# 11457              1ST DOWN FRANKS      2011-05-24                   Canvass
# 7610                         SATAY      2014-08-01                   Canvass
# 11452               1ST DOWN FRANK      2011-05-24                   Canvass
# 59658       URBAN INDIA RESTAURANT      2010-08-10                   License
# 58300           HEEKRY'S BBQ PLACE      2012-04-27                   Canvass
# 103397             HOMEWOOD SUITES      2016-08-03                   Canvass
# 109293                 KHYBER PASS      2016-08-22                   Canvass
# 52083           LOOMIS FOOD MARKET      2017-03-14                 Complaint
# 83                  CHURRO FACTORY      2011-06-08                   License
# 90                 COMPLETELY NUTS      2011-06-03                   License
# 91                 COMPLETELY NUTS      2012-06-14                   Canvass
# 65820                Mabuhay Grill      2011-05-06                   License
#
#          Results                                         Violations  count
# 11496       Pass                                                NaN      3
# 98422       Fail                                                NaN      2
# 23548       Pass                                                NaN      2
# 11476       Pass                                                NaN      2
# 77896   No Entry                                                NaN      2
# 11465       Pass                                                NaN      2
# 110774      Fail  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...      2
# 51717       Pass                                                NaN      2
# 11457       Pass                                                NaN      2
# 7610    No Entry                                                NaN      2
# 11452       Pass                                                NaN      2
# 59658       Fail                                                NaN      2
# 58300       Fail                                                NaN      2
# 103397      Pass                                                NaN      2
# 109293  No Entry                                                NaN      2
# 52083   No Entry                                                NaN      2
# 83          Pass                                                NaN      2
# 90          Pass                                                NaN      2
# 91          Pass                                                NaN      2
# 65820       Fail                                                NaN      2

# %%
len(inspection_counts4[inspection_counts4['count']>1])
# Out:
# 40

# %%
# remove the exclusion of "out of business" inspections
temp5 = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results', 'Violations']]
inspection_counts5 = temp5.groupby(
    by=['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type', 'Results', 'Violations'], dropna=False)\
    .size().rename('count').reset_index().sort_values(by='count', ascending=False)
inspection_counts5.head(20)
# Out:
#        License #                                    DBA Name  \
# 12995    1354323                  SPORTSERVICE SOLDIER FIELD
# 12955    1354323                  SPORTSERVICE SOLDIER FIELD
# 69824    2065013                             FRANK'S  FRANKS
# 12994    1354323                  SPORTSERVICE SOLDIER FIELD
# 8389     1246854                            SAVE-A-LOT  #855
# 12945    1354323                  SPORTSERVICE SOLDIER FIELD
# 60369    2013962                             KENDALL COLLEGE
# 130427     26334                 PARADISE GARDEN PRODUCE INC
# 58052    2002692                         CHICAGO  MINI  MART
# 148334     66351                               ASPIRA HAUGAN
# 6545     1197541           GIORDANO'S RESTAURANT & PIZZAERIA
# 57467    1997806                            SUPER MAS MARKET
# 65937    2042893                            CO-OP SAUCE LLC.
# 114555   2363627  HOMEWOOD SUITES BY HILTON CHICAGO DOWNTOWN
# 36291    1801694                                THE BASEMENT
# 122306   2437593                               DUNKIN DONUTS
# 13063    1354323                  SPORTSERVICE SOLDIER FIELD
# 97                                           COMPLETELY NUTS
# 96                                           COMPLETELY NUTS
# 119410   2411206                          Half Acre Beer Co.
#
#                                  AKA Name Inspection Date Inspection Type  \
# 12995                      GRIDIRON GRILL      2013-11-14         Canvass
# 12955                      2ND CITY PIZZA      2013-11-14         Canvass
# 69824                     FRANK'S  FRANKS      2012-02-16         Canvass
# 12994                      GRIDIRON GRILL      2011-05-24         Canvass
# 8389                     SAVE-A-LOT  #855      2014-12-22         Canvass
# 12945                     1ST DOWN FRANKS      2013-11-14         Canvass
# 60369            LAB KITCHEN B-ROOM 120B.      2013-09-09         Canvass
# 130427        PARADISE GARDEN PRODUCE INC      2014-12-04         Canvass
# 58052                                 NaN      2016-12-08         Canvass
# 148334        ASPIRA HAUGAN MIDDLE SCHOOL      2010-01-20         Canvass
# 6545    GIORDANO'S RESTAURANT & PIZZAERIA      2015-12-07         Canvass
# 57467                    SUPER MAS MARKET      2013-01-03         Canvass
# 65937                    CO-OP SAUCE LLC.      2013-10-29         Canvass
# 114555                    HOMEWOOD SUITES      2016-08-03         Canvass
# 36291                        THE BASEMENT      2010-03-12       Complaint
# 122306                      DUNKIN DONUTS      2016-05-19         License
# 13063                       SKYLINE SUITE      2013-09-19         Canvass
# 97                        COMPLETELY NUTS      2012-06-14         Canvass
# 96                        COMPLETELY NUTS      2011-06-03         License
# 119410                 Half Acre Beer Co.      2015-07-10         License
#
#                 Results                                         Violations  \
# 12995   Out of Business                                                NaN
# 12955   Out of Business                                                NaN
# 69824   Out of Business                                                NaN
# 12994              Pass                                                NaN
# 8389    Out of Business                                                NaN
# 12945   Out of Business                                                NaN
# 60369   Out of Business                                                NaN
# 130427  Out of Business                                                NaN
# 58052   Out of Business                                                NaN
# 148334             Pass                                                NaN
# 6545    Out of Business                                                NaN
# 57467   Out of Business                                                NaN
# 65937   Out of Business                                                NaN
# 114555             Pass                                                NaN
# 36291              Fail                                                NaN
# 122306             Fail  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 13063   Out of Business                                                NaN
# 97                 Pass                                                NaN
# 96                 Pass                                                NaN
# 119410             Pass                                                NaN
#
#         count
# 12995       7
# 12955       3
# 69824       3
# 12994       3
# 8389        3
# 12945       3
# 60369       3
# 130427      2
# 58052       2
# 148334      2
# 6545        2
# 57467       2
# 65937       2
# 114555      2
# 36291       2
# 122306      2
# 13063       2
# 97          2
# 96          2
# 119410      2

# %%
print("How many unique food facilities/inspection date/result combinations have multiple inspections on that date?")
num_facility_date_multiple_inspections = len(inspection_counts5[inspection_counts5['count']>1])
num_facility_date_comb = len(inspection_counts5)
print(f"{num_facility_date_multiple_inspections} out of {num_facility_date_comb} ({round(100*num_facility_date_multiple_inspections/num_facility_date_comb, 2)}%)")

print("How many inspection records are involved ?")
num_inspection_involved = inspection_counts3[inspection_counts5['count']>1]['count'].sum()
print(f"{num_inspection_involved} out of {num_inspection} ({round(100*num_inspection_involved/num_inspection, 2)}%)")

print("How many unique license numbers are involved?")
num_license_involved = len(inspection_counts5[inspection_counts5['count']>1][['License #']].drop_duplicates())
print(f"{num_license_involved} out of {num_license} ({round(100*num_license_involved/num_license, 2)}%)")

print("How many unique food facilities are involved?")
num_facility_involved = len(inspection_counts5[inspection_counts5['count']>1][['License #', 'AKA Name']].drop_duplicates())
print(f"{num_facility_involved} out of {num_facility} ({round(100*num_facility_involved/num_facility, 2)}%)")

print("How many unique inspection dates are involved?")
num_dates_involved = len(inspection_counts5[inspection_counts5['count']>1][['Inspection Date']].drop_duplicates())
print(f"{num_dates_involved} out of {num_dates} ({round(100*num_dates_involved/num_dates, 2)}%)")
# Out:
# How many unique food facilities/inspection date/result combinations have multiple inspections on that date?
# 92 out of 153707 (0.06%)
# How many inspection records are involved ?
# 91 out of 153810 (0.06%)
# How many unique license numbers are involved?
# 76 out of 32752 (0.23%)
# How many unique food facilities are involved?
# 85 out of 33886 (0.25%)
# How many unique inspection dates are involved?
# 77 out of 1946 (3.96%)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %% [markdown]
# take an example:

# %%
input_data[(input_data['License #']=='1354323') 
           & (input_data['AKA Name']=='GRIDIRON GRILL') 
           & (input_data['Inspection Date']=='2011-05-24')
           & (input_data['Results']=='Pass')].reset_index(drop=True)
# Out:
#   Inspection ID                    DBA Name        AKA Name License #  \
# 0        567417  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 1        567415  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 2        569358  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
#
#   Facility Type             Risk                   Address     City State  \
# 0    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 1    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
# 2    Restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR   CHICAGO    IL
#
#      Zip Inspection Date Inspection Type Results Violations   Latitude  \
# 0  60605      2011-05-24         Canvass    Pass        NaN  41.862628
# 1  60605      2011-05-24         Canvass    Pass        NaN  41.862628
# 2  60605      2011-05-24         Canvass    Pass        NaN  41.862628
#
#    Longitude                                  Location
# 0 -87.615031  (41.862628294037634, -87.61503109411332)
# 1 -87.615031  (41.862628294037634, -87.61503109411332)
# 2 -87.615031  (41.862628294037634, -87.61503109411332)

# %% [markdown]
# ### Different license numbers for the same food facility?

# %% [markdown]
# Example:

# %%
input_data[input_data['AKA Name']=='LA MEXICANA TAMALE CART'][
    ['DBA Name','AKA Name','License #','Facility Type','Address','City','State','Zip',
     'Latitude','Longitude','Location', 'Inspection Date']
].drop_duplicates()
# Out:
#                                                 DBA Name  \
# 5101   PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11720  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11723  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11724  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11728  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11730  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11732  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11734  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11738  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11740  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11743  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11746  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11750  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11755  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11756  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11781  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 14046  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
#
#                       AKA Name License #                Facility Type  \
# 5101   LA MEXICANA TAMALE CART   2506389  Mobile Prepared Food Vendor
# 11720  LA MEXICANA TAMALE CART   2506388  Mobile Prepared Food Vendor
# 11723  LA MEXICANA TAMALE CART   2506235  Mobile Prepared Food Vendor
# 11724  LA MEXICANA TAMALE CART   2506234  Mobile Prepared Food Vendor
# 11728  LA MEXICANA TAMALE CART   2506233  Mobile Prepared Food Vendor
# 11730  LA MEXICANA TAMALE CART   2506231  Mobile Prepared Food Vendor
# 11732  LA MEXICANA TAMALE CART    250623  Mobile Prepared Food Vendor
# 11734  LA MEXICANA TAMALE CART   2506222  Mobile Prepared Food Vendor
# 11738  LA MEXICANA TAMALE CART    250622  Mobile Prepared Food Vendor
# 11740  LA MEXICANA TAMALE CART   2506221  Mobile Prepared Food Vendor
# 11743  LA MEXICANA TAMALE CART   2506215  Mobile Prepared Food Vendor
# 11746  LA MEXICANA TAMALE CART   2506213  Mobile Prepared Food Vendor
# 11750  LA MEXICANA TAMALE CART   2506212                   Restaurant
# 11755  LA MEXICANA TAMALE CART   2506211  Mobile Prepared Food Vendor
# 11756  LA MEXICANA TAMALE CART   2506209  Mobile Prepared Food Vendor
# 11781  LA MEXICANA TAMALE CART   2500986  Mobile Prepared Food Vendor
# 14046  LA MEXICANA TAMALE CART   2495679  Mobile Prepared Food Vendor
#
#                   Address     City State    Zip   Latitude  Longitude  \
# 5101   4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11720  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11723  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11724  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11728  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11730  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11732  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11734  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11738  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11740  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11743  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11746  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11750  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11755  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11756  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 11781  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 14046  4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
#
#                                       Location Inspection Date
# 5101   (41.81761758884696, -87.69825774800141)      2017-01-10
# 11720  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11723  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11724  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11728  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11730  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11732  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11734  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11738  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11740  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11743  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11746  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11750  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11755  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11756  (41.81761758884696, -87.69825774800141)      2017-01-10
# 11781  (41.81761758884696, -87.69825774800141)      2017-01-10
# 14046  (41.81761758884696, -87.69825774800141)      2016-11-22

# %% [markdown]
# Note that most of them have the facility type of "Mobile Prepared Food Vendor".

# %%
temp = input_data[[
    'DBA Name','AKA Name','License #','Facility Type','Address','City','State','Zip',
    'Latitude','Longitude','Location']].drop_duplicates()
facility_counts = temp.groupby(
    by=['DBA Name','AKA Name','Facility Type','Address','City','State','Zip','Latitude','Longitude','Location'], dropna=False)\
    .size().rename('count').reset_index().sort_values(by='count', ascending=False)
facility_counts.head(20)
# Out:
#                                                 DBA Name  \
# 27287                            TRIPLE A SERVICES, INC.
# 19563  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 27864                                     VHC LOWER, LLC
# 23368                                         SOHO HOUSE
# 19505                                PALETERIA AZTECA #2
# 28092                            WALDORF ASTORIA CHICAGO
# 9554                                      FLAT TOP GRILL
# 19451                PACIFIC LANGHAM CHICAGO CORPORATION
# 16748                            MARRIOT MARQUIS CHICAGO
# 19502                                PALETERIA AZTECA #2
# 19859                              PARS ICECREAM CO, INC
# 24836                                   SUPREME CATERING
# 26891                         THREE J'S BBQ & RESTAURANT
# 5110                       CHICAGO MARRIOTT O'HARE HOTEL
# 26120                                          THE CLARE
# 21576                   RENAISSANCE CHICAGO O'HARE HOTEL
# 15427                  LEVY RESTAURANTS AT UNITED CENTER
# 4985                 CHICAGO BORN LOSERS MOTORCYCLE CLUB
# 17472                                          MILENORTH
# 26916                               THUNDERBIRD CATERING
#
#                                             AKA Name  \
# 27287                        TRIPLE A SERVICES, INC.
# 19563                        LA MEXICANA TAMALE CART
# 27864  3RD FLOOR - BANQUET/MEETING ROOMS(LL KITCHEN)
# 23368                                     SOHO HOUSE
# 19505                                            NaN
# 28092                        WALDORF ASTORIA CHICAGO
# 9554                                  FLAT TOP GRILL
# 19451                            THE LANGHAM CHICAGO
# 16748                        MARRIOT MARQUIS CHICAGO
# 19502                            PALETERIA AZTECA #2
# 19859                                            NaN
# 24836                               SUPREME CATERING
# 26891                     THREE J'S BBQ & RESTAURANT
# 5110                   CHICAGO MARRIOTT O'HARE HOTEL
# 26120                                      THE CLARE
# 21576               RENAISSANCE CHICAGO O'HARE HOTEL
# 15427              LEVY RESTAURANTS AT UNITED CENTER
# 4985             CHICAGO BORN LOSERS MOTORCYCLE CLUB
# 17472                                            NaN
# 26916                           THUNDERBIRD CATERING
#
#                      Facility Type                Address     City State  \
# 27287        Mobile Food Dispenser      2637 S THROOP ST   CHICAGO    IL
# 19563  Mobile Prepared Food Vendor     4171 S ARCHER AVE   CHICAGO    IL
# 27864                   Restaurant      203 N WABASH AVE   CHICAGO    IL
# 23368                   Restaurant    113-125 N GREEN ST   CHICAGO    IL
# 19505        Mobile Food Dispenser      3119 W CERMAK RD   CHICAGO    IL
# 28092                   Restaurant        11 E WALTON ST   CHICAGO    IL
# 9554                    Restaurant       30 S WABASH AVE   CHICAGO    IL
# 19451                   Restaurant      330 N WABASH AVE   CHICAGO    IL
# 16748                   Restaurant    2121 S PRAIRIE AVE   CHICAGO    IL
# 19502        Mobile Food Dispenser      3119 W CERMAK RD   CHICAGO    IL
# 19859        Mobile Food Dispenser  4825 W ARTHINGTON ST   CHICAGO    IL
# 24836        Mobile Food Dispenser       1900 MAYWOOD DR   MAYWOOD    IL
# 26891        Mobile Food Dispenser        1713 E 75TH ST   CHICAGO    IL
# 5110                    Restaurant     8535 W HIGGINS RD   CHICAGO    IL
# 26120               Long Term Care       55 E PEARSON ST   CHICAGO    IL
# 21576                   Restaurant  8500 W BRYN MAWR AVE   CHICAGO    IL
# 15427                   Restaurant    1901 W MADISON AVE   CHICAGO    IL
# 4985                    Restaurant     4420 W MADISON ST   CHICAGO    IL
# 17472                   Restaurant     166 E SUPERIOR ST   CHICAGO    IL
# 26916                          NaN        1204 W 36TH PL   CHICAGO    IL
#
#          Zip   Latitude  Longitude                                  Location  \
# 27287  60608  41.844671 -87.654962    (41.84467072147077, -87.6549622241458)
# 19563  60632  41.817618 -87.698258   (41.81761758884696, -87.69825774800141)
# 27864  60601  41.885828 -87.626138  (41.885828292802344, -87.62613826248786)
# 23368  60607  41.883557 -87.648432  (41.883557097965046, -87.64843239611488)
# 19505  60623  41.851676 -87.703696   (41.85167565466277, -87.70369582116497)
# 28092  60611  41.899835 -87.627799    (41.89983492074242, -87.6277991723728)
# 9554   60603  41.881335 -87.626335   (41.88133480594687, -87.62633546646605)
# 19451  60611  41.887939 -87.627036   (41.88793874358949, -87.62703564148782)
# 16748  60616  41.853651 -87.620534  (41.853650885040594, -87.62053358114167)
# 19502  60623  41.851676 -87.703696   (41.85167565466277, -87.70369582116497)
# 19859  60644  41.869236 -87.745893   (41.86923620697448, -87.74589271238392)
# 24836  60153        NaN        NaN                                       NaN
# 26891  60649  41.758689 -87.582950   (41.75868882324165, -87.58295045587245)
# 5110   60631  41.986789 -87.840124    (41.9867885856625, -87.84012417346162)
# 26120  60611  41.897438 -87.626020    (41.8974381950521, -87.62602037433696)
# 21576  60631  41.981181 -87.839168   (41.98118072487806, -87.83916755770461)
# 15427  60612  41.881241 -87.674283  (41.881241456803345, -87.67428253395332)
# 4985   60624  41.880710 -87.736361   (41.880709909185384, -87.7363610783362)
# 17472  60611  41.895866 -87.623017    (41.89586560814865, -87.6230165441443)
# 26916  60609  41.828094 -87.655854   (41.82809412610231, -87.65585369468056)
#
#        count
# 27287     39
# 19563     16
# 27864     15
# 23368     10
# 19505     10
# 28092      9
# 9554       8
# 19451      7
# 16748      7
# 19502      7
# 19859      7
# 24836      7
# 26891      6
# 5110       6
# 26120      6
# 21576      6
# 15427      6
# 4985       6
# 17472      6
# 26916      6

# %%
len(facility_counts[facility_counts['count']>1])
# Out:
# 3909

# %%
len(facility_counts[facility_counts['count']>1])/len(facility_counts)
# Out:
# 0.13361361771944216

# %% [markdown]
# Note that some of them have the facility type of "Mobile Prepared Food Vendor". Some of the "Restaurant" facilities seem to be hotels, or within a complex.

# %% [markdown]
# ## 2. split the dataframe into multiple tables

# %%
list(input_data)
# Out:
# ['Inspection ID',
#  'DBA Name',
#  'AKA Name',
#  'License #',
#  'Facility Type',
#  'Risk',
#  'Address',
#  'City',
#  'State',
#  'Zip',
#  'Inspection Date',
#  'Inspection Type',
#  'Results',
#  'Violations',
#  'Latitude',
#  'Longitude',
#  'Location']

# %% [markdown]
# ### Inspection
# (Id, Date, Type, Result)

# %%
input_data[['Inspection ID', 'Inspection Date', 'Inspection Type', 'Results']]

# %% [markdown]
# ### Facility

# %%
input_data[['DBA Name', 'AKA Name', 'License #', 'Facility Type', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']]

# %% [markdown]
# The same License # can have multiple DBA Name?

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'DBA Name']].drop_duplicates()
temp[temp.duplicated(subset='License #', keep=False)].sort_values(by='License #')
# Out:
#        License #                                DBA Name
# 2031     1000774            RECLAIMED BAR AND RESTAURANT
# 13480    1000774                          Crabbby  Kim's
# 112603       104                    VITO & NICK'S LOUNGE
# 65459        104          MIARA'S CONT'L PASTRY DELI INC
# 17601    1042664                          BLOKES & BIRDS
# ...          ...                                     ...
# 19217       9648                            CAFFE ITALIA
# 3619         968                                CHEZ MOI
# 134794       968                            CAFE BERNARD
# 10660         99  XANDO COFFEE & BAR / COSI SANDWICH BAR
# 2002          99                           FALCO'S PIZZA
#
# [1317 rows x 2 columns]

# %% [markdown]
# The same License # can have multiple addresses?

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
temp[temp.duplicated(subset='License #', keep=False)].sort_values(by='License #')
# Out:
#        License #                  Address     City State    Zip   Latitude  \
# 65459        104  7051-7053 W ADDISON ST   CHICAGO    IL  60634  41.945234
# 112603       104  8433-8435 S PULASKI RD   CHICAGO    IL  60652  41.739329
# 98142    1045301         160 N LOOMIS ST   CHICAGO    IL  60607  41.883991
# 18089    1045301      1400 W RANDOLPH ST   CHICAGO    IL  60607  41.884274
# 99286    1093945     2321 W LAWRENCE AVE   CHICAGO    IL  60625  41.968527
# ...          ...                      ...      ...   ...    ...        ...
# 140385       845      820 S MICHIGAN AVE   CHICAGO    IL  60605  41.871577
# 137559       901          3835 W 26TH ST   CHICAGO    IL  60623  41.844188
# 99502        901       6647 S HALSTED ST   CHICAGO    IL  60621  41.772902
# 10660         99       203 N LA SALLE ST   CHICAGO    IL  60601  41.885822
# 2002          99          2806 W 40TH PL   CHICAGO    IL  60632  41.820231
#
#         Longitude
# 65459  -87.802927
# 112603 -87.721440
# 98142  -87.662525
# 18089  -87.662433
# 99286  -87.687315
# ...           ...
# 140385 -87.624310
# 137559 -87.720950
# 99502  -87.644461
# 10660  -87.632304
# 2002   -87.694875
#
# [667 rows x 7 columns]

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
temp[temp.duplicated(subset=['Address', 'City', 'State', 'Zip', 'Latitude','Longitude'], keep=False)].sort_values(by='Address')
# Out:
#        License #                 Address     City State    Zip   Latitude  \
# 10022    2215538           1 E 113TH ST   CHICAGO    IL  60628  41.688848
# 116298     21702           1 E 113TH ST   CHICAGO    IL  60628  41.688848
# 116300   1800876           1 E 113TH ST   CHICAGO    IL  60628  41.688848
# 42462    1843205        1 E DELAWARE PL   CHICAGO    IL  60611  41.899031
# 108154    203223        1 E DELAWARE PL   CHICAGO    IL  60611  41.899031
# ...          ...                     ...      ...   ...    ...        ...
# 88145    2013312       9917 S EWING AVE   CHICAGO    IL  60617  41.715244
# 75440    2046663  9928 S CRANDON AVE FL   CHICAGO    IL  60617  41.714402
# 9092     3247017  9928 S CRANDON AVE FL   CHICAGO    IL  60617  41.714402
# 15768    1998729      9939 S HALSTED ST   CHICAGO    IL  60628  41.713035
# 83412    2093742      9939 S HALSTED ST   CHICAGO    IL  60628  41.713035
#
#         Longitude
# 10022  -87.622894
# 116298 -87.622894
# 116300 -87.622894
# 42462  -87.628192
# 108154 -87.628192
# ...           ...
# 88145  -87.535130
# 75440  -87.567167
# 9092   -87.567167
# 15768  -87.642832
# 83412  -87.642832
#
# [23721 rows x 7 columns]

# %%
temp = input_data[['DBA Name', 'AKA Name', 'Address','Zip', 'Risk', 'Inspection Date']].drop_duplicates()
temp[temp.duplicated(subset=['DBA Name', 'AKA Name', 'Address','Zip', 'Inspection Date'], keep=False)]
# Out:
#                  DBA Name           AKA Name                  Address    Zip  \
# 30      NANDO'S PERI-PERI  NANDO'S PERI-PERI           117 E LAKE ST   60601
# 33      NANDO'S PERI-PERI  NANDO'S PERI-PERI           117 E LAKE ST   60601
# 52         THE PRESS ROOM     THE PRESS ROOM  1134 W WASHINGTON BLVD   60607
# 54         THE PRESS ROOM     THE PRESS ROOM  1134 W WASHINGTON BLVD   60607
# 149        THE PRESS ROOM     THE PRESS ROOM  1134 W WASHINGTON BLVD   60607
# ...                   ...                ...                      ...    ...
# 153143        FLO & SANTO        FLO & SANTO       1310 S WABASH AVE   60605
# 153352       WISHCO, INC.       WISHCO, INC.          1546 W 35TH ST   60609
# 153353       WISHCO, INC.       WISHCO, INC.          1546 W 35TH ST   60609
# 153608   HONG KONG MARKET   HONG KONG MARKET           520 W 24TH PL   60616
# 153625   HONG KONG MARKET   HONG KONG MARKET           520 W 24TH PL   60616
#
#                  Risk Inspection Date
# 30       Risk 3 (Low)      2017-08-25
# 33      Risk 1 (High)      2017-08-25
# 52       Risk 3 (Low)      2017-08-24
# 54      Risk 1 (High)      2017-08-24
# 149      Risk 3 (Low)      2017-08-22
# ...               ...             ...
# 153143   Risk 3 (Low)      2010-01-19
# 153352   Risk 3 (Low)      2010-01-13
# 153353  Risk 1 (High)      2010-01-13
# 153608   Risk 3 (Low)      2010-01-07
# 153625  Risk 1 (High)      2010-01-07
#
# [1423 rows x 6 columns]

# %%
list(input_data)
# Out:
# ['Inspection ID',
#  'DBA Name',
#  'AKA Name',
#  'License #',
#  'Facility Type',
#  'Risk',
#  'Address',
#  'City',
#  'State',
#  'Zip',
#  'Inspection Date',
#  'Inspection Type',
#  'Results',
#  'Violations',
#  'Latitude',
#  'Longitude',
#  'Location']

# %% [markdown]
# ### Facility_Risk

# %%
temp = input_data[input_data['License #']!=''][['License #', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset='License #', keep=False)].sort_values(by='License #')
# Out:
#        License #             Risk
# 65459        104    Risk 1 (High)
# 112603       104     Risk 3 (Low)
# 1729     1042664    Risk 1 (High)
# 91775    1042664     Risk 3 (Low)
# 4405        1094    Risk 1 (High)
# ...          ...              ...
# 37903       8425  Risk 2 (Medium)
# 137559       901    Risk 1 (High)
# 99502        901     Risk 3 (Low)
# 578          nan  Risk 2 (Medium)
# 113446       nan    Risk 1 (High)
#
# [471 rows x 2 columns]

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 127712                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 127627                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 33799    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 2313     1947909                      SUBWAY                      SUBWAY
# 115550   1947909                      SUBWAY                      SUBWAY
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 138772   2021346               INFUSION CAFE               INFUSION CAFE
# 138736   2021346               INFUSION CAFE               INFUSION CAFE
# 145463   2031677                 PORK SHOPPE                 PORK SHOPPE
# 145952   2031677                 PORK SHOPPE                 PORK SHOPPE
# 140399    203223               MORE CUPCAKES               MORE CUPCAKES
# 108154    203223               MORE CUPCAKES               MORE CUPCAKES
# 100153   2073639                THE SOUTHERN                THE SOUTHERN
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 36187    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
# 88857    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
# 81071    2098831                 TRENCHERMEN                 TRENCHERMEN
# 109207   2098831                 TRENCHERMEN                 TRENCHERMEN
# 122235   2113684                     WOW BAO                     WOW BAO
# 121526   2113684                     WOW BAO                     WOW BAO
# 111465   2152257                   TACO BELL                   TACO BELL
# 53947    2152257                   TACO BELL                   TACO BELL
# 79447    2240275             PARTS AND LABOR             PARTS AND LABOR
# 87760    2240275             PARTS AND LABOR             PARTS AND LABOR
# 18086    2492018          REAL GOOD JUICE CO          REAL GOOD JUICE CO
# 18066    2492018          REAL GOOD JUICE CO          REAL GOOD JUICE CO
# 4213     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
# 3143     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                    Risk
# 127712     Risk 3 (Low)
# 127627  Risk 2 (Medium)
# 33799     Risk 1 (High)
# 85087      Risk 3 (Low)
# 2313      Risk 1 (High)
# 115550     Risk 3 (Low)
# 80181   Risk 2 (Medium)
# 80180      Risk 3 (Low)
# 87107      Risk 3 (Low)
# 87109     Risk 1 (High)
# 69370      Risk 3 (Low)
# 84339     Risk 1 (High)
# 138772    Risk 1 (High)
# 138736     Risk 3 (Low)
# 145463    Risk 1 (High)
# 145952     Risk 3 (Low)
# 140399  Risk 2 (Medium)
# 108154     Risk 3 (Low)
# 100153  Risk 2 (Medium)
# 134516    Risk 1 (High)
# 36187      Risk 3 (Low)
# 88857   Risk 2 (Medium)
# 81071     Risk 1 (High)
# 109207     Risk 3 (Low)
# 122235    Risk 1 (High)
# 121526     Risk 3 (Low)
# 111465  Risk 2 (Medium)
# 53947     Risk 1 (High)
# 79447     Risk 1 (High)
# 87760      Risk 3 (Low)
# 18086     Risk 1 (High)
# 18066   Risk 2 (Medium)
# 4213                All
# 3143    Risk 2 (Medium)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Inspection Date'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85099    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 115550   1947909                      SUBWAY                      SUBWAY
# 115558   1947909                      SUBWAY                      SUBWAY
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 138736   2021346               INFUSION CAFE               INFUSION CAFE
# 138772   2021346               INFUSION CAFE               INFUSION CAFE
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 134550   2073639                THE SOUTHERN                THE SOUTHERN
# 88857    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
# 88923    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
#
#        Inspection Date             Risk
# 85087       2013-08-26     Risk 3 (Low)
# 85099       2013-08-26    Risk 1 (High)
# 115550      2012-02-02     Risk 3 (Low)
# 115558      2012-02-02    Risk 1 (High)
# 80180       2013-11-07     Risk 3 (Low)
# 80181       2013-11-07  Risk 2 (Medium)
# 87107       2013-07-22     Risk 3 (Low)
# 87109       2013-07-22    Risk 1 (High)
# 69370       2013-09-09     Risk 3 (Low)
# 84339       2013-09-09    Risk 1 (High)
# 138736      2010-10-28     Risk 3 (Low)
# 138772      2010-10-28    Risk 1 (High)
# 134516      2011-02-01    Risk 1 (High)
# 134550      2011-02-01  Risk 2 (Medium)
# 88857       2013-06-14  Risk 2 (Medium)
# 88923       2013-06-14     Risk 3 (Low)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Address', 'Inspection Date', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Address', 'Inspection Date'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85099    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 115550   1947909                      SUBWAY                      SUBWAY
# 115558   1947909                      SUBWAY                      SUBWAY
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 134550   2073639                THE SOUTHERN                THE SOUTHERN
#
#                        Address Inspection Date             Risk
# 85087    5605-5609 N CLARK ST       2013-08-26     Risk 3 (Low)
# 85099    5605-5609 N CLARK ST       2013-08-26    Risk 1 (High)
# 115550      6450 S PULASKI RD       2012-02-02     Risk 3 (Low)
# 115558      6450 S PULASKI RD       2012-02-02    Risk 1 (High)
# 80180         2804 N CLARK ST       2013-11-07     Risk 3 (Low)
# 80181         2804 N CLARK ST       2013-11-07  Risk 2 (Medium)
# 87107     4610 W DIVERSEY AVE       2013-07-22     Risk 3 (Low)
# 87109     4610 W DIVERSEY AVE       2013-07-22    Risk 1 (High)
# 69370   900 N NORTH BRANCH ST       2013-09-09     Risk 3 (Low)
# 84339   900 N NORTH BRANCH ST       2013-09-09    Risk 1 (High)
# 134516  1840-1842 W NORTH AVE       2011-02-01    Risk 1 (High)
# 134550  1840-1842 W NORTH AVE       2011-02-01  Risk 2 (Medium)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Address', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Address'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 127712                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 127627                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 33799    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 2313     1947909                      SUBWAY                      SUBWAY
# 115550   1947909                      SUBWAY                      SUBWAY
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 145463   2031677                 PORK SHOPPE                 PORK SHOPPE
# 145952   2031677                 PORK SHOPPE                 PORK SHOPPE
# 108154    203223               MORE CUPCAKES               MORE CUPCAKES
# 140399    203223               MORE CUPCAKES               MORE CUPCAKES
# 100153   2073639                THE SOUTHERN                THE SOUTHERN
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 121526   2113684                     WOW BAO                     WOW BAO
# 122235   2113684                     WOW BAO                     WOW BAO
# 79447    2240275             PARTS AND LABOR             PARTS AND LABOR
# 87760    2240275             PARTS AND LABOR             PARTS AND LABOR
# 4213     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
# 3143     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                        Address             Risk
# 127712        600 E GRAND AVE      Risk 3 (Low)
# 127627        600 E GRAND AVE   Risk 2 (Medium)
# 33799    5605-5609 N CLARK ST     Risk 1 (High)
# 85087    5605-5609 N CLARK ST      Risk 3 (Low)
# 2313        6450 S PULASKI RD     Risk 1 (High)
# 115550      6450 S PULASKI RD      Risk 3 (Low)
# 80180         2804 N CLARK ST      Risk 3 (Low)
# 80181         2804 N CLARK ST   Risk 2 (Medium)
# 87107     4610 W DIVERSEY AVE      Risk 3 (Low)
# 87109     4610 W DIVERSEY AVE     Risk 1 (High)
# 69370   900 N NORTH BRANCH ST      Risk 3 (Low)
# 84339   900 N NORTH BRANCH ST     Risk 1 (High)
# 145463     2755 W BELMONT AVE     Risk 1 (High)
# 145952     2755 W BELMONT AVE      Risk 3 (Low)
# 108154        1 E DELAWARE PL      Risk 3 (Low)
# 140399        1 E DELAWARE PL   Risk 2 (Medium)
# 100153  1840-1842 W NORTH AVE   Risk 2 (Medium)
# 134516  1840-1842 W NORTH AVE     Risk 1 (High)
# 121526     175 W JACKSON BLVD      Risk 3 (Low)
# 122235     175 W JACKSON BLVD     Risk 1 (High)
# 79447    2700 N MILWAUKEE AVE     Risk 1 (High)
# 87760    2700 N MILWAUKEE AVE      Risk 3 (Low)
# 4213         500 W MADISON ST               All
# 3143         500 W MADISON ST   Risk 2 (Medium)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name'], keep=False)].sort_values(by='License #')
# Out:
#        License #                                DBA Name             Risk
# 127712                                    FLAV-O-RICIOUS     Risk 3 (Low)
# 127627                                    FLAV-O-RICIOUS  Risk 2 (Medium)
# 149961   1120537  LEVY RESTAURANTS AT U.S CELLULAR FIELD    Risk 1 (High)
# 127783   1120537  LEVY RESTAURANTS AT U.S CELLULAR FIELD  Risk 2 (Medium)
# 95475     135245        ILLINOIS INSTITUTE OF TECHNOLOGY    Risk 1 (High)
# ...          ...                                     ...              ...
# 47119      32394                MART PLAZA CATERING CORP    Risk 1 (High)
# 36142      37979             BISMARCK ENTERPRISES/UNITED  Risk 2 (Medium)
# 84078      37979             BISMARCK ENTERPRISES/UNITED    Risk 1 (High)
# 120491      6121                                  MACY'S  Risk 2 (Medium)
# 5122        6121                                  MACY'S    Risk 1 (High)
#
# [99 rows x 3 columns]

# %% [markdown]
# ### Violation and  Inspection_Violation

# %%
violation_df = input_data[~pd.isnull(input_data['Violations'])][['Inspection ID', 'Violations']].reset_index(drop=True)
violation_df
# Out:
#        Inspection ID                                         Violations
# 0            2079125  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...
# 1            2079123  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 2            2079105  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 3            2079104  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 4            2079091  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# ...              ...                                                ...
# 123007         67733  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 123008         67732  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 123009         52234  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 123010         70269  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 123011        104236  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
#
# [123012 rows x 2 columns]

# %%
input_data['Violations'].values[2]
# Out:
# '8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  CLEAN, PROPER TEMPERATURE, CONCENTRATION, EXPOSURE TIME - Comments: NO DISH WASHING FACILITIES ON SITE, (NO THREE COMPARTMENT SINK, WITH GREASE TRAP, OR DISHMACHINE), INSTRUCTED TO PROVIDE, | 11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIGNED, AND MAINTAINED - Comments:  NO EXPOSED HAND SINK FOR REAR SERVICE AREA, INSTRUCTED TO PROVIDE,\n | 18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME OF INSPECTION, INSTRUCTED TO PROVIDE, UPON NEXT VISIT,'

# %%
violation_df = violation_df.assign(
    Violations=violation_df['Violations'].str.split(' \| ')).explode('Violations').reset_index(drop=True)
violation_df.head(10)
# Out:
#   Inspection ID                                         Violations
# 0       2079125  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...
# 1       2079125  11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...
# 2       2079125  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 3       2079123  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 4       2079123  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 5       2079105  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 6       2079105  31. CLEAN MULTI-USE UTENSILS AND SINGLE SERVIC...
# 7       2079105  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 8       2079105  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...
# 9       2079105  41. PREMISES MAINTAINED FREE OF LITTER, UNNECE...

# %%
violation_df.loc[0, 'Violations']
# Out:
# '8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  CLEAN, PROPER TEMPERATURE, CONCENTRATION, EXPOSURE TIME - Comments: NO DISH WASHING FACILITIES ON SITE, (NO THREE COMPARTMENT SINK, WITH GREASE TRAP, OR DISHMACHINE), INSTRUCTED TO PROVIDE,'

# %%
violation_df.loc[2, 'Violations']
# Out:
# '18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME OF INSPECTION, INSTRUCTED TO PROVIDE, UPON NEXT VISIT,'

# %%
violation_df.loc[5, 'Violations']
# Out:
# '18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: VIOLATION CORRECTED'

# %%
violation_df.loc[12, 'Violations']
# Out:
# '21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED - Comments: NO ORIGINAL CHICAGO FOOD SANITATION CERTIFICATE POSTED. INSTRUCTED MANAGER TO PROVIDE ORIGINAL FOOD SANITATION CERTIFICATE. COPIES ARE NOT ACCEPTABLE. SERIOUS VIOLATION 7-38-012A'

# %%
violation_df.loc[30, 'Violations']
# Out:
# '21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED - Comments: NO CITY OF CHICAGO CERTIFIED FOOD MANAGER ON SITE DURING INITIAL INSPECTION WHILE FOODS WERE BEING PREPARED. CERTIFIED MANAGER WAS TELEPHONED AT THE INITIAL INSPECTION AND ARRIVED THIRTY MINUTES LATER. INSTRUCTED A CITY OF CHICAGO CERTIFIED MANAGER MUST BE ON SITE AT ALL TIMES WHILE FOODS ARE PREPARED. SERIOUS VIOLATION. 7-38-012.'

# %%
def split_violation(violation):
    violation, comment = violation.split(' - Comments: ')
    code, description = violation.split('. ', 1)
    return code, description, comment
violation_df['code'], violation_df['description'], violation_df['comment'] = zip(*violation_df['Violations'].apply(split_violation))
violation_df = violation_df.drop(columns='Violations').drop_duplicates().reset_index(drop=True)
violation_df
# Out:
#        Inspection ID code                                        description  \
# 0            2079125    8  SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  ...
# 1            2079125   11  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIG...
# 2            2079125   18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 3            2079123   35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4            2079123   34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# ...              ...  ...                                                ...
# 568577        104236   36  LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIG...
# 568578        104236   37  TOILET ROOM DOORS SELF CLOSING: DRESSING ROOMS...
# 568579        104236   38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 568580        104236   39            LINEN: CLEAN AND SOILED PROPERLY STORED
# 568581        104236   41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
#
#                                                   comment
# 0       NO DISH WASHING FACILITIES ON SITE, (NO THREE ...
# 1        NO EXPOSED HAND SINK FOR REAR SERVICE AREA, I...
# 2       NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME ...
# 3       MUST PROVIDE OVERHEAD PROTECTION FOR COFFEE/TE...
# 4       FLOORS AT COFFEE/TEA STATIONS MUST BE MADE SMO...
# ...                                                   ...
# 568577  All rooms in which food or drink is prepared, ...
# 568578  None of the operations connected with food est...
# 568579  The flow of air discharged from kitchen fans s...
# 568580  Soiled and clean linens, coats, and aprons sha...
# 568581  All parts of the food establishment and all pa...
#
# [568582 rows x 4 columns]

# %%
violation_df[['Inspection ID', 'code']].duplicated().sum()
# Out:
# 7599

# %%
violations = violation_df[['code', 'description']].drop_duplicates().reset_index(drop=True)
violations
# Out:
#    code                                        description
# 0     8  SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  ...
# 1    11  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIG...
# 2    18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 3    35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4    34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 5    31  CLEAN MULTI-USE UTENSILS AND SINGLE SERVICE AR...
# 6    38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 7    41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
# 8     2          FACILITIES TO MAINTAIN PROPER TEMPERATURE
# 9    21  * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIA...
# 10   22  DISH MACHINES: PROVIDED WITH ACCURATE THERMOME...
# 11   30  FOOD IN ORIGINAL CONTAINER, PROPERLY LABELED: ...
# 12   32  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 13   33  FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS C...
# 14   37  TOILET ROOM DOORS SELF CLOSING: DRESSING ROOMS...
# 15    3  POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE R...
# 16   29     PREVIOUS MINOR VIOLATION(S) CORRECTED 7-42-090
# 17   12  HAND WASHING FACILITIES: WITH SOAP AND SANITAR...
# 18   19  OUTSIDE GARBAGE WASTE GREASE AND STORAGE AREA;...
# 19   43  FOOD (ICE) DISPENSING UTENSILS, WASH CLOTHS PR...
# 20   45                      FOOD HANDLER REQUIREMENTS MET
# 21   40  REFRIGERATION AND METAL STEM THERMOMETERS PROV...
# 22   13  NO EVIDENCE OF RODENT OR INSECT INFESTATION, N...
# 23    6  HANDS WASHED AND CLEANED, GOOD HYGIENIC PRACTI...
# 24   16  FOOD PROTECTED DURING STORAGE, PREPARATION, DI...
# 25   36  LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIG...
# 26   14     PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42-090
# 27   24  DISH WASHING FACILITIES: PROPERLY DESIGNED, CO...
# 28   28  * INSPECTION REPORT SUMMARY DISPLAYED AND VISI...
# 29    9  WATER SOURCE: SAFE, HOT & COLD UNDER CITY PRES...
# 30    1  SOURCE SOUND CONDITION, NO SPOILAGE, FOODS PRO...
# 31   42  APPROPRIATE METHOD OF HANDLING OF FOOD (ICE) H...
# 32   44    ONLY AUTHORIZED PERSONNEL IN THE FOOD-PREP AREA
# 33   10  SEWAGE AND WASTE WATER DISPOSAL, NO BACK SIPHO...
# 34   17         POTENTIALLY HAZARDOUS FOOD PROPERLY THAWED
# 35   70                             NO SMOKING REGULATIONS
# 36   27  TOILET ROOMS ENCLOSED CLEAN, PROVIDED WITH HAN...
# 37   39            LINEN: CLEAN AND SOILED PROPERLY STORED
# 38   25      TOXIC ITEMS PROPERLY STORED, LABELED AND USED
# 39   20  INSIDE CONTAINERS OR RECEPTACLES: ADEQUATE NUM...
# 40    4  SOURCE OF CROSS CONTAMINATION CONTROLLED I.E. ...
# 41   26  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, PROPE...
# 42   15  UNWRAPPED AND POTENTIALLY HAZARDOUS FOOD NOT R...
# 43    7  WASH AND RINSE WATER: CLEAN AND PROPER TEMPERA...
# 44    5  PERSONNEL WITH INFECTIONS RESTRICTED: NO OPEN ...
# 45   23       DISHES AND UTENSILS FLUSHED, SCRAPED, SOAKED

# %%
inspection_violation = violation_df[['Inspection ID', 'code', 'comment']]
inspection_violation
# Out:
#        Inspection ID code                                            comment
# 0            2079125    8  NO DISH WASHING FACILITIES ON SITE, (NO THREE ...
# 1            2079125   11   NO EXPOSED HAND SINK FOR REAR SERVICE AREA, I...
# 2            2079125   18  NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME ...
# 3            2079123   35  MUST PROVIDE OVERHEAD PROTECTION FOR COFFEE/TE...
# 4            2079123   34  FLOORS AT COFFEE/TEA STATIONS MUST BE MADE SMO...
# ...              ...  ...                                                ...
# 568577        104236   36  All rooms in which food or drink is prepared, ...
# 568578        104236   37  None of the operations connected with food est...
# 568579        104236   38  The flow of air discharged from kitchen fans s...
# 568580        104236   39  Soiled and clean linens, coats, and aprons sha...
# 568581        104236   41  All parts of the food establishment and all pa...
#
# [568582 rows x 3 columns]

# %% [markdown]
# Note that a certain inspection id/violation code combination can have multiple comments. For example:

# %%
inspection_violation.groupby(by=['Inspection ID', 'code']).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False).reset_index(drop=True)
# Out:
#        Inspection ID code  count
# 0            1764036   34      9
# 1            1975476   34      8
# 2            1547061   35      7
# 3            1501481   32      7
# 4            1234494   32      6
# ...              ...  ...    ...
# 560978       1459941   28      1
# 560979       1459941   21      1
# 560980       1459940   41      1
# 560981       1459940   35      1
# 560982         98544   35      1
#
# [560983 rows x 3 columns]

# %%
inspection_violation[(inspection_violation['Inspection ID']== '1764036') & (inspection_violation['code'] == '34')]
# Out:
#       Inspection ID code                                            comment
# 99332       1764036   34  REGROUT THE FLOOR IN FOOD PREP AREA ALL THE WA...
# 99333       1764036   34  DETAIL CLEAN FLOOR INSIDE WALK-IN COOLER AT BO...
# 99334       1764036   34  OBSERVED STANDING WATER ON FLOOR  ALONG FRONT ...
# 99336       1764036   34  FLOOR ALONG WALLBASE AND IN THE CORNERS IN NEE...
# 99337       1764036   34  MUST CLEAN FLOOR ALONG WALLS AND IN THE CORNER...
# 99338       1764036   34  MUST CLEAN FLOOR ALONG WALLS AND CORNERS AT BO...
# 99341       1764036   34  OBSERVED FRONT LINE WATER STANDING ON FLOOR AL...
# 99342       1764036   34  MUST CLEAN FLOOR ALONG THE WALLS AND IN THE CO...
# 99343       1764036   34  MUST CLEAN FLOOR ALONG THE WALLS AND IN CORNER...

# %% [markdown]
# ### Inspection_Risk

# %%
risk_df = input_data[~pd.isnull(input_data['Risk'])][['Inspection ID', 'Risk']].reset_index(drop=True)
risk_df
# Out:
#        Inspection ID             Risk
# 0            2079132    Risk 1 (High)
# 1            2079129  Risk 2 (Medium)
# 2            2079125     Risk 3 (Low)
# 3            2079123    Risk 1 (High)
# 4            2079105    Risk 1 (High)
# ...              ...              ...
# 153739         67732    Risk 1 (High)
# 153740         67757  Risk 2 (Medium)
# 153741         52234    Risk 1 (High)
# 153742         70269    Risk 1 (High)
# 153743        104236    Risk 1 (High)
#
# [153744 rows x 2 columns]

# %%
risk_df['Risk'].value_counts()
# Out:
# Risk 1 (High)      107351
# Risk 2 (Medium)     31845
# Risk 3 (Low)        14529
# All                    19
# Name: Risk, dtype: int64

# %%
list(re.compile(r'Risk (\d+) \((\w+)\)').match('Risk 2 (Medium)').groups())
# Out:
# ['2', 'Medium']

# %%
def extract_risk(s):
    matched = re.compile(r'\w+ (?P<code>\d+) \((?P<level>\w+)\)').match(s)
    if matched:
        return matched.group('code'), matched.group('level')
    else:
        return '', ''
    
print(extract_risk('Risk 2 (Medium)') ) 
print(extract_risk('Risk2(Medium)') )
# Out:
# ('2', 'Medium')
# ('', '')

# %%
risk_df['code'], risk_df['level'] = zip(*risk_df['Risk'].apply(extract_risk))

# %%
risk_df
# Out:
#        Inspection ID             Risk code   level
# 0            2079132    Risk 1 (High)    1    High
# 1            2079129  Risk 2 (Medium)    2  Medium
# 2            2079125     Risk 3 (Low)    3     Low
# 3            2079123    Risk 1 (High)    1    High
# 4            2079105    Risk 1 (High)    1    High
# ...              ...              ...  ...     ...
# 153739         67732    Risk 1 (High)    1    High
# 153740         67757  Risk 2 (Medium)    2  Medium
# 153741         52234    Risk 1 (High)    1    High
# 153742         70269    Risk 1 (High)    1    High
# 153743        104236    Risk 1 (High)    1    High
#
# [153744 rows x 4 columns]

# %%
risk_df[risk_df['code']=='']
# Out:
#        Inspection ID Risk code level
# 161          2078759  All
# 201          2078685  All
# 300          2078476  All
# 391          2078260  All
# 3139         2059435  All
# 4210         2050229  All
# 4672         2049776  All
# 6243         2010064  All
# 58570        1501748  All
# 67584        1474120  All
# 75258        1383423  All
# 77505        1320006  All
# 88601        1286310  All
# 94648        1084429  All
# 94673        1322184  All
# 98442        1319296  All
# 110686       1214783  All
# 116029        660163  All
# 117134        664312  All

# %%
risk_df['Risk'].apply(extract_risk)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-0555a985469f> in <module>
# ----> 1 risk_df['Risk'].apply(lambda x: re.compile(r'\w+ (\d+) \((\w+)\)').match(x).groups())
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-89-0555a985469f> in <lambda>(x)
# ----> 1 risk_df['Risk'].apply(lambda x: re.compile(r'\w+ (\d+) \((\w+)\)').match(x).groups())
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %%
>>> import re
... 
... input_example = "Today at 12:30 PM on Rakesh's Echo"
... regexp_1 = re.compile(r'(?P<day>\w+) at (?P<time>(\d+):(\d+) (\w+)) on (?P<place>\w+)')
... re_match = regexp_1.match(input_example)
>>> list(re_match.groups())
['Today', '12:30 PM', '12', '30', 'PM', 'Rakesh']
>>> re_match.group('day')
'Today'
>>> re_match.group('time')
'12:30 PM'
>>> re_match.group('place')
'Rakesh'

# %% [markdown]
# ### Inspection_Facility
