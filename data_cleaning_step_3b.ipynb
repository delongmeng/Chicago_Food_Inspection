# %% [markdown]
# **U1 (Target Use Case):**
# One could use this dataset to investigate whether different neighborhoods (indicated by zip code or geographic regions) have distinct food safety patterns, such as passing rate, complaint rate, risks, violations, and violation types, and further stratify the data by other factors (such as facility types and time range).

# %%
import pandas as pd
import numpy as np
import re
import string

# %%
input_data = pd.read_csv("data/open_refine_processed/Food-Inspections-openrefine.csv")
input_data.head()
# Out:
#    Inspection ID                 DBA Name                 AKA Name  License #  \
# 0        2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517328.0
# 1        2079129              JET'S PIZZA              JET'S PIZZA  2522268.0
# 2        2079125                ROOM 1520                ROOM 1520  2446638.0
# 3        2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517338.0
# 4        2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS  2549079.0
#
#     Facility Type Facility Type Cleaned             Risk  \
# 0      Restaurant            restaurant    Risk 1 (High)
# 1      Restaurant            restaurant  Risk 2 (Medium)
# 2   Special Event         special event     Risk 3 (Low)
# 3      Restaurant            restaurant    Risk 1 (High)
# 4  CHARTER SCHOOL                school    Risk 1 (High)
#
#                 Address     City State      Zip Inspection Date  \
# 0   2121 S PRAIRIE AVE   CHICAGO    IL  60616.0      08/28/2017
# 1    1025 W MADISON ST   CHICAGO    IL  60607.0      08/28/2017
# 2     301 N JUSTINE ST   CHICAGO    IL  60607.0      08/28/2017
# 3   2121 S PRAIRIE AVE   CHICAGO    IL  60616.0      08/28/2017
# 4  2245 N MCVICKER AVE   CHICAGO    IL  60639.0      08/28/2017
#
#   Inspection Date Transformed        Inspection Type Inspection Type Cleaned  \
# 0                  2017-08-28                License                 license
# 1                  2017-08-28                License                 license
# 2                  2017-08-28  License Re-Inspection   license re-inspection
# 3                  2017-08-28                License                 license
# 4                  2017-08-28  License Re-Inspection   license re-inspection
#
#      Results                                         Violations   Latitude  \
# 0       Pass                                                NaN  41.853651
# 1  Not Ready                                                NaN  41.881572
# 2  Not Ready  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       Pass  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       Pass  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
#
#    Longitude                                  Location
# 0 -87.620534  (41.853650885040594, -87.62053358114167)
# 1 -87.653052   (41.88157249576794, -87.65305233593274)
# 2 -87.665328   (41.88657652150854, -87.66532812140231)
# 3 -87.620534  (41.853650885040594, -87.62053358114167)
# 4 -87.776711   (41.921675488910864, -87.7767113569357)

# %%
input_data = input_data.drop(columns=['Facility Type', 'Inspection Date', 'Inspection Type']).rename(columns={
    'Facility Type Cleaned': 'Facility Type', 
    'Inspection Date Transformed': 'Inspection Date', 
    'Inspection Type Cleaned': 'Inspection Type'
})

# %%
input_data = input_data.rename(columns={
    'Inspection ID': 'inspection_id',
    'DBA Name': 'name_dba',
    'AKA Name': 'name_aka',
    'License #': 'license_id',
    'Facility Type': 'facility_type', 
    'Risk': 'risk',
    'Address': 'address',
    'City': 'city',
    'State': 'state',
    'Zip': 'zip',
    'Inspection Date': 'inspection_date', 
    'Inspection Type': 'inspection_type',
    'Results': 'results',
    'Violations': 'violations',
    'Latitude': 'latitude',
    'Longitude': 'longitude'
})
input_data.head()
# Out:
#    inspection_id                 name_dba                 name_aka  \
# 0        2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO
# 1        2079129              JET'S PIZZA              JET'S PIZZA
# 2        2079125                ROOM 1520                ROOM 1520
# 3        2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO
# 4        2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS
#
#    license_id  facility_type             risk               address     city  \
# 0   2517328.0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO
# 1   2522268.0     restaurant  Risk 2 (Medium)    1025 W MADISON ST   CHICAGO
# 2   2446638.0  special event     Risk 3 (Low)     301 N JUSTINE ST   CHICAGO
# 3   2517338.0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO
# 4   2549079.0         school    Risk 1 (High)  2245 N MCVICKER AVE   CHICAGO
#
#   state      zip inspection_date        inspection_type    results  \
# 0    IL  60616.0      2017-08-28                license       Pass
# 1    IL  60607.0      2017-08-28                license  Not Ready
# 2    IL  60607.0      2017-08-28  license re-inspection  Not Ready
# 3    IL  60616.0      2017-08-28                license       Pass
# 4    IL  60639.0      2017-08-28  license re-inspection       Pass
#
#                                           violations   latitude  longitude  \
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711
#
#                                    Location
# 0  (41.853650885040594, -87.62053358114167)
# 1   (41.88157249576794, -87.65305233593274)
# 2   (41.88657652150854, -87.66532812140231)
# 3  (41.853650885040594, -87.62053358114167)
# 4   (41.921675488910864, -87.7767113569357)

# %% [markdown]
# # 1. Basic data exploration and cleaning

# %% [markdown]
# ## 1.1 data types and duplicated column(s)

# %% [markdown]
# **[exploration]**
# Check data types and convert data types:

# %%
input_data.dtypes
# Out:
# inspection_id        int64
# name_dba            object
# name_aka            object
# license_id         float64
# facility_type       object
# risk                object
# address             object
# city                object
# state               object
# zip                float64
# inspection_date     object
# inspection_type     object
# results             object
# violations          object
# latitude           float64
# longitude          float64
# Location            object
# dtype: object

# %%
input_data['inspection_id'] = input_data['inspection_id'].astype(str)
input_data['license_id'] = input_data['license_id'].astype(str)
input_data['license_id'] = input_data['license_id'].str.replace('.0', '', regex=False)
input_data['zip'] = input_data['zip'].astype(str).str.replace('.0', '', regex=False)
input_data['inspection_date'] = pd.to_datetime(input_data['inspection_date'])
input_data.dtypes
# Out:
# inspection_id              object
# name_dba                   object
# name_aka                   object
# license_id                 object
# facility_type              object
# risk                       object
# address                    object
# city                       object
# state                      object
# zip                        object
# inspection_date    datetime64[ns]
# inspection_type            object
# results                    object
# violations                 object
# latitude                  float64
# longitude                 float64
# Location                   object
# dtype: object

# %% [markdown]
# **[exploration]**
# Check missing values:

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   inspection_id    153810 non-null  object
#  1   name_dba         153810 non-null  object
#  2   name_aka         151267 non-null  object
#  3   license_id       153810 non-null  object
#  4   facility_type    149250 non-null  object
#  5   risk             153744 non-null  object
#  6   address          153810 non-null  object
#  7   city             153651 non-null  object
#  8   state            153802 non-null  object
#  9   zip              153810 non-null  object
#  10  inspection_date  153810 non-null  datetime64[ns]
#  11  inspection_type  153809 non-null  object
#  12  results          153810 non-null  object
#  13  violations       123012 non-null  object
#  14  latitude         153266 non-null  float64
#  15  longitude        153266 non-null  float64
#  16  Location         153266 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(14)
# memory usage: 19.9+ MB

# %%
input_data.isnull().sum()
# Out:
# inspection_id          0
# name_dba               0
# name_aka            2543
# license_id             0
# facility_type       4560
# risk                  66
# address                0
# city                 159
# state                  8
# zip                    0
# inspection_date        0
# inspection_type        1
# results                0
# violations         30798
# latitude             544
# longitude            544
# Location             544
# dtype: int64

# %% [markdown]
# **[exploration]**
# Check whether the "location" column has the same information with the "latitude" and "longitude" columns:

# %%
def check_location(x):
    result = True
    e = 10e-5
    if (not pd.isnull(x['Location'])) and len(x['Location']) > 0:
        la, lo = x['Location'].strip('(|)').split(',')
        la, lo = float(la), float(lo)
        result = (abs(la - x['latitude']) < e) and (abs(lo - x['longitude']) < e)
    return result
    
sum(input_data.apply(check_location, axis=1)) == len(input_data)
# Out:
# True

# %% [markdown]
# **[cleaning]**
# So let's remove the "location" column since it does not provide any additional information:

# %%
input_data.drop(columns='Location', inplace=True)

# %%
input_data.head()
# Out:
#   inspection_id                 name_dba                 name_aka license_id  \
# 0       2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO    2517328
# 1       2079129              JET'S PIZZA              JET'S PIZZA    2522268
# 2       2079125                ROOM 1520                ROOM 1520    2446638
# 3       2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO    2517338
# 4       2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS    2549079
#
#    facility_type             risk               address     city state    zip  \
# 0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL  60616
# 1     restaurant  Risk 2 (Medium)    1025 W MADISON ST   CHICAGO    IL  60607
# 2  special event     Risk 3 (Low)     301 N JUSTINE ST   CHICAGO    IL  60607
# 3     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL  60616
# 4         school    Risk 1 (High)  2245 N MCVICKER AVE   CHICAGO    IL  60639
#
#   inspection_date        inspection_type    results  \
# 0      2017-08-28                license       Pass
# 1      2017-08-28                license  Not Ready
# 2      2017-08-28  license re-inspection  Not Ready
# 3      2017-08-28                license       Pass
# 4      2017-08-28  license re-inspection       Pass
#
#                                           violations   latitude  longitude
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711

# %% [markdown]
# ## 1.2 string cleanup for 'name_dba', 'name_aka', 'address', 'city', 'zip', 'state'

# %% [markdown]
# **[cleaning]**
# Clean up strings:

# %%
def clean_strings(x):
    return x.upper().replace('.', '').replace(',', '').replace("'", '').strip() if (not pd.isnull(x)) else x

for column in ['name_dba', 'name_aka', 'address', 'city']:
    input_data[column] = input_data[column].apply(clean_strings)

input_data.head()
# Out:
#   inspection_id                 name_dba                 name_aka license_id  \
# 0       2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO    2517328
# 1       2079129               JETS PIZZA               JETS PIZZA    2522268
# 2       2079125                ROOM 1520                ROOM 1520    2446638
# 3       2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO    2517338
# 4       2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS    2549079
#
#    facility_type             risk              address     city state    zip  \
# 0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1     restaurant  Risk 2 (Medium)    1025 W MADISON ST  CHICAGO    IL  60607
# 2  special event     Risk 3 (Low)     301 N JUSTINE ST  CHICAGO    IL  60607
# 3     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         school    Risk 1 (High)  2245 N MCVICKER AVE  CHICAGO    IL  60639
#
#   inspection_date        inspection_type    results  \
# 0      2017-08-28                license       Pass
# 1      2017-08-28                license  Not Ready
# 2      2017-08-28  license re-inspection  Not Ready
# 3      2017-08-28                license       Pass
# 4      2017-08-28  license re-inspection       Pass
#
#                                           violations   latitude  longitude
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711

# %% [markdown]
# **[exploration]**
# Check whether the "city", and "state" columns look good:

# %%
input_data['city'].value_counts()
# Out:
# CHICAGO                 153435
# CCHICAGO                    39
# SCHAUMBURG                  18
# MAYWOOD                     15
# ELK GROVE VILLAGE           12
# CHESTNUT STREET              8
# INACTIVE                     8
# SKOKIE                       8
# EVANSTON                     7
# CICERO                       6
# CHICAGOCHICAGO               6
# CHCHICAGO                    6
# CHARLES A HAYES              6
# ELMHURST                     5
# WORTH                        5
# ALSIP                        4
# SUMMIT                       4
# CALUMET CITY                 4
# OAK PARK                     4
# EAST HAZEL CREST             3
# NILES NILES                  3
# CHICAGOI                     3
# SCHILLER PARK                3
# CHCICAGO                     3
# BEDFORD PARK                 2
# BANNOCKBURNDEERFIELD         2
# BERWYN                       2
# NAPERVILLE                   2
# STREAMWOOD                   2
# CHICAGO HEIGHTS              2
# BLUE ISLAND                  2
# 312CHICAGO                   2
# OLYMPIA FIELDS               1
# GLENCOE                      1
# OAK LAWN                     1
# DES PLAINES                  1
# FRANKFORT                    1
# BROADVIEW                    1
# LAKE BLUFF                   1
# LAKE ZURICH                  1
# COUNTRY CLUB HILLS           1
# BURNHAM                      1
# BOLINGBROOK                  1
# LOMBARD                      1
# TINLEY PARK                  1
# JUSTICE                      1
# WESTMONT                     1
# OOLYMPIA FIELDS              1
# NORRIDGE                     1
# BRIDEVIEW                    1
# BLOOMINGDALE                 1
# EVERGREEN PARK               1
# Name: city, dtype: int64

# %% [markdown]
# **[cleaning]**
# We do notice some misspelling of "CHICAGO", as well as "INACTIVE",
# let's correct them:

# %%
input_data['city'] = input_data['city'].apply(
    lambda x: 'CHICAGO' if x in ['CCHICAGO', 'CHICAGOCHICAGO', 'CHCHICAGO', 'CHICAGOI', 'CHCICAGO', '312CHICAGO'] else (np.nan if x=='INACTIVE' else x))
input_data['city'].value_counts()
# Out:
# CHICAGO                 153494
# SCHAUMBURG                  18
# MAYWOOD                     15
# ELK GROVE VILLAGE           12
# SKOKIE                       8
# CHESTNUT STREET              8
# EVANSTON                     7
# CHARLES A HAYES              6
# CICERO                       6
# ELMHURST                     5
# WORTH                        5
# ALSIP                        4
# OAK PARK                     4
# CALUMET CITY                 4
# SUMMIT                       4
# EAST HAZEL CREST             3
# SCHILLER PARK                3
# NILES NILES                  3
# STREAMWOOD                   2
# BLUE ISLAND                  2
# CHICAGO HEIGHTS              2
# NAPERVILLE                   2
# BANNOCKBURNDEERFIELD         2
# BEDFORD PARK                 2
# BERWYN                       2
# GLENCOE                      1
# FRANKFORT                    1
# DES PLAINES                  1
# OAK LAWN                     1
# OLYMPIA FIELDS               1
# BROADVIEW                    1
# LAKE ZURICH                  1
# WESTMONT                     1
# BURNHAM                      1
# BOLINGBROOK                  1
# COUNTRY CLUB HILLS           1
# LOMBARD                      1
# TINLEY PARK                  1
# JUSTICE                      1
# OOLYMPIA FIELDS              1
# NORRIDGE                     1
# BLOOMINGDALE                 1
# BRIDEVIEW                    1
# LAKE BLUFF                   1
# EVERGREEN PARK               1
# Name: city, dtype: int64

# %% [markdown]
# **[exploration]**
# Check whether the "zip" column has valid values:
# There are also some missing values "nan". We can also check if all zip codes are valid (5 digits).

# %%
sorted(list(set(input_data['zip'])))
# Out:
# ['60007',
#  '60015',
#  '60018',
#  '60022',
#  '60044',
#  '60047',
#  '60076',
#  '60077',
#  '60107',
#  '60108',
#  '60126',
#  '60148',
#  '60153',
#  '60155',
#  '60176',
#  '60193',
#  '60201',
#  '60202',
#  '60302',
#  '60402',
#  '60406',
#  '60409',
#  '60411',
#  '60423',
#  '60429',
#  '60440',
#  '60453',
#  '60458',
#  '60461',
#  '60477',
#  '60478',
#  '60482',
#  '60501',
#  '60540',
#  '60559',
#  '60601',
#  '60602',
#  '60603',
#  '60604',
#  '60605',
#  '60606',
#  '60607',
#  '60608',
#  '60609',
#  '60610',
#  '60611',
#  '60612',
#  '60613',
#  '60614',
#  '60615',
#  '60616',
#  '60617',
#  '60618',
#  '60619',
#  '60620',
#  '60621',
#  '60622',
#  '60623',
#  '60624',
#  '60625',
#  '60626',
#  '60627',
#  '60628',
#  '60629',
#  '60630',
#  '60631',
#  '60632',
#  '60633',
#  '60634',
#  '60636',
#  '60637',
#  '60638',
#  '60639',
#  '60640',
#  '60641',
#  '60642',
#  '60643',
#  '60644',
#  '60645',
#  '60646',
#  '60647',
#  '60649',
#  '60651',
#  '60652',
#  '60653',
#  '60654',
#  '60655',
#  '60656',
#  '60657',
#  '60659',
#  '60660',
#  '60661',
#  '60666',
#  '60706',
#  '60707',
#  '60714',
#  '60803',
#  '60804',
#  '60805',
#  '60827',
#  'nan']

# %%
input_data[input_data['zip']=='nan'].head()
# Out:
#      inspection_id           name_dba             name_aka license_id  \
# 5927       2028349           KITCHFIX  KITCHFIX GOLD COAST    2418085
# 7750       1995776      MONICAS PIZZA        MONICAS PIZZA    2522031
# 8422       1990124   7-ELEVEN #37622B     7-ELEVEN #37622B    2492548
# 8483       1990130   7-ELEVEN #37622B     7-ELEVEN #37622B    2492551
# 8491       1990118  7-ELEVEN # 37622A             7 ELEVEN    2442933
#
#      facility_type             risk                 address city state  zip  \
# 5927    restaurant  Risk 2 (Medium)         1165 N STATE ST  NaN    IL  nan
# 7750    restaurant    Risk 1 (High)  6446-6448 S PULASKI RD  NaN    IL  nan
# 8422       grocery  Risk 2 (Medium)        4 W JACKSON BLVD  NaN    IL  nan
# 8483       grocery  Risk 2 (Medium)        4 W JACKSON BLVD  NaN    IL  nan
# 8491       grocery    Risk 1 (High)        4 W JACKSON BLVD  NaN    IL  nan
#
#      inspection_date inspection_type          results  \
# 5927      2017-04-14       complaint             Pass
# 7750      2017-03-17         license             Pass
# 8422      2017-03-07         license             Pass
# 8483      2017-03-07         license             Pass
# 8491      2017-03-07         canvass  Out of Business
#
#                                              violations   latitude  longitude
# 5927  42. APPROPRIATE METHOD OF HANDLING OF FOOD (IC...  41.903769 -87.628532
# 7750                                                NaN  41.775402 -87.722822
# 8422  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.878286 -87.627804
# 8483                                                NaN  41.878286 -87.627804
# 8491                                                NaN  41.878286 -87.627804

# %% [markdown]
# Except for the 'nan' values, all other values have 5 digits:

# %%
input_data[(input_data['zip']!='nan') & (input_data['zip'].str.len()!= 5)]
# Out:
# Empty DataFrame
# Columns: [inspection_id, name_dba, name_aka, license_id, facility_type, risk, address, city, state, zip, inspection_date, inspection_type, results, violations, latitude, longitude]
# Index: []

# %% [markdown]
# **[cleaning]**
# Convert all 'nan' zip values to be null:

# %%
input_data['zip'] = input_data['zip'].apply(lambda x: np.nan if x=='nan' else x)
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153805                       TROQUET    1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153807                      CAFE 608    2013328     restaurant
# 153808                     MRDANIELS    1899292     restaurant
# 153809                    TEMPO CAFE      80916     restaurant
#
#                    risk              address     city state    zip  \
# 0         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)    1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)     301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)  2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                  ...      ...   ...    ...
# 153805    Risk 1 (High)  1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)    100 W RANDOLPH ST  CHICAGO    IL  60601
# 153807    Risk 1 (High)      608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)   5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)      6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
list(set(input_data['zip']))
# Out:
# [nan,
#  '60461',
#  '60660',
#  '60047',
#  '60107',
#  '60629',
#  '60706',
#  '60076',
#  '60640',
#  '60176',
#  '60478',
#  '60643',
#  '60645',
#  '60429',
#  '60615',
#  '60646',
#  '60638',
#  '60627',
#  '60653',
#  '60661',
#  '60477',
#  '60625',
#  '60559',
#  '60644',
#  '60651',
#  '60614',
#  '60827',
#  '60440',
#  '60007',
#  '60621',
#  '60620',
#  '60402',
#  '60637',
#  '60155',
#  '60406',
#  '60619',
#  '60634',
#  '60126',
#  '60652',
#  '60616',
#  '60630',
#  '60202',
#  '60603',
#  '60618',
#  '60602',
#  '60707',
#  '60453',
#  '60617',
#  '60609',
#  '60631',
#  '60482',
#  '60639',
#  '60655',
#  '60641',
#  '60015',
#  '60654',
#  '60657',
#  '60077',
#  '60201',
#  '60656',
#  '60803',
#  '60108',
#  '60423',
#  '60649',
#  '60804',
#  '60302',
#  '60647',
#  '60612',
#  '60458',
#  '60605',
#  '60604',
#  '60636',
#  '60501',
#  '60022',
#  '60659',
#  '60193',
#  '60622',
#  '60411',
#  '60642',
#  '60610',
#  '60018',
#  '60148',
#  '60666',
#  '60606',
#  '60044',
#  '60714',
#  '60601',
#  '60540',
#  '60626',
#  '60632',
#  '60628',
#  '60153',
#  '60613',
#  '60607',
#  '60805',
#  '60611',
#  '60623',
#  '60624',
#  '60409',
#  '60633',
#  '60608']

# %% [markdown]
# **[exploaration]**
# Check the state column:
# There are only 8 records with missing "state" while all others are "IL". We can also see that we might be able to infer the "state" from "zip". We will take care of this later.

# %%
list(set(input_data['state']))
# Out:
# [nan, 'IL']

# %%
input_data['state'].isnull().sum()
# Out:
# 8

# %%
input_data[input_data['state'].isnull()]
# Out:
#        inspection_id                  name_dba                  name_aka  \
# 20927        1950389  AMY BECK CAKE DESIGN LLC  AMY BECK CAKE DESIGN LLC
# 43620        1566316  AMY BECK CAKE DESIGN LLC  AMY BECK CAKE DESIGN LLC
# 44075        1562023  AMY BECK CAKE DESIGN LLC  AMY BECK CAKE DESIGN LLC
# 70837        1459452  AMY BECK CAKE DESIGN LLC  AMY BECK CAKE DESIGN LLC
# 88043        1353435       EMPORIUM ARCADE BAR       EMPORIUM ARCADE BAR
# 108931       1229551       EMPORIUM ARCADE BAR       EMPORIUM ARCADE BAR
# 109306       1229384       EMPORIUM ARCADE BAR       EMPORIUM ARCADE BAR
# 133613        579263  AMY BECK CAKE DESIGN LLC  AMY BECK CAKE DESIGN LLC
#
#        license_id facility_type           risk               address     city  \
# 20927     2079264        bakery  Risk 1 (High)      636 N RACINE AVE      NaN
# 43620     2079264        bakery  Risk 1 (High)      636 N RACINE AVE      NaN
# 44075     2079264        bakery  Risk 1 (High)      636 N RACINE AVE      NaN
# 70837     2079264        bakery  Risk 1 (High)      636 N RACINE AVE      NaN
# 88043     2133873        tavern   Risk 3 (Low)  1366 N MILWAUKEE AVE  CHICAGO
# 108931    2133873        tavern   Risk 3 (Low)  1366 N MILWAUKEE AVE  CHICAGO
# 109306    2133873        tavern   Risk 3 (Low)  1366 N MILWAUKEE AVE  CHICAGO
# 133613    2079264        bakery  Risk 1 (High)      636 N RACINE AVE      NaN
#
#        state    zip inspection_date        inspection_type          results  \
# 20927    NaN  60642      2016-08-15                canvass             Pass
# 43620    NaN  60642      2015-08-17                canvass             Pass
# 44075    NaN  60642      2015-08-10                canvass             Fail
# 70837    NaN  60642      2014-05-06                canvass             Pass
# 88043    NaN  60642      2013-07-02                canvass  Out of Business
# 108931   NaN  60642      2012-06-11  license re-inspection             Pass
# 109306   NaN  60642      2012-06-05                license             Fail
# 133613   NaN  60642      2011-02-22                license             Pass
#
#                                                violations   latitude  \
# 20927   34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.893380
# 43620   21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.893380
# 44075   21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.893380
# 70837   42. APPROPRIATE METHOD OF HANDLING OF FOOD (IC...  41.893380
# 88043                                                 NaN  41.906543
# 108931                                                NaN  41.906543
# 109306  12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  41.906543
# 133613                                                NaN  41.893380
#
#         longitude
# 20927  -87.657588
# 43620  -87.657588
# 44075  -87.657588
# 70837  -87.657588
# 88043  -87.671693
# 108931 -87.671693
# 109306 -87.671693
# 133613 -87.657588

# %%
input_data[input_data['zip']=='60642'][['zip', 'state', 'city']].drop_duplicates()
# Out:
#          zip state     city
# 174    60642    IL  CHICAGO
# 20927  60642   NaN      NaN
# 88043  60642   NaN  CHICAGO

# %% [markdown]
# ## 1.3 Clean up address variations and incorrect/missing city/zip/state

# %% [markdown]
# **[exploaration]**
# Further check if there are different variations of addresses for the same location (latitude & longitude) and city/state/zip:

# %%
temp = input_data[['address', 'latitude', 'longitude']].drop_duplicates()
address_duplicated = temp.groupby(
    by=['latitude', 'longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['latitude', 'address'], ascending=False)

address_duplicated
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
#    display(address_duplicated)
# Out:
#                          address   latitude  longitude
# 25889           1632 W HOWARD ST  42.019490 -87.672057
# 83917         1632 W HOWARD BLDG  42.019490 -87.672057
# 148429           7410 N CLARK ST  42.016328 -87.675398
# 77277          7410 N CLARK BLDG  42.016328 -87.675398
# 5653           7318 N OAKLEY AVE  42.014660 -87.687677
# ...                          ...        ...        ...
# 23977             106 W 119TH ST  41.678105 -87.625439
# 5574    12201-12209 S HALSTED ST  41.672270 -87.641576
# 37884         12201 S HALSTED ST  41.672270 -87.641576
# 100604      13703 S INDIANA BLDG  41.646554 -87.617083
# 100601       13703 S INDIANA AVE  41.646554 -87.617083
#
# [1598 rows x 3 columns]

# %% [markdown]
# **[cleaning]**
# Let's clean up the "address" column for these situations. We'll just use the address from the first record for the duplicated records:

# %%
address_dedup = address_duplicated.drop_duplicates(subset=['latitude', 'longitude'], keep='first')
address_dedup
# Out:
#                           address   latitude  longitude
# 25889            1632 W HOWARD ST  42.019490 -87.672057
# 148429            7410 N CLARK ST  42.016328 -87.675398
# 5653            7318 N OAKLEY AVE  42.014660 -87.687677
# 11421        7138-7140 N CLARK ST  42.012561 -87.674774
# 98091           3146 W TOUHY BLDG  42.011980 -87.708534
# ...                           ...        ...        ...
# 15741          555-557 W 115TH ST  41.685036 -87.637083
# 20901   11919 S AVENUE O AVE FRNT  41.678517 -87.539894
# 41055          106-108 W 119TH ST  41.678105 -87.625439
# 5574     12201-12209 S HALSTED ST  41.672270 -87.641576
# 100604       13703 S INDIANA BLDG  41.646554 -87.617083
#
# [769 rows x 3 columns]

# %%
address_to_check, la_to_check, lo_to_check = list(set(address_duplicated['address'])), list(set(address_duplicated['latitude'])), list(set(address_duplicated['longitude']))

def clean_address(x):
    address, la, lo = x['address'], x['latitude'], x['longitude']
    if (address in address_to_check) and (la in la_to_check) and (lo in lo_to_check):
        temp = address_dedup[(address_dedup['latitude']==la) & (address_dedup['longitude']==lo)]
        if len(temp) == 1:
            address = temp['address'].values[0]

    return address
        
input_data['address'] = input_data.apply(clean_address, axis=1)
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153805                       TROQUET    1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153807                      CAFE 608    2013328     restaurant
# 153808                     MRDANIELS    1899292     restaurant
# 153809                    TEMPO CAFE      80916     restaurant
#
#                    risk                     address     city state    zip  \
# 0         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)           1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)            301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)         2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                         ...      ...   ...    ...
# 153805    Risk 1 (High)         1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)  100 W RANDOLPH ST STE C-19  CHICAGO    IL  60601
# 153807    Risk 1 (High)             608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)          5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)             6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data[['address', 'latitude', 'longitude']].drop_duplicates()
temp.groupby(
    by=['latitude', 'longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['latitude', 'address'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [address, latitude, longitude]
# Index: []

# %% [markdown]
# **[exploaration]**
# Further check the "city" information:

# %%
temp = input_data.groupby(by=['latitude', 'longitude', 'city'], dropna=False).size().rename('count').reset_index()
duplicated_city = temp.groupby(by=['latitude', 'longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['latitude', 'longitude', 'count'], ascending=False)
duplicated_city
# Out:
#         latitude  longitude             city  count
# 15690  42.008536 -87.914428          CHICAGO   1874
# 15691  42.008536 -87.914428              NaN     10
# 14419  41.975801 -87.713499          CHICAGO     11
# 14420  41.975801 -87.713499              NaN      1
# 14271  41.973068 -87.659926              NaN      2
# 14270  41.973068 -87.659926          CHICAGO      1
# 14215  41.971217 -87.659582          CHICAGO      4
# 14216  41.971217 -87.659582              NaN      1
# 14003  41.968491 -87.659816          CHICAGO      6
# 14004  41.968491 -87.659816              NaN      2
# 13671  41.965865 -87.693871              NaN      4
# 13670  41.965865 -87.693871          CHICAGO      2
# 13593  41.965212 -87.663260          CHICAGO     13
# 13594  41.965212 -87.663260              NaN      5
# 13270  41.960675 -87.729113          CHICAGO      8
# 13271  41.960675 -87.729113              NaN      2
# 13172  41.958548 -87.786919          CHICAGO     12
# 13173  41.958548 -87.786919              NaN      1
# 13102  41.956117 -87.679966          CHICAGO      4
# 13103  41.956117 -87.679966         WESTMONT      1
# 12531  41.948005 -87.664186          CHICAGO     23
# 12532  41.948005 -87.664186              NaN      4
# 9234   41.908254 -87.639863          CHICAGO      9
# 9233   41.908254 -87.639863  CHESTNUT STREET      8
# 8446   41.896318 -87.635840          CHICAGO     11
# 8447   41.896318 -87.635840              NaN      1
# 6366   41.877397 -87.635043          CHICAGO     11
# 6367   41.877397 -87.635043              NaN      2
# 5957   41.869170 -87.665384          CHICAGO     16
# 5958   41.869170 -87.665384              NaN      1
# 5796   41.865800 -87.676074          CHICAGO     14
# 5797   41.865800 -87.676074              NaN      2
# 5698   41.862628 -87.615031          CHICAGO    213
# 5699   41.862628 -87.615031              NaN      6
# 5119   41.851553 -87.715059          CHICAGO      2
# 5120   41.851553 -87.715059              NaN      2
# 5089   41.851047 -87.622093          CHICAGO     32
# 5090   41.851047 -87.622093              NaN      2
# 5082   41.850939 -87.632120          CHICAGO     29
# 5083   41.850939 -87.632120              NaN      2
# 4115   41.814266 -87.736013              NaN      3
# 4114   41.814266 -87.736013          CHICAGO      1
# 4036   41.810670 -87.743384          CHICAGO      5
# 4035   41.810670 -87.743384     BEDFORD PARK      2
# 3637   41.801540 -87.645197          CHICAGO     22
# 3638   41.801540 -87.645197              NaN      3
# 2691   41.778981 -87.695090          CHICAGO     28
# 2692   41.778981 -87.695090              NaN      8
# 2499   41.775402 -87.722822          CHICAGO      1
# 2500   41.775402 -87.722822              NaN      1
# 1991   41.760120 -87.644137          CHICAGO      5
# 1992   41.760120 -87.644137              NaN      5
# 1972   41.759579 -87.558917          CHICAGO      7
# 1973   41.759579 -87.558917              NaN      1
# 1718   41.751592 -87.568606          CHICAGO      9
# 1719   41.751592 -87.568606              NaN      1
# 1629   41.751030 -87.613649          CHICAGO      5
# 1630   41.751030 -87.613649              NaN      1
# 1426   41.746236 -87.643766              NaN     12
# 1425   41.746236 -87.643766          CHICAGO      1

# %% [markdown]
# **[cleaning]**
# Let's clean up the "city" column:
# - Infer and add back missing values: For locations that have a certain city and "NaN", we'll replace the "NaN" with the city.
# - For conflicting values: For locations that have multiple non-"NaN" cities, we'll choose the one with a higher count.

# %%
city_dedup = duplicated_city[~pd.isnull(duplicated_city['city'])].drop_duplicates(subset=['latitude', 'longitude']).drop(columns='count')
city_dedup
# Out:
#         latitude  longitude     city
# 15690  42.008536 -87.914428  CHICAGO
# 14419  41.975801 -87.713499  CHICAGO
# 14270  41.973068 -87.659926  CHICAGO
# 14215  41.971217 -87.659582  CHICAGO
# 14003  41.968491 -87.659816  CHICAGO
# 13670  41.965865 -87.693871  CHICAGO
# 13593  41.965212 -87.663260  CHICAGO
# 13270  41.960675 -87.729113  CHICAGO
# 13172  41.958548 -87.786919  CHICAGO
# 13102  41.956117 -87.679966  CHICAGO
# 12531  41.948005 -87.664186  CHICAGO
# 9234   41.908254 -87.639863  CHICAGO
# 8446   41.896318 -87.635840  CHICAGO
# 6366   41.877397 -87.635043  CHICAGO
# 5957   41.869170 -87.665384  CHICAGO
# 5796   41.865800 -87.676074  CHICAGO
# 5698   41.862628 -87.615031  CHICAGO
# 5119   41.851553 -87.715059  CHICAGO
# 5089   41.851047 -87.622093  CHICAGO
# 5082   41.850939 -87.632120  CHICAGO
# 4114   41.814266 -87.736013  CHICAGO
# 4036   41.810670 -87.743384  CHICAGO
# 3637   41.801540 -87.645197  CHICAGO
# 2691   41.778981 -87.695090  CHICAGO
# 2499   41.775402 -87.722822  CHICAGO
# 1991   41.760120 -87.644137  CHICAGO
# 1972   41.759579 -87.558917  CHICAGO
# 1718   41.751592 -87.568606  CHICAGO
# 1629   41.751030 -87.613649  CHICAGO
# 1425   41.746236 -87.643766  CHICAGO

# %%
cities_to_check, la_to_check, lo_to_check = list(set(duplicated_city['city'])), list(set(duplicated_city['latitude'])), list(set(duplicated_city['longitude']))

def clean_city(x):
    city, la, lo = x['city'], x['latitude'], x['longitude']
    if (pd.isnull(city) or (city in cities_to_check)) and (la in la_to_check) and (lo in lo_to_check):
        temp = city_dedup[(city_dedup['latitude']==la) & (city_dedup['longitude']==lo)]
        if len(temp) == 1:
            city = temp['city'].values[0]

    return city
        
input_data['city'] = input_data.apply(clean_city, axis=1)
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153805                       TROQUET    1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153807                      CAFE 608    2013328     restaurant
# 153808                     MRDANIELS    1899292     restaurant
# 153809                    TEMPO CAFE      80916     restaurant
#
#                    risk                     address     city state    zip  \
# 0         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)           1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)            301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)         2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                         ...      ...   ...    ...
# 153805    Risk 1 (High)         1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)  100 W RANDOLPH ST STE C-19  CHICAGO    IL  60601
# 153807    Risk 1 (High)             608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)          5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)             6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data.groupby(by=['latitude', 'longitude', 'city'], dropna=False).size().rename('count').reset_index()
temp.groupby(by=['latitude', 'longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['latitude', 'longitude', 'count'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [latitude, longitude, city, count]
# Index: []

# %% [markdown]
# **[exploaration]**
# Further check the "zip" information:

# %%
temp = input_data.groupby(by=['latitude', 'longitude', 'zip'], dropna=False).size().rename('count').reset_index()
duplicated_zip = temp.groupby(by=['latitude', 'longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['latitude', 'longitude', 'count'], ascending=False)
duplicated_zip
# Out:
#         latitude  longitude    zip  count
# 15719  42.008536 -87.914428  60666   1881
# 15718  42.008536 -87.914428  60606      3
# 14556  41.977421 -87.654869  60613      1
# 14557  41.977421 -87.654869  60640      1
# 14446  41.975801 -87.713499  60625     11
# ...          ...        ...    ...    ...
# 1719   41.751592 -87.568606    NaN      1
# 1629   41.751030 -87.613649  60619      5
# 1630   41.751030 -87.613649    NaN      1
# 7      41.648818 -87.617080  60827      2
# 6      41.648818 -87.617080  60627      1
#
# [116 rows x 4 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(duplicated_zip)
# Out:
#         latitude  longitude    zip  count
# 15719  42.008536 -87.914428  60666   1881
# 15718  42.008536 -87.914428  60606      3
# 14556  41.977421 -87.654869  60613      1
# 14557  41.977421 -87.654869  60640      1
# 14446  41.975801 -87.713499  60625     11
# 14447  41.975801 -87.713499    NaN      1
# 14243  41.971217 -87.659582  60640      4
# 14244  41.971217 -87.659582    NaN      1
# 14031  41.968491 -87.659816  60640      6
# 14032  41.968491 -87.659816    NaN      2
# 13699  41.965865 -87.693871    NaN      4
# 13698  41.965865 -87.693871  60625      2
# 13621  41.965212 -87.663260  60640     13
# 13622  41.965212 -87.663260    NaN      5
# 13201  41.958548 -87.786919  60634     12
# 13202  41.958548 -87.786919    NaN      1
# 13132  41.956117 -87.679966  60618      4
# 13131  41.956117 -87.679966  60559      1
# 12560  41.948005 -87.664186  60613     23
# 12561  41.948005 -87.664186    NaN      4
# 9642   41.910729 -87.653153  60642     15
# 9641   41.910729 -87.653153  60622     12
# 9229   41.907425 -87.673074  60622      6
# 9230   41.907425 -87.673074  60642      6
# 9223   41.907260 -87.656804  60622      2
# 9224   41.907260 -87.656804  60642      2
# 9189   41.906543 -87.671693  60642      3
# 9188   41.906543 -87.671693  60622      2
# 9048   41.903725 -87.662474  60642      9
# 9047   41.903725 -87.662474  60622      1
# 9045   41.903668 -87.653699  60642      5
# 9044   41.903668 -87.653699  60622      3
# 9041   41.903590 -87.659213  60642      6
# 9040   41.903590 -87.659213  60622      2
# 9006   41.903308 -87.666632  60642      3
# 9005   41.903308 -87.666632  60622      1
# 8632   41.898965 -87.648090  60642     75
# 8631   41.898965 -87.648090  60622      1
# 8514   41.896737 -87.631834  60654     15
# 8513   41.896737 -87.631834  60610      3
# 8507   41.896698 -87.635359  60654     17
# 8506   41.896698 -87.635359  60610      2
# 8504   41.896696 -87.635545  60610      5
# 8505   41.896696 -87.635545  60654      5
# 8490   41.896585 -87.642996  60654     69
# 8489   41.896585 -87.642996  60610      1
# 8467   41.896347 -87.631094  60654     10
# 8466   41.896347 -87.631094  60610      1
# 8462   41.896318 -87.635840  60654     11
# 8463   41.896318 -87.635840    NaN      1
# 8108   41.894009 -87.629863  60610      6
# 8109   41.894009 -87.629863  60654      6
# 8097   41.893840 -87.637248  60654     16
# 8096   41.893840 -87.637248  60610      1
# 8028   41.893229 -87.639305  60654      9
# 8027   41.893229 -87.639305  60610      6
# 8016   41.893148 -87.629029  60654      3
# 8015   41.893148 -87.629029  60610      1
# 7899   41.891773 -87.633927  60610      2
# 7900   41.891773 -87.633927  60654      1
# 7873   41.891601 -87.629797  60654     18
# 7872   41.891601 -87.629797  60610      1
# 7855   41.891388 -87.629495  60654     11
# 7854   41.891388 -87.629495  60610      2
# 7842   41.891207 -87.655872  60642     17
# 7841   41.891207 -87.655872  60622      2
# 7776   41.890915 -87.662563  60642      5
# 7775   41.890915 -87.662563  60622      1
# 7755   41.890729 -87.629386  60654      9
# 7754   41.890729 -87.629386  60610      1
# 7750   41.890685 -87.627885  60654      9
# 7749   41.890685 -87.627885  60610      1
# 7721   41.890208 -87.630941  60654     23
# 7720   41.890208 -87.630941  60610      7
# 7716   41.890171 -87.628244  60654     20
# 7715   41.890171 -87.628244  60610      1
# 7679   41.889921 -87.630298  60654     10
# 7678   41.889921 -87.630298  60610      1
# 7675   41.889904 -87.631592  60654     10
# 7674   41.889904 -87.631592  60610      2
# 7668   41.889833 -87.631223  60654     13
# 7667   41.889833 -87.631223  60610      1
# 7660   41.889760 -87.631221  60610      3
# 7661   41.889760 -87.631221  60654      2
# 7629   41.889225 -87.632674  60654     12
# 7628   41.889225 -87.632674  60610      2
# 7596   41.888633 -87.632363  60654      7
# 7595   41.888633 -87.632363  60610      1
# 7593   41.888628 -87.628190  60610      1
# 7594   41.888628 -87.628190  60654      1
# 7590   41.888582 -87.629417  60610     11
# 7591   41.888582 -87.629417  60654      3
# 6361   41.877397 -87.635043  60606     11
# 6362   41.877397 -87.635043    NaN      2
# 5792   41.865800 -87.676074  60608     14
# 5793   41.865800 -87.676074    NaN      2
# 5694   41.862628 -87.615031  60605    213
# 5695   41.862628 -87.615031    NaN      6
# 5519   41.857806 -87.673279  60608      6
# 5520   41.857806 -87.673279  60618      1
# 5114   41.851553 -87.715059  60623      2
# 5115   41.851553 -87.715059    NaN      2
# 5084   41.851047 -87.622093  60616     32
# 5085   41.851047 -87.622093    NaN      2
# 4437   41.830792 -87.650822  60608      4
# 4438   41.830792 -87.650822  60609      2
# 4007   41.809773 -87.594961  60653     16
# 4006   41.809773 -87.594961  60615      1
# 2497   41.775402 -87.722822  60629      1
# 2498   41.775402 -87.722822    NaN      1
# 1718   41.751592 -87.568606  60649      9
# 1719   41.751592 -87.568606    NaN      1
# 1629   41.751030 -87.613649  60619      5
# 1630   41.751030 -87.613649    NaN      1
# 7      41.648818 -87.617080  60827      2
# 6      41.648818 -87.617080  60627      1

# %% [markdown]
# **[cleaning]**
# Let's clean up the "zip" column:
# - Infer and add back missing values: For locations that have a certain zip and "NaN", we'll replace the "NaN" with the zip.
# - For conflicting values: For locations that have multiple non-"NaN" zip values, we'll choose the one with a higher count.

# %%
zip_dedup = duplicated_zip[~pd.isnull(duplicated_zip['zip'])].drop_duplicates(subset=['latitude', 'longitude']).drop(columns='count')
zip_dedup
# Out:
#         latitude  longitude    zip
# 15719  42.008536 -87.914428  60666
# 14556  41.977421 -87.654869  60613
# 14446  41.975801 -87.713499  60625
# 14243  41.971217 -87.659582  60640
# 14031  41.968491 -87.659816  60640
# 13698  41.965865 -87.693871  60625
# 13621  41.965212 -87.663260  60640
# 13201  41.958548 -87.786919  60634
# 13132  41.956117 -87.679966  60618
# 12560  41.948005 -87.664186  60613
# 9642   41.910729 -87.653153  60642
# 9229   41.907425 -87.673074  60622
# 9223   41.907260 -87.656804  60622
# 9189   41.906543 -87.671693  60642
# 9048   41.903725 -87.662474  60642
# 9045   41.903668 -87.653699  60642
# 9041   41.903590 -87.659213  60642
# 9006   41.903308 -87.666632  60642
# 8632   41.898965 -87.648090  60642
# 8514   41.896737 -87.631834  60654
# 8507   41.896698 -87.635359  60654
# 8504   41.896696 -87.635545  60610
# 8490   41.896585 -87.642996  60654
# 8467   41.896347 -87.631094  60654
# 8462   41.896318 -87.635840  60654
# 8108   41.894009 -87.629863  60610
# 8097   41.893840 -87.637248  60654
# 8028   41.893229 -87.639305  60654
# 8016   41.893148 -87.629029  60654
# 7899   41.891773 -87.633927  60610
# 7873   41.891601 -87.629797  60654
# 7855   41.891388 -87.629495  60654
# 7842   41.891207 -87.655872  60642
# 7776   41.890915 -87.662563  60642
# 7755   41.890729 -87.629386  60654
# 7750   41.890685 -87.627885  60654
# 7721   41.890208 -87.630941  60654
# 7716   41.890171 -87.628244  60654
# 7679   41.889921 -87.630298  60654
# 7675   41.889904 -87.631592  60654
# 7668   41.889833 -87.631223  60654
# 7660   41.889760 -87.631221  60610
# 7629   41.889225 -87.632674  60654
# 7596   41.888633 -87.632363  60654
# 7593   41.888628 -87.628190  60610
# 7590   41.888582 -87.629417  60610
# 6361   41.877397 -87.635043  60606
# 5792   41.865800 -87.676074  60608
# 5694   41.862628 -87.615031  60605
# 5519   41.857806 -87.673279  60608
# 5114   41.851553 -87.715059  60623
# 5084   41.851047 -87.622093  60616
# 4437   41.830792 -87.650822  60608
# 4007   41.809773 -87.594961  60653
# 2497   41.775402 -87.722822  60629
# 1718   41.751592 -87.568606  60649
# 1629   41.751030 -87.613649  60619
# 7      41.648818 -87.617080  60827

# %%
zip_to_check, la_to_check, lo_to_check = list(set(duplicated_zip['zip'])), list(set(duplicated_zip['latitude'])), list(set(duplicated_zip['longitude']))

def clean_zip(x):
    zip_, la, lo = x['zip'], x['latitude'], x['longitude']
    if (pd.isnull(zip_) or (zip_ in zip_to_check)) and (la in la_to_check) and (lo in lo_to_check):
        temp = zip_dedup[(zip_dedup['latitude']==la) & (zip_dedup['longitude']==lo)]
        if len(temp) == 1:
            zip_ = temp['zip'].values[0]

    return zip_
        
input_data['zip'] = input_data.apply(clean_zip, axis=1)
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153805                       TROQUET    1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153807                      CAFE 608    2013328     restaurant
# 153808                     MRDANIELS    1899292     restaurant
# 153809                    TEMPO CAFE      80916     restaurant
#
#                    risk                     address     city state    zip  \
# 0         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)           1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)            301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)         2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                         ...      ...   ...    ...
# 153805    Risk 1 (High)         1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)  100 W RANDOLPH ST STE C-19  CHICAGO    IL  60601
# 153807    Risk 1 (High)             608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)          5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)             6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data.groupby(by=['latitude', 'longitude', 'zip'], dropna=False).size().rename('count').reset_index()
temp.groupby(by=['latitude', 'longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['latitude', 'longitude', 'count'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [latitude, longitude, zip, count]
# Index: []

# %% [markdown]
# **[exploaration]**
# Check whether a certain zip code always have the same set of city and state:

# %%
temp = input_data[~input_data['zip'].isnull()].groupby(by=['zip', 'state', 'city'], dropna=False).size().rename('count').reset_index()
duplicated_city_state = temp.groupby(by='zip', dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['zip', 'count'], ascending=False)
duplicated_city_state
# Out:
#       zip state             city  count
# 98  60655    IL          CHICAGO    652
# 97  60655    IL            ALSIP      1
# 91  60649    IL          CHICAGO   1920
# 90  60649    IL  CHARLES A HAYES      6
# 92  60649    IL              NaN      2
# 87  60646    IL          CHICAGO   1143
# 88  60646    IL              NaN      4
# 84  60644    IL          CHICAGO   1967
# 85  60644    IL              NaN      2
# 80  60642    IL          CHICAGO   1712
# 82  60642   NaN              NaN      5
# 81  60642   NaN          CHICAGO      3
# 76  60639    IL          CHICAGO   3987
# 77  60639    IL              NaN      3
# 71  60633    IL          CHICAGO    281
# 70  60633    IL          BURNHAM      1
# 58  60622    IL          CHICAGO   4824
# 59  60622    IL              NaN      5
# 53  60618    IL          CHICAGO   4807
# 54  60618    IL              NaN      2
# 48  60614    IL          CHICAGO   5595
# 49  60614    IL              NaN      3
# 28  60461    IL   OLYMPIA FIELDS      1
# 29  60461    IL  OOLYMPIA FIELDS      1

# %% [markdown]
# **[cleaning]**
# Let's further clean up the "state" and "city" columns according to the "zip" column:
# - All of these zip codes have non-"NaN" state or city values, we'll just trust the one with the highest count.

# %%
city_state_dedup = duplicated_city_state.drop_duplicates(subset=['zip']).drop(columns='count')
city_state_dedup
# Out:
#       zip state            city
# 98  60655    IL         CHICAGO
# 91  60649    IL         CHICAGO
# 87  60646    IL         CHICAGO
# 84  60644    IL         CHICAGO
# 80  60642    IL         CHICAGO
# 76  60639    IL         CHICAGO
# 71  60633    IL         CHICAGO
# 58  60622    IL         CHICAGO
# 53  60618    IL         CHICAGO
# 48  60614    IL         CHICAGO
# 28  60461    IL  OLYMPIA FIELDS

# %%
zip_to_check_2 = list(city_state_dedup['zip'])

def clean_city_state(x):
    zip_, city, state = x['zip'], x['city'], x['state']
    if zip_ in zip_to_check_2:
        temp = city_state_dedup[city_state_dedup['zip']==zip_]
        if len(temp) == 1:
            city = temp['city'].values[0]
            state = temp['state'].values[0]

    return city, state
        
input_data[['city', 'state']] = input_data.apply(clean_city_state, axis=1, result_type="expand")
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153805                       TROQUET    1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153807                      CAFE 608    2013328     restaurant
# 153808                     MRDANIELS    1899292     restaurant
# 153809                    TEMPO CAFE      80916     restaurant
#
#                    risk                     address     city state    zip  \
# 0         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)           1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)            301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)         2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                         ...      ...   ...    ...
# 153805    Risk 1 (High)         1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)  100 W RANDOLPH ST STE C-19  CHICAGO    IL  60601
# 153807    Risk 1 (High)             608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)          5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)             6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data[~input_data['zip'].isnull()].groupby(by=['zip', 'state', 'city'], dropna=False).size().rename('count').reset_index()
temp.groupby(by='zip', dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by=['zip', 'count'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [zip, state, city, count]
# Index: []

# %% [markdown]
# ## 1.4 Clean up conflicting risk information

# %% [markdown]
# **[exploration]**
# Check the risk column:
# For the same facility, do they have conflicting risk status?
# Note that it is possible the risk level could change by time. I checked and confirmed that even on the same date, most of the following records still have conflicting risk status.

# %%
temp = input_data[['license_id', 'name_dba', 'name_aka', 'address', 'risk']].drop_duplicates()
duplicated_risk = temp[temp.duplicated(subset=['license_id', 'name_dba', 'name_aka', 'address'], keep=False)].sort_values(by='license_id')
duplicated_risk
# Out:
#        license_id                    name_dba                    name_aka  \
# 127712          0              FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 127627          0              FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 35736     1578736    MT ARARAT DAYCARE CENTER    MT ARARAT DAYCARE CENTER
# 35751     1578736    MT ARARAT DAYCARE CENTER    MT ARARAT DAYCARE CENTER
# 85087     1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 33799     1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 131692    1739775     ROTISSERIE ENT & ANNETS     ROTISSERIE ENT & ANNETS
# 131690    1739775     ROTISSERIE ENT & ANNETS     ROTISSERIE ENT & ANNETS
# 115550    1947909                      SUBWAY                      SUBWAY
# 2313      1947909                      SUBWAY                      SUBWAY
# 80180     1954774        WELLS STREET POPCORN        WELLS STREET POPCORN
# 80181     1954774        WELLS STREET POPCORN        WELLS STREET POPCORN
# 87109     1974918                ATINOS PIZZA                ATINOS PIZZA
# 87107     1974918                ATINOS PIZZA                ATINOS PIZZA
# 69370     2013962             KENDALL COLLEGE     LAB KITCHEN B-ROOM 120B
# 84339     2013962             KENDALL COLLEGE     LAB KITCHEN B-ROOM 120B
# 145952    2031677                 PORK SHOPPE                 PORK SHOPPE
# 145463    2031677                 PORK SHOPPE                 PORK SHOPPE
# 140399    2032230               MORE CUPCAKES               MORE CUPCAKES
# 108154    2032230               MORE CUPCAKES               MORE CUPCAKES
# 145260    2041764     TAMMYS SWICHES & SALADS       TAMMYS SWICH & SALADS
# 144874    2041764     TAMMYS SWICHES & SALADS       TAMMYS SWICH & SALADS
# 136375    2069823                BOOST MOBILE                BOOST MOBILE
# 136112    2069823                BOOST MOBILE                BOOST MOBILE
# 134516    2073639                THE SOUTHERN                THE SOUTHERN
# 100153    2073639                THE SOUTHERN                THE SOUTHERN
# 81071     2098831                 TRENCHERMEN                 TRENCHERMEN
# 109207    2098831                 TRENCHERMEN                 TRENCHERMEN
# 121526    2113684                     WOW BAO                     WOW BAO
# 122235    2113684                     WOW BAO                     WOW BAO
# 111465    2152257                   TACO BELL                   TACO BELL
# 53947     2152257                   TACO BELL                   TACO BELL
# 87760     2240275             PARTS AND LABOR             PARTS AND LABOR
# 79447     2240275             PARTS AND LABOR             PARTS AND LABOR
# 52251     2278041               COBBLERS CAFE                         NaN
# 86762     2278041               COBBLERS CAFE                         NaN
# 47286     2321266               ROSATIS PIZZA               ROSATIS PIZZA
# 69730     2321266               ROSATIS PIZZA               ROSATIS PIZZA
# 6180      2333150            GREENLINE COFFEE            GREENLINE COFFEE
# 69712     2333150            GREENLINE COFFEE            GREENLINE COFFEE
# 54179     2368585         VIA LIMA RESTAURANT         VIA LIMA RESTAURANT
# 50857     2368585         VIA LIMA RESTAURANT         VIA LIMA RESTAURANT
# 9226      2510999                     EVELYNS                     EVELYNS
# 4958      2510999                     EVELYNS                     EVELYNS
# 4213      2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
# 3143      2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                         address             risk
# 127712          600 E GRAND AVE     Risk 3 (Low)
# 127627          600 E GRAND AVE  Risk 2 (Medium)
# 35736   6514-6516 W HIGGINS AVE    Risk 1 (High)
# 35751   6514-6516 W HIGGINS AVE     Risk 3 (Low)
# 85087      5605-5609 N CLARK ST     Risk 3 (Low)
# 33799      5605-5609 N CLARK ST    Risk 1 (High)
# 131692        2009 N BISSELL ST  Risk 2 (Medium)
# 131690        2009 N BISSELL ST     Risk 3 (Low)
# 115550        6450 S PULASKI RD     Risk 3 (Low)
# 2313          6450 S PULASKI RD    Risk 1 (High)
# 80180           2804 N CLARK ST     Risk 3 (Low)
# 80181           2804 N CLARK ST  Risk 2 (Medium)
# 87109      4610A W DIVERSEY AVE    Risk 1 (High)
# 87107      4610A W DIVERSEY AVE     Risk 3 (Low)
# 69370     900 N NORTH BRANCH ST     Risk 3 (Low)
# 84339     900 N NORTH BRANCH ST    Risk 1 (High)
# 145952       2755 W BELMONT AVE     Risk 3 (Low)
# 145463       2755 W BELMONT AVE    Risk 1 (High)
# 140399          1 E DELAWARE PL  Risk 2 (Medium)
# 108154          1 E DELAWARE PL     Risk 3 (Low)
# 145260      1854 W 18TH ST BLDG              NaN
# 144874      1854 W 18TH ST BLDG  Risk 2 (Medium)
# 136375       4731 S ASHLAND AVE              NaN
# 136112       4731 S ASHLAND AVE     Risk 3 (Low)
# 134516    1840-1842 W NORTH AVE    Risk 1 (High)
# 100153    1840-1842 W NORTH AVE  Risk 2 (Medium)
# 81071     2039-2041 W NORTH AVE    Risk 1 (High)
# 109207    2039-2041 W NORTH AVE     Risk 3 (Low)
# 121526       175 W JACKSON BLVD     Risk 3 (Low)
# 122235       175 W JACKSON BLVD    Risk 1 (High)
# 111465      1646-1648 W 95TH ST  Risk 2 (Medium)
# 53947       1646-1648 W 95TH ST    Risk 1 (High)
# 87760      2700 N MILWAUKEE AVE     Risk 3 (Low)
# 79447      2700 N MILWAUKEE AVE    Risk 1 (High)
# 52251        7036 S WESTERN AVE  Risk 2 (Medium)
# 86762        7036 S WESTERN AVE              NaN
# 47286           4863 N BROADWAY     Risk 3 (Low)
# 69730           4863 N BROADWAY    Risk 1 (High)
# 6180              501 E 61ST ST  Risk 2 (Medium)
# 69712             501 E 61ST ST              NaN
# 54179        4024 N LINCOLN AVE              NaN
# 50857        4024 N LINCOLN AVE    Risk 1 (High)
# 9226            5522 S STATE ST              NaN
# 4958            5522 S STATE ST    Risk 1 (High)
# 4213           500 W MADISON ST              All
# 3143           500 W MADISON ST  Risk 2 (Medium)

# %% [markdown]
# **[cleaning]**
# Let's clean up the "risk" column for these situations:
# - Infer and add back missing values: For facilities that have a certain level and "NaN", we'll replace the "NaN" with the risk level.
# - Make conflicting values invalid: For facilities that have multiple non-"NaN" levels, we'll replace all of them with "NaN".

# %%
def combine_risk(x):
    non_nan_risks = list(set(x) - set([np.nan]))
    return non_nan_risks[0] if len(non_nan_risks) == 1 else np.nan

risk_dedup = duplicated_risk.groupby(by=['license_id', 'name_dba', 'name_aka', 'address'], dropna=False)['risk'].agg(combine_risk).rename('risk').reset_index()
risk_dedup
# Out:
#    license_id                    name_dba                    name_aka  \
# 0           0              FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 1     1578736    MT ARARAT DAYCARE CENTER    MT ARARAT DAYCARE CENTER
# 2     1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 3     1739775     ROTISSERIE ENT & ANNETS     ROTISSERIE ENT & ANNETS
# 4     1947909                      SUBWAY                      SUBWAY
# 5     1954774        WELLS STREET POPCORN        WELLS STREET POPCORN
# 6     1974918                ATINOS PIZZA                ATINOS PIZZA
# 7     2013962             KENDALL COLLEGE     LAB KITCHEN B-ROOM 120B
# 8     2031677                 PORK SHOPPE                 PORK SHOPPE
# 9     2032230               MORE CUPCAKES               MORE CUPCAKES
# 10    2041764     TAMMYS SWICHES & SALADS       TAMMYS SWICH & SALADS
# 11    2069823                BOOST MOBILE                BOOST MOBILE
# 12    2073639                THE SOUTHERN                THE SOUTHERN
# 13    2098831                 TRENCHERMEN                 TRENCHERMEN
# 14    2113684                     WOW BAO                     WOW BAO
# 15    2152257                   TACO BELL                   TACO BELL
# 16    2240275             PARTS AND LABOR             PARTS AND LABOR
# 17    2278041               COBBLERS CAFE                         NaN
# 18    2321266               ROSATIS PIZZA               ROSATIS PIZZA
# 19    2333150            GREENLINE COFFEE            GREENLINE COFFEE
# 20    2368585         VIA LIMA RESTAURANT         VIA LIMA RESTAURANT
# 21    2510999                     EVELYNS                     EVELYNS
# 22    2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                     address             risk
# 0           600 E GRAND AVE              NaN
# 1   6514-6516 W HIGGINS AVE              NaN
# 2      5605-5609 N CLARK ST              NaN
# 3         2009 N BISSELL ST              NaN
# 4         6450 S PULASKI RD              NaN
# 5           2804 N CLARK ST              NaN
# 6      4610A W DIVERSEY AVE              NaN
# 7     900 N NORTH BRANCH ST              NaN
# 8        2755 W BELMONT AVE              NaN
# 9           1 E DELAWARE PL              NaN
# 10      1854 W 18TH ST BLDG  Risk 2 (Medium)
# 11       4731 S ASHLAND AVE     Risk 3 (Low)
# 12    1840-1842 W NORTH AVE              NaN
# 13    2039-2041 W NORTH AVE              NaN
# 14       175 W JACKSON BLVD              NaN
# 15      1646-1648 W 95TH ST              NaN
# 16     2700 N MILWAUKEE AVE              NaN
# 17       7036 S WESTERN AVE  Risk 2 (Medium)
# 18          4863 N BROADWAY              NaN
# 19            501 E 61ST ST  Risk 2 (Medium)
# 20       4024 N LINCOLN AVE    Risk 1 (High)
# 21          5522 S STATE ST    Risk 1 (High)
# 22         500 W MADISON ST              NaN

# %%
license_to_check, dba_to_check, address_to_check = list(risk_dedup['license_id']), list(risk_dedup['name_dba']), list(risk_dedup['address'])

def clean_risk(x):
    license, dba, aka, address, risk = x['license_id'], x['name_dba'], x['name_aka'], x['address'], x['risk']
    if (license in license_to_check) and (dba in dba_to_check) and (address in address_to_check):
        temp = risk_dedup[(risk_dedup['license_id']==license) &
                     (risk_dedup['name_dba']==dba) &
                     (pd.isnull(risk_dedup['name_aka']) | (risk_dedup['name_aka']==aka)) &
                     (risk_dedup['address']==address)]
        if len(temp) == 1:
            risk = temp['risk'].values[0]

    return risk
        
input_data['risk'] = input_data.apply(clean_risk, axis=1)
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153805                       TROQUET    1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153807                      CAFE 608    2013328     restaurant
# 153808                     MRDANIELS    1899292     restaurant
# 153809                    TEMPO CAFE      80916     restaurant
#
#                    risk                     address     city state    zip  \
# 0         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)           1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)            301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)         2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                         ...      ...   ...    ...
# 153805    Risk 1 (High)         1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)  100 W RANDOLPH ST STE C-19  CHICAGO    IL  60601
# 153807    Risk 1 (High)             608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)          5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)             6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data[['license_id', 'name_dba', 'name_aka', 'address', 'risk']].drop_duplicates()
temp[temp.duplicated(subset=['license_id', 'name_dba', 'name_aka', 'address'], keep=False)].sort_values(by='license_id')
# Out:
# Empty DataFrame
# Columns: [license_id, name_dba, name_aka, address, risk]
# Index: []

# %% [markdown]
# ## 1.5 Initial cleanup of results and violations

# %% [markdown]
# **[exploration]**
# Check the results and violations columns:

# %%
input_data['results'].value_counts()
# Out:
# Pass                    90506
# Fail                    29845
# Pass w/ Conditions      14530
# Out of Business         13794
# No Entry                 4257
# Not Ready                 818
# Business Not Located       60
# Name: results, dtype: int64

# %%
conclusive_results = ['Pass', 'Fail', 'Pass w/ Conditions']
non_conclusive_results = ['Out of Business', 'No Entry', 'Not Ready', 'Business Not Located']

# %% [markdown]
# If the result is non-conclusive, then there shouldn't be violations information. But there are still such records:

# %%
input_data[input_data['results'].isin(non_conclusive_results) & (~input_data['violations'].isnull())]
# Out:
#        inspection_id                        name_dba  \
# 2            2079125                       ROOM 1520
# 11           2079076              THE ART OF CHICKEN
# 38           2079101                  THE PARTY ROOM
# 129          2078837                         SILOM12
# 316          2078880                 PARTS AND LABOR
# ...              ...                             ...
# 109860       1215137                      BUBS GYROS
# 115737        545787  HONEY BEAR NURSERY & KINDERGAR
# 117134        545725                  THE BURGER BAR
# 127908        517377                      KITH & KIN
# 135977        353252              JOY AND JAMES CAFE
#
#                               name_aka license_id  facility_type  \
# 2                            ROOM 1520    2446638  special event
# 11                  THE ART OF CHICKEN    2202818     restaurant
# 38                      THE PARTY ROOM    2534843       catering
# 129              SILOM12 THAI BUCKTOWN    2064938     restaurant
# 316                    PARTS AND LABOR    2240274     restaurant
# ...                                ...        ...            ...
# 109860                     BUBS  GYROS    2069295     restaurant
# 115737  HONEY BEAR NURSERY & KINDERGAR       5664        daycare
# 117134                  THE BURGER BAR    2064712     restaurant
# 127908             WEBSTER STREET CAFE    1799703     restaurant
# 135977             JOY  AND JAMES CAFE    1221335     restaurant
#
#                    risk                    address     city state    zip  \
# 2          Risk 3 (Low)           301 N JUSTINE ST  CHICAGO    IL  60607
# 11        Risk 1 (High)         2041 N WESTERN AVE  CHICAGO    IL  60647
# 38        Risk 1 (High)      10232 S VINCENNES AVE  CHICAGO    IL  60643
# 129       Risk 1 (High)  1846-1848 N MILWAUKEE AVE  CHICAGO    IL  60647
# 316       Risk 1 (High)       2700 N MILWAUKEE AVE  CHICAGO    IL  60647
# ...                 ...                        ...      ...   ...    ...
# 109860    Risk 1 (High)      5800 W IRVING PARK RD  CHICAGO    IL  60634
# 115737    Risk 1 (High)              419 W 95TH ST  CHICAGO    IL  60628
# 117134  Risk 2 (Medium)              622 E 71ST ST  CHICAGO    IL  60619
# 127908    Risk 1 (High)    1119-1121 W WEBSTER AVE  CHICAGO    IL  60614
# 135977    Risk 1 (High)        4701 W LAWRENCE AVE  CHICAGO    IL  60630
#
#        inspection_date          inspection_type          results  \
# 2           2017-08-28    license re-inspection        Not Ready
# 11          2017-08-25                complaint         No Entry
# 38          2017-08-25    license re-inspection        Not Ready
# 129         2017-08-22                  canvass         No Entry
# 316         2017-08-15                  canvass         No Entry
# ...                ...                      ...              ...
# 109860      2012-05-24  complaint re-inspection  Out of Business
# 115737      2012-01-31                  canvass  Out of Business
# 117134      2012-01-03  complaint re-inspection  Out of Business
# 127908      2011-06-01  complaint re-inspection  Out of Business
# 135977      2010-12-30                  canvass  Out of Business
#
#                                                violations   latitude  \
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 11      34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.918742
# 38      2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.707675
# 129     30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  41.914901
# 316     35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.930191
# ...                                                   ...        ...
# 109860  24. DISH WASHING FACILITIES: PROPERLY DESIGNED...  41.953228
# 115737  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.721474
# 117134  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.765919
# 127908  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921577
# 135977  41. PREMISES MAINTAINED FREE OF LITTER, UNNECE...  41.967944
#
#         longitude
# 2      -87.665328
# 11     -87.687301
# 38     -87.655848
# 129    -87.684667
# 316    -87.709475
# ...           ...
# 109860 -87.771956
# 115737 -87.634264
# 117134 -87.609521
# 127908 -87.656727
# 135977 -87.745328
#
# [363 rows x 16 columns]

# %% [markdown]
# **[cleaning]**
# Let's clean up these violations:

# %%
input_data['violations'] = input_data.apply(lambda x: np.nan if (x['results'] in non_conclusive_results) else x['violations'], axis=1)

# %% [markdown]
# Confirm the change:

# %%
input_data[input_data['results'].isin(non_conclusive_results) & (~input_data['violations'].isnull())]
# Out:
# Empty DataFrame
# Columns: [inspection_id, name_dba, name_aka, license_id, facility_type, risk, address, city, state, zip, inspection_date, inspection_type, results, violations, latitude, longitude]
# Index: []

# %% [markdown]
# ## 1.6 Inspection IDs and duplicated inspections

# %% [markdown]
# **[exploration]**
# Check that all inspection_ids are unique:

# %%
len(set(input_data['inspection_id'])) == len(list(input_data['inspection_id']))
# Out:
# True

# %% [markdown]
# **[exploration]**
# However, if we ignore the inspection_id, there seem to be duplicated records:

# %%
input_data[input_data[list(input_data)[1:]].duplicated(keep=False)]
# Out:
#        inspection_id                     name_dba  \
# 2084         2069297           PICOSITO GRILL-BAR
# 2138         2064677           PICOSITO GRILL-BAR
# 3648         2015324            METAL HAVEN GRILL
# 3694         2050813            METAL HAVEN GRILL
# 7507         2010211           LOOMIS FOOD MARKET
# ...              ...                          ...
# 152903         68271  DE ARCOS PIZZA & RESTAURANT
# 153108         88223                ASPIRA HAUGAN
# 153109         88222                ASPIRA HAUGAN
# 153113        158274              ARGENTINA FOODS
# 153114        158273              ARGENTINA FOODS
#
#                            name_aka license_id facility_type             risk  \
# 2084             PICOSITO GRILL-BAR    2158267    restaurant    Risk 1 (High)
# 2138             PICOSITO GRILL-BAR    2158267    restaurant    Risk 1 (High)
# 3648              METAL HAVEN GRILL    2457868    restaurant    Risk 1 (High)
# 3694              METAL HAVEN GRILL    2457868    restaurant    Risk 1 (High)
# 7507             LOOMIS FOOD MARKET    2004423       grocery  Risk 2 (Medium)
# ...                             ...        ...           ...              ...
# 152903  DE ARCOS PIZZA & RESTAURANT    1577283    restaurant    Risk 1 (High)
# 153108  ASPIRA HAUGAN MIDDLE SCHOOL      66351        school    Risk 1 (High)
# 153109  ASPIRA HAUGAN MIDDLE SCHOOL      66351        school    Risk 1 (High)
# 153113              ARGENTINA FOODS      57047       grocery  Risk 2 (Medium)
# 153114              ARGENTINA FOODS      57047       grocery  Risk 2 (Medium)
#
#                      address     city state    zip inspection_date  \
# 2084    3553-3559 E 100TH ST  CHICAGO    IL  60617      2017-06-21
# 2138    3553-3559 E 100TH ST  CHICAGO    IL  60617      2017-06-21
# 3648    3835 W FULLERTON AVE  CHICAGO    IL  60647      2017-05-22
# 3694    3835 W FULLERTON AVE  CHICAGO    IL  60647      2017-05-22
# 7507      6859 S LOOMIS BLVD  CHICAGO    IL  60636      2017-03-14
# ...                      ...      ...   ...    ...             ...
# 152903        2832 E 87TH ST  CHICAGO    IL  60617      2010-01-22
# 153108     3729 W LELAND AVE  CHICAGO    IL  60625      2010-01-20
# 153109     3729 W LELAND AVE  CHICAGO    IL  60625      2010-01-20
# 153113        4500 S WOOD ST  CHICAGO    IL  60609      2010-01-20
# 153114        4500 S WOOD ST  CHICAGO    IL  60609      2010-01-20
#
#         inspection_type          results violations   latitude  longitude
# 2084            canvass         No Entry        NaN  41.713767 -87.536796
# 2138            canvass         No Entry        NaN  41.713767 -87.536796
# 3648            canvass  Out of Business        NaN  41.924416 -87.723320
# 3694            canvass  Out of Business        NaN  41.924416 -87.723320
# 7507          complaint         No Entry        NaN  41.768716 -87.658922
# ...                 ...              ...        ...        ...        ...
# 152903      tag removal             Pass        NaN  41.737447 -87.555039
# 153108          canvass             Pass        NaN  41.966378 -87.721826
# 153109          canvass             Pass        NaN  41.966378 -87.721826
# 153113  out of business             Fail        NaN  41.812105 -87.670072
# 153114  out of business             Fail        NaN  41.812105 -87.670072
#
# [175 rows x 16 columns]

# %% [markdown]
# **[cleaning]**
# There are 175 records that contain duplicated information. For example, inspection #2069297 and #2064677 are exactly the same except for the inspection_id itself. For the purpose of our target use case, we don't need those repeated records, so we'll remove them:

# %%
input_data = input_data.drop_duplicates(subset=list(input_data)[1:], ignore_index=True)
input_data
# Out:
#        inspection_id                      name_dba  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153712         67732                      WOLCOTTS
# 153713         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153714         52234                      CAFE 608
# 153715         70269                     MRDANIELS
# 153716        104236                    TEMPO CAFE
#
#                             name_aka license_id  facility_type  \
# 0            MARRIOT MARQUIS CHICAGO    2517328     restaurant
# 1                         JETS PIZZA    2522268     restaurant
# 2                          ROOM 1520    2446638  special event
# 3            MARRIOT MARQUIS CHICAGO    2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS    2549079         school
# ...                              ...        ...            ...
# 153712                       TROQUET    1992039     restaurant
# 153713  DUNKIN DONUTS/BASKIN-ROBBINS    1380279     restaurant
# 153714                      CAFE 608    2013328     restaurant
# 153715                     MRDANIELS    1899292     restaurant
# 153716                    TEMPO CAFE      80916     restaurant
#
#                    risk                     address     city state    zip  \
# 0         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)           1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)            301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)          2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)         2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                         ...      ...   ...    ...
# 153712    Risk 1 (High)         1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153713  Risk 2 (Medium)  100 W RANDOLPH ST STE C-19  CHICAGO    IL  60601
# 153714    Risk 1 (High)             608 W BARRY AVE  CHICAGO    IL  60657
# 153715    Risk 1 (High)          5645 W BELMONT AVE  CHICAGO    IL  60634
# 153716    Risk 1 (High)             6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        inspection_date        inspection_type    results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153712      2010-01-04  license re-inspection       Pass
# 153713      2010-01-04            tag removal       Pass
# 153714      2010-01-04  license re-inspection       Pass
# 153715      2010-01-04  license re-inspection       Pass
# 153716      2010-01-04                canvass       Fail
#
#                                                violations   latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2                                                     NaN  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153712  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153713                                                NaN  41.884586
# 153714  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153715  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153716  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153712 -87.675967
# 153713 -87.631010
# 153714 -87.644755
# 153715 -87.768318
# 153716 -87.628009
#
# [153717 rows x 16 columns]

# %% [markdown]
# **[exploration]**

# %%
num_inspection = len(input_data)
print(f"How many inspection records are there in total? {num_inspection}")
num_license = len(set(input_data['license_id']))
print(f"How many unique license numbers are there? {num_license}")
num_facility = len(input_data[['license_id', 'name_dba', 'name_aka', 'facility_type', 'address']].drop_duplicates())
print(f"How many unique food facilities are there? {num_facility}")
num_dates = len(set(input_data['inspection_date']))
print(f"How many unique inspection dates are there? {num_dates}")
# Out:
# How many inspection records are there in total? 153717
# How many unique license numbers are there? 32851
# How many unique food facilities are there? 34037
# How many unique inspection dates are there? 1946

# %% [markdown]
# # 2. Try to better understand the data

# %% [markdown]
# ## 2.1 What defines a facility?

# %% [markdown]
# **[exploration]**
# ### 1. The same license_id can have multiple name_dba:

# %%
temp = input_data[(input_data['license_id']!='') & (input_data['license_id']!='nan') & (~pd.isnull(input_data['license_id']))][[
    'license_id', 'name_dba']].drop_duplicates()
temp[temp.duplicated(subset='license_id', keep=False)].sort_values(by='license_id')
# Out:
#        license_id               name_dba
# 108764          0      NORMAS MINI STORE
# 107063          0                  KENNY
# 135814          0      GRILL IN THE PARK
# 107553          0  BABYCAKES GOURMET LLC
# 135473          0  EDGEWATER FOOD PANTRY
# ...           ...                    ...
# 17349       87119             PUB ROYALE
# 19210        9648           CAFFE ITALIA
# 15801        9648               CAFE #10
# 134717        968           CAFE BERNARD
# 3618          968               CHEZ MOI
#
# [1265 rows x 2 columns]

# %% [markdown]
# ### 2. The same license_id can have multiple addresses:

# %%
temp = input_data[(input_data['license_id']!='') & (input_data['license_id']!='nan') & (~pd.isnull(input_data['license_id']))][[
    'license_id', 'address', 'city', 'state', 'zip', 'latitude','longitude']].drop_duplicates()
temp[temp.duplicated(subset='license_id', keep=False)].sort_values(by='license_id')
# Out:
#        license_id                 address     city state    zip   latitude  \
# 216             0      4225 N CENTRAL AVE  CHICAGO    IL  60634  41.957639
# 105890          0           512 E 71ST ST  CHICAGO    IL  60619  41.765871
# 18068           0        4807 N DAMEN AVE  CHICAGO    IL  60625  41.969019
# 105565          0              300 E 47TH  CHICAGO    IL  60653  41.809447
# 105170          0          2157 W 19TH ST  CHICAGO    IL  60608  41.855674
# ...           ...                     ...      ...   ...    ...        ...
# 3102        70217  2550 W 56TH (5600S) ST  CHICAGO    IL  60629  41.792067
# 9875        80130      179 W VAN BUREN ST  CHICAGO    IL  60605  41.876748
# 68628       80130      111 E WACKER DR FL  CHICAGO    IL  60601  41.888079
# 7126        81030   1461 E HYDE PARK BLVD  CHICAGO    IL  60615  41.802341
# 152077      81030   1453 E HYDE PARK BLVD  CHICAGO    IL  60615  41.802338
#
#         longitude
# 216    -87.767001
# 105890 -87.612286
# 18068  -87.679045
# 105565 -87.619524
# 105170 -87.680646
# ...           ...
# 3102   -87.688478
# 9875   -87.633286
# 68628  -87.624047
# 7126   -87.589372
# 152077 -87.589676
#
# [494 rows x 7 columns]

# %% [markdown]
# Note: even the same set of 'license_id', 'name_dba', 'name_aka', 'facility_type' can still have different address/latitude/longitude:

# %%
temp = input_data[(input_data['license_id']!='') & (input_data['license_id']!='nan') & (~pd.isnull(input_data['license_id']))][[
    'license_id', 'name_dba', 'name_aka', 'facility_type', 'address', 'city', 'state', 'zip', 'latitude','longitude']].drop_duplicates()
temp[temp.duplicated(subset=['license_id', 'name_dba', 'name_aka', 'facility_type'], keep=False)].sort_values(by='license_id')
# Out:
#        license_id                      name_dba                      name_aka  \
# 117243          0                       UNKNOWN                           NaN
# 136021          0                 DUNKIN DONUTS                           NaN
# 105565          0                       UNKNOWN                           NaN
# 56841           0                   HERBAL LIFE                   HERBAL LIFE
# 18068           0                   HERBAL LIFE                   HERBAL LIFE
# 122919          0                       UNKNOWN                           NaN
# 124607          0                 DUNKIN DONUTS                           NaN
# 3425      1142125   POTBELLY SANDWICH WORKS LLC   POTBELLY SANDWICH WORKS LLC
# 77705     1142125   POTBELLY SANDWICH WORKS LLC   POTBELLY SANDWICH WORKS LLC
# 3196        13976                  ALDI INC #64                  ALDI INC #64
# 3210        13976                  ALDI INC #64                  ALDI INC #64
# 106612    1476455          THUNDERBIRD CATERING          THUNDERBIRD CATERING
# 108307    1476455          THUNDERBIRD CATERING          THUNDERBIRD CATERING
# 3243      1743553       STARBUCKS COFFEE #10957       STARBUCKS COFFEE #10957
# 120570    1743553       STARBUCKS COFFEE #10957       STARBUCKS COFFEE #10957
# 98419     1888650                   TASTY PLACE                   TASTY PLACE
# 7737      1888650                   TASTY PLACE                   TASTY PLACE
# 7610      1937822       POTBELLY SANDWICH WORKS                      POTBELLY
# 28096     1937822       POTBELLY SANDWICH WORKS                      POTBELLY
# 85779     1985290            LESLIES PIZZA CORP            LESLIES PIZZA CORP
# 70015     1985290            LESLIES PIZZA CORP            LESLIES PIZZA CORP
# 96129     2003503                III FORKS #425                     III FORKS
# 4100      2003503                III FORKS #425                     III FORKS
# 13944     2003567    LEONIDAS CAFE CHOCOLATERIE    LEONIDAS CAFE CHOCOLATERIE
# 149758    2003567    LEONIDAS CAFE CHOCOLATERIE    LEONIDAS CAFE CHOCOLATERIE
# 153100    2008948         MICHAELS ON MAIN CAFE         MICHAELS ON MAIN CAFE
# 8746      2008948         MICHAELS ON MAIN CAFE         MICHAELS ON MAIN CAFE
# 36174     2088918          HAREER FOOD & LIQUOR          HAREER FOOD & LIQUOR
# 88808     2088918          HAREER FOOD & LIQUOR          HAREER FOOD & LIQUOR
# 10540     2146635                           KFC                           KFC
# 112092    2146635                           KFC                           KFC
# 22264     2177122       ALI BABA FISH & CHICKEN       ALI BABA FISH & CHICKEN
# 36031     2177122       ALI BABA FISH & CHICKEN       ALI BABA FISH & CHICKEN
# 64149     2290163                 HAUTE SAUSAGE                 HAUTE SAUSAGE
# 18251     2290163                 HAUTE SAUSAGE                 HAUTE SAUSAGE
# 54553     2373706              TACO BELL #27900                     TACO BELL
# 8627      2373706              TACO BELL #27900                     TACO BELL
# 25052     2423147                       LA JEFA                       LA JEFA
# 34363     2423147                       LA JEFA                       LA JEFA
# 17696     2423842                    BOB CHA II                    BOB CHA II
# 17665     2423842                    BOB CHA II                    BOB CHA II
# 28429     2442868    EAT N RUN CHICKEN AND FISH    EAT N RUN CHICKEN AND FISH
# 18906     2442868    EAT N RUN CHICKEN AND FISH    EAT N RUN CHICKEN AND FISH
# 18079     2492018            REAL GOOD JUICE CO            REAL GOOD JUICE CO
# 18059     2492018            REAL GOOD JUICE CO            REAL GOOD JUICE CO
# 2277      2535189                         CITGO                         CITGO
# 1439      2535189                         CITGO                         CITGO
# 9875        80130  TOKYO LUNCH BOXES & CATERING  TOKYO LUNCH BOXES & CATERING
# 68628       80130  TOKYO LUNCH BOXES & CATERING  TOKYO LUNCH BOXES & CATERING
#
#                facility_type                 address     city state    zip  \
# 117243                   NaN   8090 S COMMERCIAL AVE  CHICAGO    IL  60617
# 136021                   NaN     2640 W DIVERSEY AVE  CHICAGO    IL  60647
# 105565                   NaN              300 E 47TH  CHICAGO    IL  60653
# 56841                 herbal     1854 W 18TH ST BLDG  CHICAGO    IL  60608
# 18068                 herbal        4807 N DAMEN AVE  CHICAGO    IL  60625
# 122919                   NaN   10222 S WENTWORTH AVE  CHICAGO    IL  60628
# 124607                   NaN     8700 S EXCHANGE AVE  CHICAGO    IL  60617
# 3425              restaurant       5700 S CICERO AVE  CHICAGO    IL  60638
# 77705             restaurant       5800 S CICERO AVE  CHICAGO    IL  60638
# 3196                 grocery    1753 N MILWAUKEE AVE  CHICAGO    IL  60647
# 3210                 grocery    1767 N MILWAUKEE AVE  CHICAGO    IL  60647
# 106612  mobile food preparer          1204 W 36TH PL  CHICAGO    IL  60609
# 108307  mobile food preparer            1204 W 35 ST  CHICAGO    IL  60609
# 3243              restaurant       150 E RANDOLPH ST  CHICAGO    IL  60601
# 120570            restaurant      150 N MICHIGAN AVE  CHICAGO    IL  60601
# 98419                 bakery         2101 S CHINA PL  CHICAGO    IL  60616
# 7737                  bakery    2339 S WENTWORTH AVE  CHICAGO    IL  60616
# 7610              restaurant       2739 N ELSTON AVE  CHICAGO    IL  60647
# 28096             restaurant       2717 N ELSTON AVE  CHICAGO    IL  60647
# 85779             restaurant     3107 S 71ST ST BSMT  CHICAGO    IL  60629
# 70015             restaurant          3107 W 71ST ST  CHICAGO    IL  60629
# 96129             restaurant         333 E BENTON PL  CHICAGO    IL  60601
# 4100              restaurant        180 N FIELD BLVD  CHICAGO    IL  60601
# 13944             restaurant        59 E CHICAGO AVE  CHICAGO    IL  60611
# 149758            restaurant           750 N RUSH ST  CHICAGO    IL  60611
# 153100            restaurant    8750 W BRYN WAWR AVE  CHICAGO    IL  60631
# 8746              restaurant    8750 W BRYN MAWR AVE  CHICAGO    IL  60631
# 36174                grocery  5450-5452 S HALSTED ST  CHICAGO    IL  60609
# 88808                grocery       5452 S HALSTED ST  CHICAGO    IL  60609
# 10540             restaurant       3927 N HARLEM AVE  CHICAGO    IL  60634
# 112092            restaurant       3937 N HARLEM AVE  CHICAGO    IL  60634
# 22264             restaurant   8950-58 S ASHLAND AVE  CHICAGO    IL  60620
# 36031             restaurant      8958 S ASHLAND AVE  CHICAGO    IL  60620
# 64149             restaurant       335 S FRANKLIN ST  CHICAGO    IL  60606
# 18251             restaurant       337 S FRANKLIN ST  CHICAGO    IL  60606
# 54553             restaurant     1646-1648 W 95TH ST  CHICAGO    IL  60643
# 8627              restaurant          1644 W 95TH ST  CHICAGO    IL  60643
# 25052   mobile food preparer    324 N LEAVITT STE 1S  CHICAGO    IL  60612
# 34363   mobile food preparer     2637 S THROOP ST FL  CHICAGO    IL  60608
# 17696   mobile food preparer        2300 S THROOP ST  CHICAGO    IL  60608
# 17665   mobile food preparer    324 N LEAVITT STE 1S  CHICAGO    IL  60612
# 28429             restaurant                              NaN    IL    NaN
# 18906             restaurant      8233 S ASHLAND AVE  CHICAGO    IL  60620
# 18079             restaurant        2031 W FULTON ST  CHICAGO    IL  60612
# 18059             restaurant         320 N DAMEN AVE  CHICAGO    IL  60612
# 2277                 grocery  4601-4615 N PULASKI RD  CHICAGO    IL  60630
# 1439                 grocery       4603 N PULASKI RD  CHICAGO    IL  60630
# 9875              restaurant      179 W VAN BUREN ST  CHICAGO    IL  60605
# 68628             restaurant      111 E WACKER DR FL  CHICAGO    IL  60601
#
#          latitude  longitude
# 117243        NaN        NaN
# 136021  41.932226 -87.694274
# 105565  41.809447 -87.619524
# 56841   41.857806 -87.673279
# 18068   41.969019 -87.679045
# 122919  41.708213 -87.628492
# 124607  41.737270 -87.552955
# 3425    41.789329 -87.741646
# 77705   41.787652 -87.741560
# 3196    41.913342 -87.681822
# 3210    41.913588 -87.682203
# 106612  41.828094 -87.655854
# 108307  41.830726 -87.656012
# 3243    41.884628 -87.622613
# 120570  41.884531 -87.624602
# 98419   41.854105 -87.634059
# 7737    41.849788 -87.631797
# 7610    41.931426 -87.686504
# 28096   41.930936 -87.685792
# 85779         NaN        NaN
# 70015   41.764300 -87.700699
# 96129   41.885390 -87.618987
# 4100    41.885504 -87.617551
# 13944   41.896600 -87.625913
# 149758  41.896455 -87.625645
# 153100        NaN        NaN
# 8746    41.981063 -87.845674
# 36174   41.794613 -87.645315
# 88808   41.794559 -87.645313
# 10540   41.951606 -87.807079
# 112092  41.951879 -87.807089
# 22264   41.730593 -87.663058
# 36031   41.730381 -87.663052
# 64149   41.877259 -87.635041
# 18251   41.877213 -87.635041
# 54553   41.721299 -87.664470
# 8627    41.721300 -87.664343
# 25052   41.887434 -87.681849
# 34363   41.844671 -87.654962
# 17696   41.850451 -87.658798
# 17665   41.887434 -87.681849
# 28429         NaN        NaN
# 18906   41.743903 -87.663129
# 18079   41.886644 -87.678049
# 18059   41.887493 -87.676959
# 2277    41.964649 -87.727782
# 1439    41.964704 -87.727784
# 9875    41.876748 -87.633286
# 68628   41.888079 -87.624047

# %% [markdown]
# ### 3. The same license number and name_dba can have multiple name_akas.
# For example, there are 81 distinct name_dba/facility type combinations for license_id14616 ILLINOIS SPORTSERVICE INC:

# %%
temp = input_data[['license_id', 'name_dba', 'name_aka', 'facility_type']].drop_duplicates().groupby(
    by=['license_id', 'name_dba'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False).reset_index(drop=True)
temp.head(5)
# Out:
#   license_id                           name_dba  count
# 0      14616          ILLINOIS SPORTSERVICE INC     81
# 1    1974745                  THE UNITED CENTER     45
# 2    1354323         SPORTSERVICE SOLDIER FIELD     45
# 3    1574001  LEVY RESTAURANTS AT WRIGLEY FIELD     19
# 4    1932251                    MCCORMICK PLACE     16

# %% [markdown]
# There are 178 such license_id/name_dba combinations that have more than 1 name_dba/facility type combinations:

# %%
len(temp[temp['count']>1])
# Out:
# 178

# %% [markdown]
# Take a closer look at license_id14616:

# %%
input_data[(input_data['license_id']=='14616') & (input_data['name_dba']=='ILLINOIS SPORTSERVICE INC')][
    ['license_id', 'name_dba', 'name_aka', 'facility_type']].drop_duplicates()
# Out:
#        license_id                   name_dba  \
# 2209        14616  ILLINOIS SPORTSERVICE INC
# 123192      14616  ILLINOIS SPORTSERVICE INC
# 123200      14616  ILLINOIS SPORTSERVICE INC
# 128176      14616  ILLINOIS SPORTSERVICE INC
# 128419      14616  ILLINOIS SPORTSERVICE INC
# ...           ...                        ...
# 149924      14616  ILLINOIS SPORTSERVICE INC
# 149950      14616  ILLINOIS SPORTSERVICE INC
# 149955      14616  ILLINOIS SPORTSERVICE INC
# 149973      14616  ILLINOIS SPORTSERVICE INC
# 149982      14616  ILLINOIS SPORTSERVICE INC
#
#                                                  name_aka facility_type
# 2209                                GUARANTEED RATE FIELD       stadium
# 123192                                    MAIN COMMISSARY    commissary
# 123200    SHERM LOLLARS GUARD THE PLATE GRILLE STAND #524    restaurant
# 128176                           TEX-MEX 3 - STEAK (#544)         kiosk
# 128419                                BBQ BRISKET  (#531)         kiosk
# ...                                                   ...           ...
# 149924                            DIPPING DOTS (SEC #132)    restaurant
# 149950                                    GO GO WHITE SOX    restaurant
# 149955                                     NACHO 8 (#544)    restaurant
# 149973                       HOT DOG VIENNA BEEF 7 (#557)    restaurant
# 149982  SWEET SPOT (BIG ED WALSHS ITALIAN BEEF AND PIZZA)    restaurant
#
# [81 rows x 4 columns]

# %% [markdown]
# ### 4. The same address can have multiple license numbers

# %%
temp = input_data[(input_data['license_id']!='') & (input_data['license_id']!='nan') & (~pd.isnull(input_data['license_id']))][[
    'license_id', 'address', 'city', 'state', 'zip', 'latitude','longitude']].drop_duplicates()
temp[temp.duplicated(subset=['address', 'city', 'state', 'zip', 'latitude','longitude'], keep=False)].sort_values(by='address')
# Out:
#        license_id                address     city state    zip   latitude  \
# 28429     2442868                             NaN    IL    NaN        NaN
# 149587          0                             NaN    IL    NaN        NaN
# 10019     2215538           1 E 113TH ST  CHICAGO    IL  60628  41.688848
# 116232      21702           1 E 113TH ST  CHICAGO    IL  60628  41.688848
# 116234    1800876           1 E 113TH ST  CHICAGO    IL  60628  41.688848
# ...           ...                    ...      ...   ...    ...        ...
# 32207     2113336       9917 S EWING AVE  CHICAGO    IL  60617  41.715244
# 75412     2046663  9928 S CRANDON AVE FL  CHICAGO    IL  60617  41.714402
# 9089      3247017  9928 S CRANDON AVE FL  CHICAGO    IL  60617  41.714402
# 83366     2093742      9939 S HALSTED ST  CHICAGO    IL  60628  41.713035
# 15763     1998729      9939 S HALSTED ST  CHICAGO    IL  60628  41.713035
#
#         longitude
# 28429         NaN
# 149587        NaN
# 10019  -87.622894
# 116232 -87.622894
# 116234 -87.622894
# ...           ...
# 32207  -87.535130
# 75412  -87.567167
# 9089   -87.567167
# 83366  -87.642832
# 15763  -87.642832
#
# [24859 rows x 7 columns]

# %% [markdown]
# ### 5. Even the same (?) food facility can have different license numbers!

# %%
temp = input_data[[
    'name_dba','name_aka','license_id','facility_type','address','city','state','zip',
    'latitude','longitude']].drop_duplicates()
facility_counts = temp.groupby(
    by=['name_dba','name_aka','facility_type','address','city','state','zip','latitude','longitude'], dropna=False)\
    .size().rename('count').reset_index().sort_values(by='count', ascending=False)
facility_counts.head(10)
# Out:
#                                                 name_dba  \
# 27180                              TRIPLE A SERVICES INC
# 19437  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 27671                                      VHC LOWER LLC
# 19379                                PALETERIA AZTECA #2
# 23287                                         SOHO HOUSE
# 27894                            WALDORF ASTORIA CHICAGO
# 9515                                      FLAT TOP GRILL
# 19376                                PALETERIA AZTECA #2
# 19323                PACIFIC LANGHAM CHICAGO CORPORATION
# 19744                               PARS ICECREAM CO INC
#
#                                             name_aka         facility_type  \
# 27180                          TRIPLE A SERVICES INC  mobile food preparer
# 19437                        LA MEXICANA TAMALE CART  mobile food preparer
# 27671  3RD FLOOR - BANQUET/MEETING ROOMS(LL KITCHEN)            restaurant
# 19379                                            NaN  mobile food preparer
# 23287                                     SOHO HOUSE            restaurant
# 27894                        WALDORF ASTORIA CHICAGO            restaurant
# 9515                                  FLAT TOP GRILL            restaurant
# 19376                            PALETERIA AZTECA #2  mobile food preparer
# 19323                            THE LANGHAM CHICAGO            restaurant
# 19744                                            NaN  mobile food preparer
#
#                     address     city state    zip   latitude  longitude  count
# 27180   2637 S THROOP ST FL  CHICAGO    IL  60608  41.844671 -87.654962     43
# 19437     4171 S ARCHER AVE  CHICAGO    IL  60632  41.817618 -87.698258     16
# 27671      203 N WABASH AVE  CHICAGO    IL  60601  41.885828 -87.626138     15
# 19379      3119 W CERMAK RD  CHICAGO    IL  60623  41.851676 -87.703696     10
# 23287    113-125 N GREEN ST  CHICAGO    IL  60607  41.883557 -87.648432     10
# 27894        11 E WALTON ST  CHICAGO    IL  60611  41.899835 -87.627799      9
# 9515        30 S WABASH AVE  CHICAGO    IL  60603  41.881335 -87.626335      8
# 19376      3119 W CERMAK RD  CHICAGO    IL  60623  41.851676 -87.703696      7
# 19323      330 N WABASH AVE  CHICAGO    IL  60611  41.887939 -87.627036      7
# 19744  4825 W ARTHINGTON ST  CHICAGO    IL  60644  41.869236 -87.745893      7

# %%
print(f"{len(facility_counts[facility_counts['count']>1])} such facilities are involved!")
print(f"That's {round(100*len(facility_counts[facility_counts['count']>1])/len(facility_counts), 2)}% of all facilities!!")
# Out:
# 4017 such facilities are involved!
# That's 13.84% of all facilities!!

# %% [markdown]
# Note that some of them have the facility type of "Mobile Prepared Food Vendor". Some of the "Restaurant" facilities seem to be hotels, or within a complex.
# In the following example, most of them have the facility type of "Mobile Prepared Food Vendor":

# %%
input_data[input_data['name_aka']=='LA MEXICANA TAMALE CART'][
    ['license_id', 'name_dba','name_aka','facility_type','address','city','state','zip',
     'latitude','longitude','inspection_date']
].drop_duplicates()
# Out:
#       license_id                                           name_dba  \
# 5099     2506389  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11717    2506388  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11720    2506235  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11721    2506234  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11725    2506233  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11727    2506231  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11729    2506230  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11731    2506222  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11735    2506220  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11737    2506221  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11740    2506215  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11743    2506213  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11747    2506212  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11752    2506211  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11753    2506209  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11778    2500986  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 14041    2495679  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
#
#                       name_aka         facility_type            address  \
# 5099   LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11717  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11720  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11721  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11725  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11727  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11729  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11731  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11735  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11737  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11740  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11743  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11747  LA MEXICANA TAMALE CART            restaurant  4171 S ARCHER AVE
# 11752  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11753  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11778  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 14041  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
#
#           city state    zip   latitude  longitude inspection_date
# 5099   CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11717  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11720  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11721  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11725  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11727  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11729  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11731  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11735  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11737  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11740  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11743  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11747  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11752  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11753  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11778  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 14041  CHICAGO    IL  60632  41.817618 -87.698258      2016-11-22

# %% [markdown]
# Since these facilities, although sharing the same address, are treated differently for the food inspection purpose, here we need to treat them as distinct facilities!

# %% [markdown]
# ## 2.2 Duplicated inspections?

# %% [markdown]
# **[exploration]**
# ### 6. Are there any redundant inspection entries on the same day for the same facility?

# %%
temp2 = input_data[['inspection_id', 'license_id', 'name_dba', 'name_aka', 'inspection_date', 'inspection_type']]
inspection_counts2 = temp2.groupby(by=['license_id', 'name_dba', 'name_aka', 'inspection_date', 'inspection_type'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False)
inspection_counts2.head(10)
# Out:
#        license_id                      name_dba  \
# 12931     1354323    SPORTSERVICE SOLDIER FIELD
# 12933     1354323    SPORTSERVICE SOLDIER FIELD
# 12892     1354323    SPORTSERVICE SOLDIER FIELD
# 12899     1354323    SPORTSERVICE SOLDIER FIELD
# 16591       14616     ILLINOIS SPORTSERVICE INC
# 23926     1578830                 BUFFET CASTLE
# 24426     1592201                     6 DEGREES
# 66801     2048785     TRUMP INTERNATIONAL HOTEL
# 137502       3727     ALL AMERICAN NURSING HOME
# 139166      40155  POPEYES CHICKEN/INDIAN SWAAD
#
#                                 name_aka inspection_date  \
# 12931                     GRIDIRON GRILL      2010-06-07
# 12933                     GRIDIRON GRILL      2011-05-23
# 12892                    1ST DOWN FRANKS      2010-06-07
# 12899                     2ND CITY PIZZA      2010-06-07
# 16591   MOOSES DOGS AND POLISH 10 (#538)      2010-03-25
# 23926                      BUFFET CASTLE      2013-04-18
# 24426                          6 DEGREES      2016-09-09
# 66801                            SIXTEEN      2017-05-09
# 137502         ALL AMERICAN NURSING HOME      2010-02-25
# 139166      POPEYES CHICKEN/INDIAN SWAAD      2010-05-20
#
#                 inspection_type  count
# 12931                   canvass      5
# 12933                   canvass      3
# 12892                   canvass      3
# 12899                   canvass      3
# 16591                   canvass      2
# 23926                   canvass      2
# 24426                   canvass      2
# 66801                   canvass      2
# 137502                  canvass      2
# 139166  complaint re-inspection      2

# %%
print("How many unique food facilities/inspection date combinations have multiple inspections on that date?")
num_facility_date_multiple_inspections = len(inspection_counts2[inspection_counts2['count']>1])
num_facility_date_comb = len(inspection_counts2)
print(f"{num_facility_date_multiple_inspections} out of {num_facility_date_comb} ({round(100*num_facility_date_multiple_inspections/num_facility_date_comb, 2)}%)")

print("How many inspection records are involved ?")
num_inspection_involved = inspection_counts2[inspection_counts2['count']>1]['count'].sum()
print(f"{num_inspection_involved} out of {num_inspection} ({round(100*num_inspection_involved/num_inspection, 2)}%)")

print("How many unique license numbers are involved?")
num_license_involved = len(inspection_counts2[inspection_counts2['count']>1][['license_id']].drop_duplicates())
print(f"{num_license_involved} out of {num_license} ({round(100*num_license_involved/num_license, 2)}%)")

print("How many unique food facilities are involved?")
num_facility_involved = len(inspection_counts2[inspection_counts2['count']>1][['license_id', 'name_aka']].drop_duplicates())
print(f"{num_facility_involved} out of {num_facility} ({round(100*num_facility_involved/num_facility, 2)}%)")

print("How many unique inspection dates are involved?")
num_dates_involved = len(inspection_counts2[inspection_counts2['count']>1][['inspection_date']].drop_duplicates())
print(f"{num_dates_involved} out of {num_dates} ({round(100*num_dates_involved/num_dates, 2)}%)")
# Out:
# How many unique food facilities/inspection date combinations have multiple inspections on that date?
# 393 out of 153318 (0.26%)
# How many inspection records are involved ?
# 792 out of 153717 (0.52%)
# How many unique license numbers are involved?
# 370 out of 32851 (1.13%)
# How many unique food facilities are involved?
# 381 out of 34037 (1.12%)
# How many unique inspection dates are involved?
# 336 out of 1946 (17.27%)

# %% [markdown]
# What's happening there? Take one example to look into the details:

# %%
input_data[(input_data['license_id']=='1354323') & (input_data['name_aka']=='GRIDIRON GRILL') & (input_data['inspection_date']=='2010-06-07')]
# Out:
#        inspection_id                    name_dba        name_aka license_id  \
# 146342        250633  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL    1354323
# 146350        197469  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL    1354323
# 146358        112420  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL    1354323
# 146363        160390  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL    1354323
# 146406        197476  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL    1354323
#
#        facility_type             risk                  address     city state  \
# 146342    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146350    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146358    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146363    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146406    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
#
#           zip inspection_date inspection_type results  \
# 146342  60605      2010-06-07         canvass    Pass
# 146350  60605      2010-06-07         canvass    Pass
# 146358  60605      2010-06-07         canvass    Pass
# 146363  60605      2010-06-07         canvass    Pass
# 146406  60605      2010-06-07         canvass    Pass
#
#                                                violations   latitude  \
# 146342  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.862628
# 146350  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.862628
# 146358  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.862628
# 146363  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.862628
# 146406  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.862628
#
#         longitude
# 146342 -87.615031
# 146350 -87.615031
# 146358 -87.615031
# 146363 -87.615031
# 146406 -87.615031

# %% [markdown]
# OK. It looks like there are indeed multiple inspections on the same date. Although the results are the same ("Pass"), the detailed "violations" notes are different! In this case, **we will need to collapse these inspections**. (We'll do this in a later section!)
# Also note that some of the violations have different comments although they share the same violation code:

# %%
input_data.loc[146342, 'violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \n \nMUST DETAIL CLEAN FLOORS UNDER GRILL AND REMOVE FOOD DEBRIS AND GREASE BUILD UP.  '

# %%
input_data.loc[146406, 'violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \nSTANDING WATER NEXT TO GREASE TRAP. INSTRUCTED TO CLEAN AND MAINTAIN. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned. \nPEELING PAINT NOTED ON WALL NEXT TO DEEP FRYER, INSTRUCTED MANAGER TO REMOVE AND MAINTAIN.'

# %% [markdown]
# Let's also consider address, results and violatoins:
# Now there are no duplicates!

# %%
temp = input_data[['inspection_id', 'license_id', 'name_dba', 'name_aka', 'facility_type', 'address', 'inspection_date', 'inspection_type', 'results', 'violations']]
temp.duplicated(subset=list(temp)[1:], keep=False).sum()
# Out:
# 0

# %% [markdown]
# # 3. Further data cleanup and split into multiple tables

# %% [markdown]
# ## 3.1 Facility and Address tables

# %% [markdown]
# Based on above exploration, we define a "facility" as a unique combination of 'license_id', 'name_dba', 'name_aka', 'facility_type', 'address', 'zip'. To be convenient, we need to assign an artifical id to a certain facility.

# %% [markdown]
# [check] Is it true that a unique "address" and "zip" combination has unique set of "city", "state", "latitude" and "longitude"? In other words, we only need the "address" and "zip" columns, and the "city", "state", "latitude" and "longitude" columns are not providing additional information in identifying a certain facility. This is true:

# %%
addresses = input_data[['address', 'city', 'state', 'zip', 'latitude', 'longitude']].drop_duplicates()
addresses.duplicated(subset=['address', 'zip'], keep=False).sum()
# Out:
# 0

# %%
facilities = input_data[['name_dba', 'name_aka', 'license_id', 'facility_type', 'address', 'zip']].drop_duplicates().sort_values(by='name_dba').reset_index(drop=True)
facilities.insert (0, 'facility_id', facilities.index)
facilities
# Out:
#        facility_id                 name_dba                 name_aka  \
# 0                0     #1 CHINA EXPRESS LTD    #1 CHINA EXPRESS  LTD
# 1                1             #1 CHOP SUEY             #1 CHOP SUEY
# 2                2             #1 CHOP SUEY             #1 CHOP SUEY
# 3                3  #1 CHOP SUEY RESTAURANT  #1 CHOP SUEY RESTAURANT
# 4                4              #1 DELI INC              31 DELI INC
# ...            ...                      ...                      ...
# 34032        34032       ZULLOS MARKETS LLC            ZULLOS MARKET
# 34033        34033           ZUS QUICK MART          ZUS QUIICK MART
# 34034        34034           ZUZU WRAPS INC               ZUZU WRAPS
# 34035        34035             ZYGGYZ GRILL             ZYGGYZ GRILL
# 34036        34036                  ZZS INC                 PITA PIT
#
#       license_id facility_type                  address    zip
# 0        1869616    restaurant     4248 S WENTWORTH AVE  60609
# 1        2042372    restaurant           1907 W 87TH ST  60620
# 2        1970042    restaurant    4307 W IRVING PARK RD  60641
# 3        1739799    restaurant    4307 W IRVING PARK RD  60641
# 4        2501188       grocery       6901 S NORMAL BLVD  60621
# ...          ...           ...                      ...    ...
# 34032    2016915    restaurant         131 N CLINTON ST  60661
# 34033    2020878       grocery       11641 S HALSTED ST  60628
# 34034    2256140    restaurant      3200 W LAWRENCE AVE  60625
# 34035    1991900    restaurant  6604 N SHERIDAN RD BLDG  60626
# 34036    2543509    restaurant       2404 N LINCOLN AVE  60614
#
# [34037 rows x 7 columns]

# %%
facilities.to_csv("data/tables/facilities.csv", index=False)

# %%
addresses = addresses[['address', 'zip', 'city', 'state', 'latitude', 'longitude']]
addresses
# Out:
#                          address    zip     city state   latitude  longitude
# 0             2121 S PRAIRIE AVE  60616  CHICAGO    IL  41.853651 -87.620534
# 1              1025 W MADISON ST  60607  CHICAGO    IL  41.881572 -87.653052
# 2               301 N JUSTINE ST  60607  CHICAGO    IL  41.886577 -87.665328
# 4            2245 N MCVICKER AVE  60639  CHICAGO    IL  41.921675 -87.776711
# 5       4355 S COTTAGE GROVE AVE  60653  CHICAGO    IL  41.815197 -87.606531
# ...                          ...    ...      ...   ...        ...        ...
# 153489      3333 W FULLERTON AVE  60647  CHICAGO    IL  41.924554 -87.711953
# 153567      13205 S MUSKEGON AVE  60633  CHICAGO    IL  41.655351 -87.554280
# 153653         7105 S RACINE AVE  60636  CHICAGO    IL  41.764896 -87.653965
# 153668            2003 W 69TH ST  60636  CHICAGO    IL  41.768328 -87.673819
# 153674     2458 S CALIFORNIA AVE  60608  CHICAGO    IL  41.846516 -87.695423
#
# [16032 rows x 6 columns]

# %%
addresses.to_csv("data/tables/addresses.csv", index=False)

# %%
# add the facility_id column to the dataset and double check
input_data = input_data.merge(facilities)
len(set(input_data['facility_id'])) == len(facilities)
# Out:
# True

# %%
input_data.to_csv('data/half_clean/input_data_cleaned_intermediate.csv', index=False)

# %% [markdown]
# ## 3.2 Risk and Facility_Risk tables

# %% [markdown]
# Here we double check that each facility has a certain risk level:

# %%
facility_risk = input_data[~input_data['risk'].isnull()][['facility_id', 'risk']].drop_duplicates()
facility_risk.duplicated(subset=['facility_id'], keep=False).sum()
# Out:
# 0

# %%
facility_risk = facility_risk.sort_values(by='facility_id').reset_index(drop=True)
facility_risk
# Out:
#        facility_id             risk
# 0                0    Risk 1 (High)
# 1                1    Risk 1 (High)
# 2                2    Risk 1 (High)
# 3                3    Risk 1 (High)
# 4                4  Risk 2 (Medium)
# ...            ...              ...
# 33949        34032  Risk 2 (Medium)
# 33950        34033     Risk 3 (Low)
# 33951        34034    Risk 1 (High)
# 33952        34035    Risk 1 (High)
# 33953        34036  Risk 2 (Medium)
#
# [33954 rows x 2 columns]

# %%
facility_risk['risk'].value_counts()
# Out:
# Risk 1 (High)      18331
# Risk 3 (Low)        8403
# Risk 2 (Medium)     7202
# All                   18
# Name: risk, dtype: int64

# %% [markdown]
# Let's further seperate the risk code and risk level. For "All", let's define a risk code 0 to indicate "All".

# %%
facility_risk['risk'] = facility_risk['risk'].str.replace('All', 'Risk 0 (All)')
facility_risk['risk'].value_counts()
# Out:
# Risk 1 (High)      18331
# Risk 3 (Low)        8403
# Risk 2 (Medium)     7202
# Risk 0 (All)          18
# Name: risk, dtype: int64

# %%
def extract_risk(s):
    matched = re.compile(r'\w+ (?P<code>\d+) \((?P<level>\w+)\)').match(s)
    if matched:
        return matched.group('code'), matched.group('level')
    else:
        return '', ''

facility_risk['risk_code'], facility_risk['risk_level'] = zip(*facility_risk['risk'].apply(extract_risk))
facility_risk
# Out:
#        facility_id             risk risk_code risk_level
# 0                0    Risk 1 (High)         1       High
# 1                1    Risk 1 (High)         1       High
# 2                2    Risk 1 (High)         1       High
# 3                3    Risk 1 (High)         1       High
# 4                4  Risk 2 (Medium)         2     Medium
# ...            ...              ...       ...        ...
# 33949        34032  Risk 2 (Medium)         2     Medium
# 33950        34033     Risk 3 (Low)         3        Low
# 33951        34034    Risk 1 (High)         1       High
# 33952        34035    Risk 1 (High)         1       High
# 33953        34036  Risk 2 (Medium)         2     Medium
#
# [33954 rows x 4 columns]

# %%
risks = facility_risk[['risk_code', 'risk_level']].drop_duplicates().sort_values(by='risk_code').reset_index(drop=True)\
    .rename(columns={'risk_code': 'code', 'risk_level': 'level'})
risks.to_csv("data/tables/risks.csv", index=False)
risks
# Out:
#   code   level
# 0    0     All
# 1    1    High
# 2    2  Medium
# 3    3     Low

# %%
facility_risk = facility_risk.drop(columns=['risk', 'risk_level'])
facility_risk.to_csv("data/tables/facility_risk.csv", index=False)
facility_risk
# Out:
#        facility_id risk_code
# 0                0         1
# 1                1         1
# 2                2         1
# 3                3         1
# 4                4         2
# ...            ...       ...
# 33949        34032         2
# 33950        34033         3
# 33951        34034         1
# 33952        34035         1
# 33953        34036         2
#
# [33954 rows x 2 columns]

# %% [markdown]
# ## 3.3 Inspection and Facility_Inspection tables

# %%
inspection_results = input_data[['inspection_id', 'inspection_date', 'inspection_type', 'results', 'violations', 'facility_id']]
inspection_results
# Out:
#        inspection_id inspection_date        inspection_type    results  \
# 0            2079132      2017-08-28                license       Pass
# 1            2078553      2017-08-15                license  Not Ready
# 2            2079129      2017-08-28                license  Not Ready
# 3            2079125      2017-08-28  license re-inspection  Not Ready
# 4            2072040      2017-08-08                license       Fail
# ...              ...             ...                    ...        ...
# 153712         70272      2010-01-05        out of business       Pass
# 153713         68251      2010-01-05  license re-inspection       Pass
# 153714        158243      2010-01-05                license       Fail
# 153715        160208      2010-01-05        out of business       Pass
# 153716         67733      2010-01-04  license re-inspection       Pass
#
#                                                violations  facility_id
# 0                                                     NaN        19402
# 1                                                     NaN        19402
# 2                                                     NaN        15093
# 3                                                     NaN        25450
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        25450
# ...                                                   ...          ...
# 153712                                                NaN        30313
# 153713  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...         7670
# 153714                                                NaN         9059
# 153715                                                NaN        18585
# 153716  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...        33577
#
# [153717 rows x 6 columns]

# %% [markdown]
# Check the results column:

# %%
inspection_results['results'].value_counts()
# Out:
# Pass                    90485
# Fail                    29835
# Pass w/ Conditions      14530
# Out of Business         13737
# No Entry                 4252
# Not Ready                 818
# Business Not Located       60
# Name: results, dtype: int64

# %% [markdown]
# As mentioned above, there is a repeated inspection issue - for a certain facility_id/inspection_date/inspection_type combination, how many different inspections are there? We are expecting count=1 but we see count>1 in 367 such combinations and it involves 740 inspection records:

# %%
inspection_dup_counts = inspection_results.groupby(by=['facility_id', 'inspection_date', 'inspection_type'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False)
inspection_dup_counts[inspection_dup_counts['count'] > 1]
# Out:
#         facility_id inspection_date          inspection_type  count
# 122905        27465      2010-06-07                  canvass      5
# 122907        27465      2011-05-23                  canvass      3
# 122963        27484      2010-06-07                  canvass      3
# 122984        27490      2010-06-07                  canvass      3
# 99834         22488      2015-07-07                  canvass      2
# ...             ...             ...                      ...    ...
# 94601         21407      2010-10-07                  canvass      2
# 21856          5258      2015-07-08                  canvass      2
# 8419           2178      2010-01-06  complaint re-inspection      2
# 9660           2438      2013-02-07                  canvass      2
# 153117        33989      2010-05-03                  canvass      2
#
# [367 rows x 4 columns]

# %% [markdown]
# Inspections involved:

# %%
inspections_duplicated = inspection_results[inspection_results.duplicated(subset=['facility_id', 'inspection_date', 'inspection_type'], keep=False)].sort_values(by='facility_id')
inspections_duplicated

#with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
#    display(inspections_duplicated)
# Out:
#        inspection_id inspection_date inspection_type          results  \
# 45325        1990125      2017-03-07         canvass             Pass
# 45326        1990135      2017-03-07         canvass  Out of Business
# 152367        277609      2010-07-21         canvass             Pass
# 152368        277587      2010-07-21         canvass             Fail
# 111358       1559937      2015-07-07         canvass  Out of Business
# ...              ...             ...             ...              ...
# 109645       1567176      2015-09-03         canvass  Out of Business
# 133527         78338      2010-03-09         canvass             Pass
# 133528         78337      2010-03-09         canvass             Pass
# 113817         58461      2010-05-03         canvass             Pass
# 113818        233459      2010-05-03         canvass             Pass
#
#                                                violations  facility_id
# 45325   34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...          111
# 45326                                                 NaN          111
# 152367  14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...          206
# 152368  14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...          206
# 111358                                                NaN          213
# ...                                                   ...          ...
# 109645                                                NaN        33866
# 133527  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...        33898
# 133528  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...        33898
# 113817  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        33989
# 113818  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        33989
#
# [740 rows x 6 columns]

# %% [markdown]
# Some examples:

# %%
inspection_results[(inspection_results['facility_id']==27465) & (inspection_results['inspection_date']=='2010-06-07')]
# Out:
#        inspection_id inspection_date inspection_type results  \
# 127533        250633      2010-06-07         canvass    Pass
# 127534        197469      2010-06-07         canvass    Pass
# 127535        112420      2010-06-07         canvass    Pass
# 127536        160390      2010-06-07         canvass    Pass
# 127537        197476      2010-06-07         canvass    Pass
#
#                                                violations  facility_id
# 127533  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...        27465
# 127534  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...        27465
# 127535  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...        27465
# 127536  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...        27465
# 127537  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...        27465

# %%
inspection_results[(inspection_results['facility_id']==27465) & (inspection_results['inspection_date']=='2011-05-23')]
# Out:
#        inspection_id inspection_date inspection_type results  \
# 127528        567409      2011-05-23         canvass    Pass
# 127529        569352      2011-05-23         canvass    Pass
# 127530        565353      2011-05-23         canvass    Pass
#
#                                                violations  facility_id
# 127528                                                NaN        27465
# 127529  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...        27465
# 127530  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...        27465

# %%
inspection_results[(inspection_results['facility_id']==206) & (inspection_results['inspection_date']=='2010-07-21')]
# Out:
#        inspection_id inspection_date inspection_type results  \
# 152367        277609      2010-07-21         canvass    Pass
# 152368        277587      2010-07-21         canvass    Fail
#
#                                                violations  facility_id
# 152367  14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...          206
# 152368  14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...          206

# %% [markdown]
# It looks like there could exist multiple inspections on the same date for the same facility. In the above examples, although some times the results are the same ("Pass"), the detailed "violations" notes could be different! Also note that some of the violations have different comments although they share the same violation code:

# %%
input_data.loc[146342, 'violations']
# Out:
# '21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED - Comments: A certified food service manager must be present in all establishments at which potentially hazardous food is prepared or served. \nNO ORIGINAL CHICAGO FOOD SANITATION CERTIFICATE POSTED. | 36. LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIGHT PROVIDED, FIXTURES SHIELDED - Comments: Shielding to protect against broken glass falling into food shall be provided for all artificial lighting sources in preparation, service, and display facilities. \nREPLACE DAMAGED LIGHT SHIELDS IN PREP AREA. | 38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED - Comments: REPAIR LEAKING OVERHEAD PIPE IN UTILITY CLOSET.'

# %%
input_data.loc[146406, 'violations']
# Out:
# "18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: No Pest Control logbook on premises by licensed pest control company. Instructed that a licensed pest control company must service premises and provided logbook with all required documents. Serious citation issued 7-38-020. | 21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED - Comments: No Certified Food Manager on premises when potentially hazardous foods are served and prepared-establishment prepares various beverages-hot and cold using dairy products. Instructed that a Certified Food Manager must be on premises during all hours of operation. Serious citation issued 7-38-012. | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: Floors along wallbase thru-out premises not cleaned. Instructed to detail clean daily. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: Walls and door frames thru-out not maintained. Instructed to apply non-toxic sealant to raw wood and paint walls. \n \nSeveral holes noted in walls thru-out. Instructed seal all holes. \n \nCoving not provided along wallbase thru-out. Instructed to install between floor and wallbase. | 40. REFRIGERATION AND METAL STEM THERMOMETERS PROVIDED AND CONSPICUOUS - Comments: Thermometer not provided inside coolers. Instructed to provide thermometer visible inside coolers. | 38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED - Comments: Stove not properly vented in rear prep area. Instructed to have cooking equipment under vented hood. | 70. NO SMOKING REGULATIONS - Comments: Observed smoking in public places. Found customer-male standing at front counter smoking cigarette, while walking thru-out premises. Also, in video gaming area observed hundreds of cigarette butts and ashes on the ground around machines. Instructed that 'No Smoking' ordinances requires that establishment has 'smoking free inside all establishments and only allowed 15 ft. outside of establishment. Citation issued 7-32-015. | 26. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, PROPERLY DESIGNED AND INSTALLED - Comments: Handsink not provided in rear prep area where food preparation is performed. Instructed to install additional handsink in rear prep area for food handlers. Serious citation issued 7-38-030."

# %% [markdown]
# **[solution]**
# We need to collapse these repeated inspections.
#
# **Rules** - For the same facility and the same inspection type, on the same date, if have more than one results:
# - If have non-conflicting results (such as “Pass” and “Out of Business”), will just keep the conclusive one (such as “Pass”) and ignore the non-conclusive one (such as “Out of Business”).
# - If have conflicting results (such as “Pass” and “Fail”), will consider both invalid and remove all of them.
# - If have “No Entry” and other results, then remove “No Entry”.
# - If have the same result (such as “Pass” or “Fail”) with different “violations”, then combine these violations.
# - If have “Pass” and “Pass w/ Conditions”, then consider it as “Pass w/ Conditions”, and combine violations.
# - If only have “Business not loacated” and “Out of Business”, just keep “Out of Business”.
# - In all of these cases, only keep one inspection id, and add a “-c” at the end to indicate “collapsed”.
#
# Note:
# conclusive_results = ['Pass', 'Fail', 'Pass w/ Conditions'];
# non_conclusive_results = ['Out of Business', 'No Entry', 'Not Ready', 'Business Not Located']

# %%
def inspection_agg(df):
    d = {}
    debug = False
    
    def process_single_type(d, df):
        result = df['results'].values[0]
        d['results'] = result
        d['inspection_id'] = df['inspection_id'].values[0] + '-s'
        d['violations'] = np.nan
        if (result in conclusive_results) and ((~df['violations'].isnull()).sum() > 0):            
            d['violations'] = ' | '.join([violation for violation in list(set(df['violations'])) if not pd.isna(violation)])                                        
        return d

    def choose_non_conclusive_type(d, df, type_):
        df = df[df['results']==type_]
        d['results'] = type_
        d['inspection_id'] = df['inspection_id'].values[0] + '-s'
        d['violations'] = np.nan 
        return d     
    
    # remove all "No Entry" results because they are not informative
    df = df[df['results']!='No Entry']
    
    results = list(set(df['results']))
    
    if debug:
        display(df)
        print(results)
        
    # branch 1: if there is only one type of result:
    if len(set(df['results']))==1:
        if debug: print('In Branch 1!')
        d = process_single_type(d, df)
    
    # other wise there are at least 2 types
    # branch 2: if there are conflicting results
    elif (('Pass' in results) or ('Pass w/ Conditions' in results)) and ('Fail' in results):
        if debug: print('In Branch 2!')
        d = {}
        
    # now we know there are no conflicting results
    # branch 3: if we have both 'Pass' and Pass w/ Conditions'
    elif ('Pass' in results) and ('Pass w/ Conditions' in results):
        if debug: print('In Branch 3!')
        df = df[df['results'].isin(['Pass', 'Pass w/ Conditions'])]
        d['results'] = 'Pass w/ Conditions'
        d['inspection_id'] = df['inspection_id'].values[0] + '-s'
        d['violations'] = np.nan
        if (~df['violations'].isnull()).sum() > 0:
            d['violations'] = ' | '.join([violation for violation in list(set(df['violations'])) if not pd.isna(violation)])
        
    # branch 4: if at least one conclusive result 
    elif ('Pass' in results) or ('Pass w/ Conditions' in results) or ('Fail' in results):
        if debug: print('In Branch 4!')
        df = df[df['results'].isin(conclusive_results)]
        d = process_single_type(d, df)
        
    # all from non-conclusive results
    # branch 5
    elif ('Not Ready' in results):
        if debug: print('In Branch 5!')
        d = choose_non_conclusive_type(d, df, 'Not Ready')      
        
    # branch 6
    elif ('Out of Business' in results):
        if debug: print('In Branch 6!')
        d = choose_non_conclusive_type(d, df, 'Out of Business')  
        
    # branch 7
    elif ('Business Not Located' in results):     
        if debug: print('In Branch 7!')
        d = choose_non_conclusive_type(d, df, 'Business Not Located')    

    return pd.Series(d, index=['inspection_id', 'results', 'violations'])
    
inspections_duplicated_agg = inspections_duplicated.groupby(by=['facility_id', 'inspection_date', 'inspection_type'], dropna=False).apply(inspection_agg).reset_index()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:74: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %% [markdown]
# Now we need to remove the records with null information (for example when there are conflicting results):

# %%
inspections_duplicated_agg = inspections_duplicated_agg[~inspections_duplicated_agg['inspection_id'].isnull()]

#with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
#    display(inspections_duplicated_agg)

# %% [markdown]
# Next, we need to process the whole dataset `inspection_results`, to replace the records in `inspections_duplicated`, with the aggregated results from `inspections_duplicated_agg`.

# %%
inspection_results_dedup = pd.concat([
    inspection_results[~inspection_results['inspection_id'].isin(list(inspections_duplicated['inspection_id']))], 
    inspections_duplicated_agg
    ], ignore_index=True)
inspection_results_dedup
# Out:
#        inspection_id inspection_date        inspection_type  \
# 0            2079132      2017-08-28                license
# 1            2078553      2017-08-15                license
# 2            2079129      2017-08-28                license
# 3            2079125      2017-08-28  license re-inspection
# 4            2072040      2017-08-08                license
# ...              ...             ...                    ...
# 153312     1949159-s      2016-08-11                canvass
# 153313     1080244-s      2012-04-16                canvass
# 153314     1567147-s      2015-09-03                canvass
# 153315       78338-s      2010-03-09                canvass
# 153316       58461-s      2010-05-03                canvass
#
#                    results                                         violations  \
# 0                     Pass                                                NaN
# 1                Not Ready                                                NaN
# 2                Not Ready                                                NaN
# 3                Not Ready                                                NaN
# 4                     Fail  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# ...                    ...                                                ...
# 153312                Pass  16. FOOD PROTECTED DURING STORAGE, PREPARATION...
# 153313                Pass  19. OUTSIDE GARBAGE WASTE GREASE AND STORAGE A...
# 153314  Pass w/ Conditions  6. HANDS WASHED AND CLEANED, GOOD HYGIENIC PRA...
# 153315                Pass  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
# 153316                Pass  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
#
#         facility_id
# 0             19402
# 1             19402
# 2             15093
# 3             25450
# 4             25450
# ...             ...
# 153312        33768
# 153313        33835
# 153314        33866
# 153315        33898
# 153316        33989
#
# [153317 rows x 6 columns]

# %% [markdown]
# Confirm the change:

# %%
inspection_dup_counts = inspection_results_dedup.groupby(by=['facility_id', 'inspection_date', 'inspection_type'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False)
inspection_dup_counts[inspection_dup_counts['count'] > 1]
# Out:
# Empty DataFrame
# Columns: [facility_id, inspection_date, inspection_type, count]
# Index: []

# %% [markdown]
# Example of collapsed record:

# %%
temp = inspection_results_dedup[(inspection_results_dedup['facility_id']==27465) & (inspection_results_dedup['inspection_date']=='2010-06-07')]
temp
# Out:
#        inspection_id inspection_date inspection_type results  \
# 153247      160390-s      2010-06-07         canvass    Pass
#
#                                                violations  facility_id
# 153247  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...        27465

# %%
print(temp['violations'].values[0])
# Out:
# 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned.
#
# DROP CEILING PANEL OVER DEEP FRYER IN POOR REPAIR. MUST REPLACE.   | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: All food and non-food contact equipment and utensils shall be smooth, easily cleanable, and durable, and shall be in good repair.
#
# MUST REMOVE ICE BUILD UP FROM INTERIOR OF REACH IN FREEZER.   | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair.
# STANDING WATER NEXT TO GREASE TRAP. INSTRUCTED TO CLEAN AND MAINTAIN. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned.
# PEELING PAINT NOTED ON WALL NEXT TO DEEP FRYER, INSTRUCTED MANAGER TO REMOVE AND MAINTAIN. | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair.
#
# MUST DETAIL CLEAN FLOORS UNDER GRILL AND REMOVE FOOD DEBRIS AND GREASE BUILD UP.   | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: All food and non-food contact equipment and utensils shall be smooth, easily cleanable, and durable, and shall be in good repar.
#
# FOUND EXTERIOR OF GREASE TRAP NOT CLEAN. | 33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS CLEAN, FREE OF ABRASIVE DETERGENTS - Comments: All food and non-food contact surfaces of equipment and all food storage utensils shall be thoroughly cleaned and sanitized daily.
# MUST CLEAN UNDER GRILL, WIRE RACK SHELF NOT CLEAN, INSTRUCTED TO CLEAN AND MAINTAIN.

# %%
inspections = inspection_results_dedup[['inspection_id', 'inspection_date', 'inspection_type', 'results']].sort_values(by='inspection_date').reset_index(drop=True)
inspections.to_csv("data/tables/inspections.csv", index=False)
inspections
# Out:
#        inspection_id inspection_date        inspection_type    results
# 0              67732      2010-01-04  license re-inspection       Pass
# 1              67733      2010-01-04  license re-inspection       Pass
# 2              52234      2010-01-04  license re-inspection       Pass
# 3              67757      2010-01-04            tag removal       Pass
# 4              70269      2010-01-04  license re-inspection       Pass
# ...              ...             ...                    ...        ...
# 153312       2079123      2017-08-28                license       Pass
# 153313       2079125      2017-08-28  license re-inspection  Not Ready
# 153314       2079129      2017-08-28                license  Not Ready
# 153315       2079105      2017-08-28  license re-inspection       Pass
# 153316       2079132      2017-08-28                license       Pass
#
# [153317 rows x 4 columns]

# %%
facility_inspection = inspection_results_dedup[['facility_id', 'inspection_id']].sort_values(by='facility_id').reset_index(drop=True)
facility_inspection.to_csv("data/tables/facility_inspection.csv", index=False)
facility_inspection
# Out:
#         facility_id inspection_id
# 0                 0        467259
# 1                 0       1285263
# 2                 1       1296904
# 3                 1       1395782
# 4                 1        277104
# ...             ...           ...
# 153312        34034       1376090
# 153313        34034       1099029
# 153314        34034       1098968
# 153315        34035        585594
# 153316        34036       2071213
#
# [153317 rows x 2 columns]

# %% [markdown]
# ## 3.4 Violation and  Inspection_Violation tables

# %%
violation_df = inspection_results_dedup[~pd.isnull(inspection_results_dedup['violations'])][['inspection_id', 'violations']].reset_index(drop=True)
violation_df
# Out:
#        inspection_id                                         violations
# 0            2072040  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 1            2079123  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 2            2079105  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 3            2078632  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 4            2079104  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# ...              ...                                                ...
# 122502     1949159-s  16. FOOD PROTECTED DURING STORAGE, PREPARATION...
# 122503     1080244-s  19. OUTSIDE GARBAGE WASTE GREASE AND STORAGE A...
# 122504     1567147-s  6. HANDS WASHED AND CLEANED, GOOD HYGIENIC PRA...
# 122505       78338-s  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
# 122506       58461-s  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
#
# [122507 rows x 2 columns]

# %% [markdown]
# Still use this example to figure out how to process the violations:

# %%
print(violation_df[violation_df['inspection_id']=='160390-s']['violations'].values[0])
# Out:
# 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned.
#
# DROP CEILING PANEL OVER DEEP FRYER IN POOR REPAIR. MUST REPLACE.   | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: All food and non-food contact equipment and utensils shall be smooth, easily cleanable, and durable, and shall be in good repair.
#
# MUST REMOVE ICE BUILD UP FROM INTERIOR OF REACH IN FREEZER.   | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair.
# STANDING WATER NEXT TO GREASE TRAP. INSTRUCTED TO CLEAN AND MAINTAIN. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned.
# PEELING PAINT NOTED ON WALL NEXT TO DEEP FRYER, INSTRUCTED MANAGER TO REMOVE AND MAINTAIN. | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair.
#
# MUST DETAIL CLEAN FLOORS UNDER GRILL AND REMOVE FOOD DEBRIS AND GREASE BUILD UP.   | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: All food and non-food contact equipment and utensils shall be smooth, easily cleanable, and durable, and shall be in good repar.
#
# FOUND EXTERIOR OF GREASE TRAP NOT CLEAN. | 33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS CLEAN, FREE OF ABRASIVE DETERGENTS - Comments: All food and non-food contact surfaces of equipment and all food storage utensils shall be thoroughly cleaned and sanitized daily.
# MUST CLEAN UNDER GRILL, WIRE RACK SHELF NOT CLEAN, INSTRUCTED TO CLEAN AND MAINTAIN.

# %% [markdown]
# **[solution]**
# - first, split violations using " | ", and expand the records (so one ispection_id can now have multiple rows, one row for one violation record).
# - then, for each violation record, we seperate violation code, description, and comment.

# %%
violation_df = violation_df.assign(
    violations=violation_df['violations'].str.split(' \| ')).explode('violations').reset_index(drop=True)
violation_df.head(10)
# Out:
#   inspection_id                                         violations
# 0       2072040  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 1       2072040  11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...
# 2       2072040  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...
# 3       2079123  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 4       2079123  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 5       2079105  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 6       2079105  31. CLEAN MULTI-USE UTENSILS AND SINGLE SERVIC...
# 7       2079105  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 8       2079105  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...
# 9       2079105  41. PREMISES MAINTAINED FREE OF LITTER, UNNECE...

# %% [markdown]
# Example:

# %%
violation_df[violation_df['inspection_id']=='160390-s']
# Out:
#        inspection_id                                         violations
# 566345      160390-s  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 566346      160390-s  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 566347      160390-s  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 566348      160390-s  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 566349      160390-s  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 566350      160390-s  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 566351      160390-s  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...

# %% [markdown]
# There may exist multiple violations for the same inspection_id and violation code, but with different comments:

# %%
violation_df.loc[566348, 'violations']
# Out:
# '35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned. \nPEELING PAINT NOTED ON WALL NEXT TO DEEP FRYER, INSTRUCTED MANAGER TO REMOVE AND MAINTAIN.'

# %%
violation_df.loc[566349, 'violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \n \nMUST DETAIL CLEAN FLOORS UNDER GRILL AND REMOVE FOOD DEBRIS AND GREASE BUILD UP.  '

# %%
def split_violation(violation):
    violation, comment = violation.split(' - Comments: ')
    code, description = violation.split('. ', 1)
    return code, description, comment
violation_df['code'], violation_df['description'], violation_df['comment'] = zip(*violation_df['violations'].apply(split_violation))
violation_df = violation_df.drop(columns='violations').drop_duplicates().reset_index(drop=True)
violation_df
# Out:
#        inspection_id code                                        description  \
# 0            2072040   18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 1            2072040   11  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIG...
# 2            2072040    8  SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  ...
# 3            2079123   35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4            2079123   34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# ...              ...  ...                                                ...
# 566561       58461-s   32  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 566562       58461-s   34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 566563       58461-s   38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 566564       58461-s   41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
# 566565       58461-s   38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
#
#                                                   comment
# 0       NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME ...
# 1       NO EXPOSED HAND SINK FOR REAR SERVICE AREA, IN...
# 2       NO DISH WASHING FACILITIES ON SITE, (NO THREE ...
# 3       MUST PROVIDE OVERHEAD PROTECTION FOR COFFEE/TE...
# 4       FLOORS AT COFFEE/TEA STATIONS MUST BE MADE SMO...
# ...                                                   ...
# 566561  All food and non-food contact equipment and ut...
# 566562  The floors shall be constructed per code, be s...
# 566563  Ventilation: All plumbing fixtures, such as to...
# 566564  All parts of the food establishment and all pa...
# 566565  Ventilation: All plumbing fixtures, such as to...
#
# [566566 rows x 4 columns]

# %%
violations = violation_df[['code', 'description']].drop_duplicates()\
    .sort_values(by='code', key=lambda val: val.astype(int)).reset_index(drop=True)
violations.to_csv("data/tables/violations.csv", index=False)
violations
# Out:
#    code                                        description
# 0     1  SOURCE SOUND CONDITION, NO SPOILAGE, FOODS PRO...
# 1     2          FACILITIES TO MAINTAIN PROPER TEMPERATURE
# 2     3  POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE R...
# 3     4  SOURCE OF CROSS CONTAMINATION CONTROLLED I.E. ...
# 4     5  PERSONNEL WITH INFECTIONS RESTRICTED: NO OPEN ...
# 5     6  HANDS WASHED AND CLEANED, GOOD HYGIENIC PRACTI...
# 6     7  WASH AND RINSE WATER: CLEAN AND PROPER TEMPERA...
# 7     8  SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  ...
# 8     9  WATER SOURCE: SAFE, HOT & COLD UNDER CITY PRES...
# 9    10  SEWAGE AND WASTE WATER DISPOSAL, NO BACK SIPHO...
# 10   11  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIG...
# 11   12  HAND WASHING FACILITIES: WITH SOAP AND SANITAR...
# 12   13  NO EVIDENCE OF RODENT OR INSECT INFESTATION, N...
# 13   14     PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42-090
# 14   15  UNWRAPPED AND POTENTIALLY HAZARDOUS FOOD NOT R...
# 15   16  FOOD PROTECTED DURING STORAGE, PREPARATION, DI...
# 16   17         POTENTIALLY HAZARDOUS FOOD PROPERLY THAWED
# 17   18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 18   19  OUTSIDE GARBAGE WASTE GREASE AND STORAGE AREA;...
# 19   20  INSIDE CONTAINERS OR RECEPTACLES: ADEQUATE NUM...
# 20   21  * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIA...
# 21   22  DISH MACHINES: PROVIDED WITH ACCURATE THERMOME...
# 22   23       DISHES AND UTENSILS FLUSHED, SCRAPED, SOAKED
# 23   24  DISH WASHING FACILITIES: PROPERLY DESIGNED, CO...
# 24   25      TOXIC ITEMS PROPERLY STORED, LABELED AND USED
# 25   26  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, PROPE...
# 26   27  TOILET ROOMS ENCLOSED CLEAN, PROVIDED WITH HAN...
# 27   28  * INSPECTION REPORT SUMMARY DISPLAYED AND VISI...
# 28   29     PREVIOUS MINOR VIOLATION(S) CORRECTED 7-42-090
# 29   30  FOOD IN ORIGINAL CONTAINER, PROPERLY LABELED: ...
# 30   31  CLEAN MULTI-USE UTENSILS AND SINGLE SERVICE AR...
# 31   32  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 32   33  FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS C...
# 33   34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 34   35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 35   36  LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIG...
# 36   37  TOILET ROOM DOORS SELF CLOSING: DRESSING ROOMS...
# 37   38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 38   39            LINEN: CLEAN AND SOILED PROPERLY STORED
# 39   40  REFRIGERATION AND METAL STEM THERMOMETERS PROV...
# 40   41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
# 41   42  APPROPRIATE METHOD OF HANDLING OF FOOD (ICE) H...
# 42   43  FOOD (ICE) DISPENSING UTENSILS, WASH CLOTHS PR...
# 43   44    ONLY AUTHORIZED PERSONNEL IN THE FOOD-PREP AREA
# 44   45                      FOOD HANDLER REQUIREMENTS MET
# 45   70                             NO SMOKING REGULATIONS

# %%
def custom_sorting(x):
    if x.name == 'inspection_id':
        return x.str.replace('-s', '').astype(int)    
    elif x.name == 'code':
        return x.astype(int)
    else:
        return x

inspection_violation = violation_df[['inspection_id', 'code', 'comment']]\
    .sort_values(by=['inspection_id', 'code'], key=custom_sorting, ignore_index=True)\
    .rename(columns={'code': 'violation_code', 'comment': 'violation_comment'})
inspection_violation.to_csv("data/tables/inspection_violation.csv", index=False)
inspection_violation
# Out:
#        inspection_id violation_code  \
# 0              44247             30
# 1              44247             32
# 2              44247             33
# 3              44247             34
# 4              44247             37
# ...              ...            ...
# 566561       2079219             31
# 566562       2079219             32
# 566563       2079219             35
# 566564       2079219             36
# 566565       2079219             38
#
#                                         violation_comment
# 0       All food not stored in the original container ...
# 1       OBSERVED TORN DOOR GASKET ON DOOR OF 'CHILL IS...
# 2       All food and non-food contact surfaces of equi...
# 3       The floors shall be constructed per code, be s...
# 4       Toilet rooms shall be completely enclosed and ...
# ...                                                   ...
# 566561  MUST INVERT MULTIUSE UTENSILS(POTS AND PANS) O...
# 566562  MUST ELIMINATE GROCERY BAGS USED FOR FOOD STOR...
# 566563  MUST CLEAN DUST BUILD UP FROM VENTS IN DINING ...
# 566564  MUST PROVIDE SHATTER PROOF BULBS OR LIGHT SHIE...
# 566565       MUST PROVIDE A BACK FLOW DEVICE ON MOP SINK.
#
# [566566 rows x 3 columns]

# %% [markdown]
# Again, note that a certain inspection_id/violation code combination can have multiple comments. For example:

# %%
inspection_violation[inspection_violation['inspection_id']=='160390-s']
# Out:
#       inspection_id violation_code  \
# 23648      160390-s             32
# 23649      160390-s             32
# 23650      160390-s             33
# 23651      160390-s             34
# 23652      160390-s             34
# 23653      160390-s             35
# 23654      160390-s             35
#
#                                        violation_comment
# 23648  All food and non-food contact equipment and ut...
# 23649  All food and non-food contact equipment and ut...
# 23650  All food and non-food contact surfaces of equi...
# 23651  The floors shall be constructed per code, be s...
# 23652  The floors shall be constructed per code, be s...
# 23653  The walls and ceilings shall be in good repair...
# 23654  The walls and ceilings shall be in good repair...
