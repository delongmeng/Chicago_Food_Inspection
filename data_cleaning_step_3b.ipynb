# %% [markdown]
# **U1 (Target Use Case):**
# One could use this dataset to investigate whether different neighborhoods (indicated by zip code or geographic regions) have distinct food safety patterns, such as passing rate, complaint rate, risks, violations, and violation types, and further stratify the data by other factors (such as facility types and time range).

# %%
import pandas as pd
import numpy as np
import re
import string

# %%
input_data = pd.read_csv("data/open_refine_processed/Food-Inspections-openrefine.csv")
input_data.head()
# Out:
#    Inspection ID                 DBA Name                 AKA Name  License #  \
# 0        2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517328.0
# 1        2079129              JET'S PIZZA              JET'S PIZZA  2522268.0
# 2        2079125                ROOM 1520                ROOM 1520  2446638.0
# 3        2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517338.0
# 4        2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS  2549079.0
#
#     Facility Type Facility Type Cleaned             Risk  \
# 0      Restaurant            restaurant    Risk 1 (High)
# 1      Restaurant            restaurant  Risk 2 (Medium)
# 2   Special Event         special event     Risk 3 (Low)
# 3      Restaurant            restaurant    Risk 1 (High)
# 4  CHARTER SCHOOL                school    Risk 1 (High)
#
#                 Address     City State      Zip Inspection Date  \
# 0   2121 S PRAIRIE AVE   CHICAGO    IL  60616.0      08/28/2017
# 1    1025 W MADISON ST   CHICAGO    IL  60607.0      08/28/2017
# 2     301 N JUSTINE ST   CHICAGO    IL  60607.0      08/28/2017
# 3   2121 S PRAIRIE AVE   CHICAGO    IL  60616.0      08/28/2017
# 4  2245 N MCVICKER AVE   CHICAGO    IL  60639.0      08/28/2017
#
#   Inspection Date Transformed        Inspection Type Inspection Type Cleaned  \
# 0                  2017-08-28                License                 license
# 1                  2017-08-28                License                 license
# 2                  2017-08-28  License Re-Inspection   license re-inspection
# 3                  2017-08-28                License                 license
# 4                  2017-08-28  License Re-Inspection   license re-inspection
#
#      Results                                         Violations   Latitude  \
# 0       Pass                                                NaN  41.853651
# 1  Not Ready                                                NaN  41.881572
# 2  Not Ready  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       Pass  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       Pass  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
#
#    Longitude                                  Location
# 0 -87.620534  (41.853650885040594, -87.62053358114167)
# 1 -87.653052   (41.88157249576794, -87.65305233593274)
# 2 -87.665328   (41.88657652150854, -87.66532812140231)
# 3 -87.620534  (41.853650885040594, -87.62053358114167)
# 4 -87.776711   (41.921675488910864, -87.7767113569357)

# %%
input_data = input_data.drop(columns=['Facility Type', 'Inspection Date', 'Inspection Type']).rename(columns={
    'Facility Type Cleaned': 'Facility Type', 
    'Inspection Date Transformed': 'Inspection Date', 
    'Inspection Type Cleaned': 'Inspection Type'
})
input_data.head()
# Out:
#    Inspection ID                 DBA Name                 AKA Name  License #  \
# 0        2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517328.0
# 1        2079129              JET'S PIZZA              JET'S PIZZA  2522268.0
# 2        2079125                ROOM 1520                ROOM 1520  2446638.0
# 3        2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO  2517338.0
# 4        2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS  2549079.0
#
#    Facility Type             Risk               Address     City State  \
# 0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL
# 1     restaurant  Risk 2 (Medium)    1025 W MADISON ST   CHICAGO    IL
# 2  special event     Risk 3 (Low)     301 N JUSTINE ST   CHICAGO    IL
# 3     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL
# 4         school    Risk 1 (High)  2245 N MCVICKER AVE   CHICAGO    IL
#
#        Zip Inspection Date        Inspection Type    Results  \
# 0  60616.0      2017-08-28                license       Pass
# 1  60607.0      2017-08-28                license  Not Ready
# 2  60607.0      2017-08-28  license re-inspection  Not Ready
# 3  60616.0      2017-08-28                license       Pass
# 4  60639.0      2017-08-28  license re-inspection       Pass
#
#                                           Violations   Latitude  Longitude  \
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711
#
#                                    Location
# 0  (41.853650885040594, -87.62053358114167)
# 1   (41.88157249576794, -87.65305233593274)
# 2   (41.88657652150854, -87.66532812140231)
# 3  (41.853650885040594, -87.62053358114167)
# 4   (41.921675488910864, -87.7767113569357)

# %% [markdown]
# ## 1. basic data exploration and cleaning

# %% [markdown]
# **[exploration]**
# Check data types and convert data types:

# %%
input_data.dtypes
# Out:
# Inspection ID        int64
# DBA Name            object
# AKA Name            object
# License #          float64
# Facility Type       object
# Risk                object
# Address             object
# City                object
# State               object
# Zip                float64
# Inspection Date     object
# Inspection Type     object
# Results             object
# Violations          object
# Latitude           float64
# Longitude          float64
# Location            object
# dtype: object

# %%
input_data['Inspection ID'] = input_data['Inspection ID'].astype(str)
input_data['License #'] = input_data['License #'].astype(str)
input_data['License #'] = input_data['License #'].str.strip('.0')
input_data['Zip'] = input_data['Zip'].astype(str)
input_data['Zip'] = input_data['Zip'].str.strip('.0')
input_data['Inspection Date'] = pd.to_datetime(input_data['Inspection Date'])
input_data.dtypes
# Out:
# Inspection ID              object
# DBA Name                   object
# AKA Name                   object
# License #                  object
# Facility Type              object
# Risk                       object
# Address                    object
# City                       object
# State                      object
# Zip                        object
# Inspection Date    datetime64[ns]
# Inspection Type            object
# Results                    object
# Violations                 object
# Latitude                  float64
# Longitude                 float64
# Location                   object
# dtype: object

# %% [markdown]
# **[exploration]**
# Check missing values:

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Inspection ID    153810 non-null  object
#  1   DBA Name         153810 non-null  object
#  2   AKA Name         151267 non-null  object
#  3   License #        153810 non-null  object
#  4   Facility Type    149250 non-null  object
#  5   Risk             153744 non-null  object
#  6   Address          153810 non-null  object
#  7   City             153651 non-null  object
#  8   State            153802 non-null  object
#  9   Zip              153810 non-null  object
#  10  Inspection Date  153810 non-null  datetime64[ns]
#  11  Inspection Type  153809 non-null  object
#  12  Results          153810 non-null  object
#  13  Violations       123012 non-null  object
#  14  Latitude         153266 non-null  float64
#  15  Longitude        153266 non-null  float64
#  16  Location         153266 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(14)
# memory usage: 19.9+ MB

# %%
input_data.isnull().sum()
# Out:
# Inspection ID          0
# DBA Name               0
# AKA Name            2543
# License #              0
# Facility Type       4560
# Risk                  66
# Address                0
# City                 159
# State                  8
# Zip                    0
# Inspection Date        0
# Inspection Type        1
# Results                0
# Violations         30798
# Latitude             544
# Longitude            544
# Location             544
# dtype: int64

# %% [markdown]
# **[exploration]**
# Check whether the "location" column has the same information with the "Latitude" and "Longitude" columns:

# %%
def check_location(x):
    result = True
    e = 10e-5
    if (not pd.isnull(x['Location'])) and len(x['Location']) > 0:
        la, lo = x['Location'].strip('(|)').split(',')
        la, lo = float(la), float(lo)
        result = (abs(la - x['Latitude']) < e) and (abs(lo - x['Longitude']) < e)
    return result
    
sum(input_data.apply(check_location, axis=1)) == len(input_data)
# Out:
# True

# %% [markdown]
# **[cleaning]**
# So let's remove the "location" column since it does not provide any additional information:

# %%
input_data.drop(columns='Location', inplace=True)

# %%
input_data.head()
# Out:
#   Inspection ID                 DBA Name                 AKA Name License #  \
# 0       2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO   2517328
# 1       2079129              JET'S PIZZA              JET'S PIZZA   2522268
# 2       2079125                ROOM 1520                ROOM 1520   2446638
# 3       2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO   2517338
# 4       2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS   2549079
#
#    Facility Type             Risk               Address     City State    Zip  \
# 0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL  60616
# 1     restaurant  Risk 2 (Medium)    1025 W MADISON ST   CHICAGO    IL  60607
# 2  special event     Risk 3 (Low)     301 N JUSTINE ST   CHICAGO    IL  60607
# 3     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE   CHICAGO    IL  60616
# 4         school    Risk 1 (High)  2245 N MCVICKER AVE   CHICAGO    IL  60639
#
#   Inspection Date        Inspection Type    Results  \
# 0      2017-08-28                license       Pass
# 1      2017-08-28                license  Not Ready
# 2      2017-08-28  license re-inspection  Not Ready
# 3      2017-08-28                license       Pass
# 4      2017-08-28  license re-inspection       Pass
#
#                                           Violations   Latitude  Longitude
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711

# %% [markdown]
# **[cleaning]**
# Clean up strings:

# %%
def clean_strings(x):
    return x.upper().replace('.', '').replace(',', '').replace("'", '').strip() if (not pd.isnull(x)) else x

for column in ['DBA Name', 'AKA Name', 'Address']:
    input_data[column] = input_data[column].apply(clean_strings)

input_data.head()
# Out:
#   Inspection ID                 DBA Name                 AKA Name License #  \
# 0       2079132  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO   2517328
# 1       2079129               JETS PIZZA               JETS PIZZA   2522268
# 2       2079125                ROOM 1520                ROOM 1520   2446638
# 3       2079123  MARRIOT MARQUIS CHICAGO  MARRIOT MARQUIS CHICAGO   2517338
# 4       2079105               CHARTWELLS  CICS WEST BELDEN CAMPUS   2549079
#
#    Facility Type             Risk              Address     City State    Zip  \
# 0     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1     restaurant  Risk 2 (Medium)    1025 W MADISON ST  CHICAGO    IL  60607
# 2  special event     Risk 3 (Low)     301 N JUSTINE ST  CHICAGO    IL  60607
# 3     restaurant    Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         school    Risk 1 (High)  2245 N MCVICKER AVE  CHICAGO    IL  60639
#
#   Inspection Date        Inspection Type    Results  \
# 0      2017-08-28                license       Pass
# 1      2017-08-28                license  Not Ready
# 2      2017-08-28  license re-inspection  Not Ready
# 3      2017-08-28                license       Pass
# 4      2017-08-28  license re-inspection       Pass
#
#                                           Violations   Latitude  Longitude
# 0                                                NaN  41.853651 -87.620534
# 1                                                NaN  41.881572 -87.653052
# 2  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577 -87.665328
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651 -87.620534
# 4  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675 -87.776711

# %% [markdown]
# **[exploaration]**
# Further check if there are different variations of Addresses for the same facility and location (Latitude & Longitude):

# %%
temp = input_data[['DBA Name','AKA Name', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
address_duplicated = temp.groupby(
    by=['DBA Name','AKA Name', 'City', 'State', 'Zip', 'Latitude', 'Longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by='AKA Name', ascending=False)
address_duplicated
# Out:
#                                       DBA Name  \
# 13530   YOUNG SCHOLARS DEVELOPMENTAL INSTITUTE
# 112142  YOUNG SCHOLARS DEVELOPMENTAL INSTITUTE
# 23888             WHIZ KIDS NURSERY CENTER INC
# 125266            WHIZ KIDS NURSERY CENTER INC
# 147287                    WHALE FISH & CHICKEN
# ...                                        ...
# 130658                 3 RS ORIENTAL FOOD MART
# 111443                        PAPA TS ITALIANO
# 111478                        PAPA TS ITALIANO
# 134985                         OBAMA FOOD MART
# 153320                         OBAMA FOOD MART
#
#                                       AKA Name                 Address  \
# 13530   YOUNG SCHOLARS DEVELOPMENTAL INSTITUTE   3038 - 3046 W 59TH ST
# 112142  YOUNG SCHOLARS DEVELOPMENTAL INSTITUTE          3038 W 59TH ST
# 23888             WHIZ KIDS NURSERY CENTER INC      514-522 W 103RD ST
# 125266            WHIZ KIDS NURSERY CENTER INC      514-518 W 103RD ST
# 147287                    WHALE FISH & CHICKEN      5650 W DIVISION ST
# ...                                        ...                     ...
# 130658                 3 RS ORIENTAL FOOD MART  2712-14 W MONTROSE AVE
# 111443                                     NaN          2843 W 63RD ST
# 111478                                     NaN            2843 W 63 ST
# 134985                                     NaN     1800 E 79TH ST BLDG
# 153320                                     NaN          1800 E 79TH ST
#
#             City State    Zip   Latitude  Longitude
# 13530    CHICAGO    IL  60629  41.786411 -87.700009
# 112142   CHICAGO    IL  60629  41.786411 -87.700009
# 23888    CHICAGO    IL  60628  41.707113 -87.636204
# 125266   CHICAGO    IL  60628  41.707113 -87.636204
# 147287   CHICAGO    IL  60651  41.902223 -87.767688
# ...          ...   ...    ...        ...        ...
# 130658   CHICAGO    IL  60618  41.961371 -87.696669
# 111443  INACTIVE    IL  60629  41.778981 -87.695090
# 111478  INACTIVE    IL  60629  41.778981 -87.695090
# 134985   CHICAGO    IL  60649  41.751655 -87.580828
# 153320   CHICAGO    IL  60649  41.751655 -87.580828
#
# [238 rows x 8 columns]

# %% [markdown]
# **[cleaning]**
# Let's clean up the "Address" column for these situations. We'll just use the Address from the first record for the duplicated records:

# %%
address_dedup = address_duplicated.drop_duplicates(subset=['DBA Name','AKA Name', 'City', 'State', 'Zip', 'Latitude', 'Longitude'], keep='first')
address_dedup
# Out:
#                                       DBA Name  \
# 13530   YOUNG SCHOLARS DEVELOPMENTAL INSTITUTE
# 23888             WHIZ KIDS NURSERY CENTER INC
# 147287                    WHALE FISH & CHICKEN
# 19545                                 WAKAMONO
# 11261                          UNCOMMON GROUND
# ...                                        ...
# 101751                             ALWAYS THAI
# 59294                                 7-ELEVEN
# 130661                 3 RS ORIENTAL FOOD MART
# 111443                        PAPA TS ITALIANO
# 134985                         OBAMA FOOD MART
#
#                                       AKA Name                   Address  \
# 13530   YOUNG SCHOLARS DEVELOPMENTAL INSTITUTE     3038 - 3046 W 59TH ST
# 23888             WHIZ KIDS NURSERY CENTER INC        514-522 W 103RD ST
# 147287                    WHALE FISH & CHICKEN        5650 W DIVISION ST
# 19545                                 WAKAMONO      3313-3319 N BROADWAY
# 11261                          UNCOMMON GROUND      3800-3804 N CLARK ST
# ...                                        ...                       ...
# 101751                             ALWAYS THAI     1825 W IRVING PARK RD
# 59294                                 7-ELEVEN       535 S STATE ST BLDG
# 130661                 3 RS ORIENTAL FOOD MART  2712-2714 W MONTROSE AVE
# 111443                                     NaN            2843 W 63RD ST
# 134985                                     NaN       1800 E 79TH ST BLDG
#
#             City State    Zip   Latitude  Longitude
# 13530    CHICAGO    IL  60629  41.786411 -87.700009
# 23888    CHICAGO    IL  60628  41.707113 -87.636204
# 147287   CHICAGO    IL  60651  41.902223 -87.767688
# 19545    CHICAGO    IL  60657  41.942313 -87.644322
# 11261    CHICAGO    IL  60613  41.951064 -87.659795
# ...          ...   ...    ...        ...        ...
# 101751   CHICAGO    IL  60613  41.954093 -87.675195
# 59294    CHICAGO    IL  60605  41.875011 -87.627475
# 130661   CHICAGO    IL  60618  41.961371 -87.696669
# 111443  INACTIVE    IL  60629  41.778981 -87.695090
# 134985   CHICAGO    IL  60649  41.751655 -87.580828
#
# [118 rows x 8 columns]

# %%
address_to_check = list(set(address_duplicated['Address']))

def clean_address(x):
    address = x['Address']
    if address in address_to_check:
        dba, aka, city, state, zip_, la, lo = x['DBA Name'], x['AKA Name'], x['City'], x['State'], x['Zip'], x['Latitude'], x['Longitude']
        temp = address_dedup[(address_dedup['DBA Name']==dba) &
                     (pd.isnull(address_dedup['AKA Name']) | (address_dedup['AKA Name']==aka)) &
                     (address_dedup['City']==city) &
                     (address_dedup['State']==state) &
                     (address_dedup['Zip']==zip_) &
                     (address_dedup['Latitude']==la) &
                     (address_dedup['Longitude']==lo)]
        if len(temp) == 1:
            address = temp['Address'].values[0]

    return address
        
input_data['Address'] = input_data.apply(clean_address, axis=1)
input_data
# Out:
#        Inspection ID                      DBA Name  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             AKA Name License #  Facility Type  \
# 0            MARRIOT MARQUIS CHICAGO   2517328     restaurant
# 1                         JETS PIZZA   2522268     restaurant
# 2                          ROOM 1520   2446638  special event
# 3            MARRIOT MARQUIS CHICAGO   2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS   2549079         school
# ...                              ...       ...            ...
# 153805                       TROQUET   1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS   1380279     restaurant
# 153807                      CAFE 608   2013328     restaurant
# 153808                     MRDANIELS   1899292     restaurant
# 153809                    TEMPO CAFE     80916     restaurant
#
#                    Risk              Address     City State    Zip  \
# 0         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)    1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)     301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)  2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                  ...      ...   ...    ...
# 153805    Risk 1 (High)  1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)    100 W RANDOLPH ST  CHICAGO    IL  60601
# 153807    Risk 1 (High)      608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)   5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)      6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        Inspection Date        Inspection Type    Results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                Violations   Latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         Longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data[['DBA Name','AKA Name', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
temp.groupby(
    by=['DBA Name','AKA Name', 'City', 'State', 'Zip', 'Latitude', 'Longitude'], dropna=False)\
    .filter(lambda x: len(x) > 1).sort_values(by='AKA Name', ascending=False)
# Out:
# Empty DataFrame
# Columns: [DBA Name, AKA Name, Address, City, State, Zip, Latitude, Longitude]
# Index: []

# %% [markdown]
# **[exploration]**
# Check the Risk column:
# For the same facility, do they have conflicting Risk status?
# Note that it is possible the Risk level could change by time. I checked and confirmed that even on the same date, most of the following records still have conflicting Risk status.

# %%
temp = input_data[['License #', 'DBA Name', 'AKA Name', 'Address', 'Risk']].drop_duplicates()
duplicated_risk = temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Address'], keep=False)].sort_values(by='License #')
duplicated_risk
# Out:
#        License #                    DBA Name                    AKA Name  \
# 127712                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 127627                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 35736    1578736    MT ARARAT DAYCARE CENTER    MT ARARAT DAYCARE CENTER
# 35751    1578736    MT ARARAT DAYCARE CENTER    MT ARARAT DAYCARE CENTER
# 33799    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 131692   1739775     ROTISSERIE ENT & ANNETS     ROTISSERIE ENT & ANNETS
# 131690   1739775     ROTISSERIE ENT & ANNETS     ROTISSERIE ENT & ANNETS
# 2313     1947909                      SUBWAY                      SUBWAY
# 115550   1947909                      SUBWAY                      SUBWAY
# 80181    1954774        WELLS STREET POPCORN        WELLS STREET POPCORN
# 80180    1954774        WELLS STREET POPCORN        WELLS STREET POPCORN
# 87109    1974918                ATINOS PIZZA                ATINOS PIZZA
# 87107    1974918                ATINOS PIZZA                ATINOS PIZZA
# 84339    2013962             KENDALL COLLEGE     LAB KITCHEN B-ROOM 120B
# 69370    2013962             KENDALL COLLEGE     LAB KITCHEN B-ROOM 120B
# 145952   2031677                 PORK SHOPPE                 PORK SHOPPE
# 145463   2031677                 PORK SHOPPE                 PORK SHOPPE
# 140399    203223               MORE CUPCAKES               MORE CUPCAKES
# 108154    203223               MORE CUPCAKES               MORE CUPCAKES
# 136375   2069823                BOOST MOBILE                BOOST MOBILE
# 136112   2069823                BOOST MOBILE                BOOST MOBILE
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 100153   2073639                THE SOUTHERN                THE SOUTHERN
# 109207   2098831                 TRENCHERMEN                 TRENCHERMEN
# 81071    2098831                 TRENCHERMEN                 TRENCHERMEN
# 121526   2113684                     WOW BAO                     WOW BAO
# 122235   2113684                     WOW BAO                     WOW BAO
# 111465   2152257                   TACO BELL                   TACO BELL
# 53947    2152257                   TACO BELL                   TACO BELL
# 87760    2240275             PARTS AND LABOR             PARTS AND LABOR
# 79447    2240275             PARTS AND LABOR             PARTS AND LABOR
# 86762    2278041               COBBLERS CAFE                         NaN
# 52251    2278041               COBBLERS CAFE                         NaN
# 47286    2321266               ROSATIS PIZZA               ROSATIS PIZZA
# 69730    2321266               ROSATIS PIZZA               ROSATIS PIZZA
# 6180      233315            GREENLINE COFFEE            GREENLINE COFFEE
# 69712     233315            GREENLINE COFFEE            GREENLINE COFFEE
# 54179    2368585         VIA LIMA RESTAURANT         VIA LIMA RESTAURANT
# 50857    2368585         VIA LIMA RESTAURANT         VIA LIMA RESTAURANT
# 4958     2510999                     EVELYNS                     EVELYNS
# 9226     2510999                     EVELYNS                     EVELYNS
# 3143     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
# 4213     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                         Address             Risk
# 127712          600 E GRAND AVE     Risk 3 (Low)
# 127627          600 E GRAND AVE  Risk 2 (Medium)
# 35736   6514-6516 W HIGGINS AVE    Risk 1 (High)
# 35751   6514-6516 W HIGGINS AVE     Risk 3 (Low)
# 33799      5605-5609 N CLARK ST    Risk 1 (High)
# 85087      5605-5609 N CLARK ST     Risk 3 (Low)
# 131692        2009 N BISSELL ST  Risk 2 (Medium)
# 131690        2009 N BISSELL ST     Risk 3 (Low)
# 2313          6450 S PULASKI RD    Risk 1 (High)
# 115550        6450 S PULASKI RD     Risk 3 (Low)
# 80181           2804 N CLARK ST  Risk 2 (Medium)
# 80180           2804 N CLARK ST     Risk 3 (Low)
# 87109       4610 W DIVERSEY AVE    Risk 1 (High)
# 87107       4610 W DIVERSEY AVE     Risk 3 (Low)
# 84339     900 N NORTH BRANCH ST    Risk 1 (High)
# 69370     900 N NORTH BRANCH ST     Risk 3 (Low)
# 145952       2755 W BELMONT AVE     Risk 3 (Low)
# 145463       2755 W BELMONT AVE    Risk 1 (High)
# 140399          1 E DELAWARE PL  Risk 2 (Medium)
# 108154          1 E DELAWARE PL     Risk 3 (Low)
# 136375   4731 1/2 S ASHLAND AVE              NaN
# 136112   4731 1/2 S ASHLAND AVE     Risk 3 (Low)
# 134516    1840-1842 W NORTH AVE    Risk 1 (High)
# 100153    1840-1842 W NORTH AVE  Risk 2 (Medium)
# 109207         2039 W NORTH AVE     Risk 3 (Low)
# 81071          2039 W NORTH AVE    Risk 1 (High)
# 121526       175 W JACKSON BLVD     Risk 3 (Low)
# 122235       175 W JACKSON BLVD    Risk 1 (High)
# 111465           1646 W 95TH ST  Risk 2 (Medium)
# 53947            1646 W 95TH ST    Risk 1 (High)
# 87760      2700 N MILWAUKEE AVE     Risk 3 (Low)
# 79447      2700 N MILWAUKEE AVE    Risk 1 (High)
# 86762        7036 S WESTERN AVE              NaN
# 52251        7036 S WESTERN AVE  Risk 2 (Medium)
# 47286           4863 N BROADWAY     Risk 3 (Low)
# 69730           4863 N BROADWAY    Risk 1 (High)
# 6180              501 E 61ST ST  Risk 2 (Medium)
# 69712             501 E 61ST ST              NaN
# 54179        4024 N LINCOLN AVE              NaN
# 50857        4024 N LINCOLN AVE    Risk 1 (High)
# 4958            5522 S STATE ST    Risk 1 (High)
# 9226            5522 S STATE ST              NaN
# 3143           500 W MADISON ST  Risk 2 (Medium)
# 4213           500 W MADISON ST              All

# %% [markdown]
# **[cleaning]**
# Let's clean up the "Risk" column for these situations:
# - Infer and add back missing values: For facilities that have a certain level and "NaN", we'll replace the "NaN" with the Risk level.
# - Make conflicting values invalid: For facilities that have multiple non-"NaN" levels, we'll replace all of them with "NaN".

# %%
def combine_risk(x):
    non_nan_risks = list(set(x) - set([np.nan]))
    return non_nan_risks[0] if len(non_nan_risks) == 1 else np.nan

risk_dedup = duplicated_risk.groupby(by=['License #', 'DBA Name', 'AKA Name', 'Address'], dropna=False)['Risk'].agg(combine_risk).rename('Risk').reset_index()
risk_dedup
# Out:
#    License #                    DBA Name                    AKA Name  \
# 0                         FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 1    1578736    MT ARARAT DAYCARE CENTER    MT ARARAT DAYCARE CENTER
# 2    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 3    1739775     ROTISSERIE ENT & ANNETS     ROTISSERIE ENT & ANNETS
# 4    1947909                      SUBWAY                      SUBWAY
# 5    1954774        WELLS STREET POPCORN        WELLS STREET POPCORN
# 6    1974918                ATINOS PIZZA                ATINOS PIZZA
# 7    2013962             KENDALL COLLEGE     LAB KITCHEN B-ROOM 120B
# 8    2031677                 PORK SHOPPE                 PORK SHOPPE
# 9     203223               MORE CUPCAKES               MORE CUPCAKES
# 10   2069823                BOOST MOBILE                BOOST MOBILE
# 11   2073639                THE SOUTHERN                THE SOUTHERN
# 12   2098831                 TRENCHERMEN                 TRENCHERMEN
# 13   2113684                     WOW BAO                     WOW BAO
# 14   2152257                   TACO BELL                   TACO BELL
# 15   2240275             PARTS AND LABOR             PARTS AND LABOR
# 16   2278041               COBBLERS CAFE                         NaN
# 17   2321266               ROSATIS PIZZA               ROSATIS PIZZA
# 18    233315            GREENLINE COFFEE            GREENLINE COFFEE
# 19   2368585         VIA LIMA RESTAURANT         VIA LIMA RESTAURANT
# 20   2510999                     EVELYNS                     EVELYNS
# 21   2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                     Address             Risk
# 0           600 E GRAND AVE              NaN
# 1   6514-6516 W HIGGINS AVE              NaN
# 2      5605-5609 N CLARK ST              NaN
# 3         2009 N BISSELL ST              NaN
# 4         6450 S PULASKI RD              NaN
# 5           2804 N CLARK ST              NaN
# 6       4610 W DIVERSEY AVE              NaN
# 7     900 N NORTH BRANCH ST              NaN
# 8        2755 W BELMONT AVE              NaN
# 9           1 E DELAWARE PL              NaN
# 10   4731 1/2 S ASHLAND AVE     Risk 3 (Low)
# 11    1840-1842 W NORTH AVE              NaN
# 12         2039 W NORTH AVE              NaN
# 13       175 W JACKSON BLVD              NaN
# 14           1646 W 95TH ST              NaN
# 15     2700 N MILWAUKEE AVE              NaN
# 16       7036 S WESTERN AVE  Risk 2 (Medium)
# 17          4863 N BROADWAY              NaN
# 18            501 E 61ST ST  Risk 2 (Medium)
# 19       4024 N LINCOLN AVE    Risk 1 (High)
# 20          5522 S STATE ST    Risk 1 (High)
# 21         500 W MADISON ST              NaN

# %%
license_to_check, dba_to_check, address_to_check = list(risk_dedup['License #']), list(risk_dedup['DBA Name']), list(risk_dedup['Address'])

def clean_risk(x):
    license, dba, aka, address, risk = x['License #'], x['DBA Name'], x['AKA Name'], x['Address'], x['Risk']
    if (license in license_to_check) and (dba in dba_to_check) and (address in address_to_check):
        temp = risk_dedup[(risk_dedup['License #']==license) &
                     (risk_dedup['DBA Name']==dba) &
                     (pd.isnull(risk_dedup['AKA Name']) | (risk_dedup['AKA Name']==aka)) &
                     (risk_dedup['Address']==address)]
        if len(temp) == 1:
            risk = temp['Risk'].values[0]

    return risk
        
input_data['Risk'] = input_data.apply(clean_risk, axis=1)
input_data
# Out:
#        Inspection ID                      DBA Name  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153805         67732                      WOLCOTTS
# 153806         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153807         52234                      CAFE 608
# 153808         70269                     MRDANIELS
# 153809        104236                    TEMPO CAFE
#
#                             AKA Name License #  Facility Type  \
# 0            MARRIOT MARQUIS CHICAGO   2517328     restaurant
# 1                         JETS PIZZA   2522268     restaurant
# 2                          ROOM 1520   2446638  special event
# 3            MARRIOT MARQUIS CHICAGO   2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS   2549079         school
# ...                              ...       ...            ...
# 153805                       TROQUET   1992039     restaurant
# 153806  DUNKIN DONUTS/BASKIN-ROBBINS   1380279     restaurant
# 153807                      CAFE 608   2013328     restaurant
# 153808                     MRDANIELS   1899292     restaurant
# 153809                    TEMPO CAFE     80916     restaurant
#
#                    Risk              Address     City State    Zip  \
# 0         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)    1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)     301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)  2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                  ...      ...   ...    ...
# 153805    Risk 1 (High)  1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153806  Risk 2 (Medium)    100 W RANDOLPH ST  CHICAGO    IL  60601
# 153807    Risk 1 (High)      608 W BARRY AVE  CHICAGO    IL  60657
# 153808    Risk 1 (High)   5645 W BELMONT AVE  CHICAGO    IL  60634
# 153809    Risk 1 (High)      6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        Inspection Date        Inspection Type    Results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153805      2010-01-04  license re-inspection       Pass
# 153806      2010-01-04            tag removal       Pass
# 153807      2010-01-04  license re-inspection       Pass
# 153808      2010-01-04  license re-inspection       Pass
# 153809      2010-01-04                canvass       Fail
#
#                                                Violations   Latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153805  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153806                                                NaN  41.884586
# 153807  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153808  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153809  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         Longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153805 -87.675967
# 153806 -87.631010
# 153807 -87.644755
# 153808 -87.768318
# 153809 -87.628009
#
# [153810 rows x 16 columns]

# %% [markdown]
# Confirm the change:

# %%
temp = input_data[['License #', 'DBA Name', 'AKA Name', 'Address', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Address'], keep=False)].sort_values(by='License #')
# Out:
# Empty DataFrame
# Columns: [License #, DBA Name, AKA Name, Address, Risk]
# Index: []

# %% [markdown]
# **[exploration]**
# Check that all inspection IDs are unique:

# %%
len(set(input_data['Inspection ID'])) == len(list(input_data['Inspection ID']))
# Out:
# True

# %% [markdown]
# **[exploration]**
# However, if we ignore the inspection ID, there seem to be duplicated records:

# %%
input_data[input_data[list(input_data)[1:]].duplicated(keep=False)]
# Out:
#        Inspection ID                     DBA Name  \
# 2084         2069297           PICOSITO GRILL-BAR
# 2138         2064677           PICOSITO GRILL-BAR
# 3648         2015324            METAL HAVEN GRILL
# 3694         2050813            METAL HAVEN GRILL
# 7507         2010211           LOOMIS FOOD MARKET
# ...              ...                          ...
# 152903         68271  DE ARCOS PIZZA & RESTAURANT
# 153108         88223                ASPIRA HAUGAN
# 153109         88222                ASPIRA HAUGAN
# 153113        158274              ARGENTINA FOODS
# 153114        158273              ARGENTINA FOODS
#
#                            AKA Name License # Facility Type             Risk  \
# 2084             PICOSITO GRILL-BAR   2158267    restaurant    Risk 1 (High)
# 2138             PICOSITO GRILL-BAR   2158267    restaurant    Risk 1 (High)
# 3648              METAL HAVEN GRILL   2457868    restaurant    Risk 1 (High)
# 3694              METAL HAVEN GRILL   2457868    restaurant    Risk 1 (High)
# 7507             LOOMIS FOOD MARKET   2004423       grocery  Risk 2 (Medium)
# ...                             ...       ...           ...              ...
# 152903  DE ARCOS PIZZA & RESTAURANT   1577283    restaurant    Risk 1 (High)
# 153108  ASPIRA HAUGAN MIDDLE SCHOOL     66351        school    Risk 1 (High)
# 153109  ASPIRA HAUGAN MIDDLE SCHOOL     66351        school    Risk 1 (High)
# 153113              ARGENTINA FOODS     57047       grocery  Risk 2 (Medium)
# 153114              ARGENTINA FOODS     57047       grocery  Risk 2 (Medium)
#
#                      Address     City State    Zip Inspection Date  \
# 2084    3553-3559 E 100TH ST  CHICAGO    IL  60617      2017-06-21
# 2138    3553-3559 E 100TH ST  CHICAGO    IL  60617      2017-06-21
# 3648    3835 W FULLERTON AVE  CHICAGO    IL  60647      2017-05-22
# 3694    3835 W FULLERTON AVE  CHICAGO    IL  60647      2017-05-22
# 7507      6859 S LOOMIS BLVD  CHICAGO    IL  60636      2017-03-14
# ...                      ...      ...   ...    ...             ...
# 152903        2832 E 87TH ST  CHICAGO    IL  60617      2010-01-22
# 153108     3729 W LELAND AVE  CHICAGO    IL  60625      2010-01-20
# 153109     3729 W LELAND AVE  CHICAGO    IL  60625      2010-01-20
# 153113        4500 S WOOD ST  CHICAGO    IL  60609      2010-01-20
# 153114        4500 S WOOD ST  CHICAGO    IL  60609      2010-01-20
#
#         Inspection Type          Results Violations   Latitude  Longitude
# 2084            canvass         No Entry        NaN  41.713767 -87.536796
# 2138            canvass         No Entry        NaN  41.713767 -87.536796
# 3648            canvass  Out of Business        NaN  41.924416 -87.723320
# 3694            canvass  Out of Business        NaN  41.924416 -87.723320
# 7507          complaint         No Entry        NaN  41.768716 -87.658922
# ...                 ...              ...        ...        ...        ...
# 152903      tag removal             Pass        NaN  41.737447 -87.555039
# 153108          canvass             Pass        NaN  41.966378 -87.721826
# 153109          canvass             Pass        NaN  41.966378 -87.721826
# 153113  out of business             Fail        NaN  41.812105 -87.670072
# 153114  out of business             Fail        NaN  41.812105 -87.670072
#
# [175 rows x 16 columns]

# %% [markdown]
# **[cleaning]**
# There are 175 records that contain duplicated information. For example, inspection #2069297 and #2064677 are exactly the same except for the inspection ID itself. For the purpose of our target use case, we don't need those repeated records, so we'll remove them:

# %%
input_data = input_data.drop_duplicates(subset=list(input_data)[1:], ignore_index=True)
input_data
# Out:
#        Inspection ID                      DBA Name  \
# 0            2079132       MARRIOT MARQUIS CHICAGO
# 1            2079129                    JETS PIZZA
# 2            2079125                     ROOM 1520
# 3            2079123       MARRIOT MARQUIS CHICAGO
# 4            2079105                    CHARTWELLS
# ...              ...                           ...
# 153712         67732                      WOLCOTTS
# 153713         67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 153714         52234                      CAFE 608
# 153715         70269                     MRDANIELS
# 153716        104236                    TEMPO CAFE
#
#                             AKA Name License #  Facility Type  \
# 0            MARRIOT MARQUIS CHICAGO   2517328     restaurant
# 1                         JETS PIZZA   2522268     restaurant
# 2                          ROOM 1520   2446638  special event
# 3            MARRIOT MARQUIS CHICAGO   2517338     restaurant
# 4            CICS WEST BELDEN CAMPUS   2549079         school
# ...                              ...       ...            ...
# 153712                       TROQUET   1992039     restaurant
# 153713  DUNKIN DONUTS/BASKIN-ROBBINS   1380279     restaurant
# 153714                      CAFE 608   2013328     restaurant
# 153715                     MRDANIELS   1899292     restaurant
# 153716                    TEMPO CAFE     80916     restaurant
#
#                    Risk              Address     City State    Zip  \
# 0         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 1       Risk 2 (Medium)    1025 W MADISON ST  CHICAGO    IL  60607
# 2          Risk 3 (Low)     301 N JUSTINE ST  CHICAGO    IL  60607
# 3         Risk 1 (High)   2121 S PRAIRIE AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)  2245 N MCVICKER AVE  CHICAGO    IL  60639
# ...                 ...                  ...      ...   ...    ...
# 153712    Risk 1 (High)  1834 W MONTROSE AVE  CHICAGO    IL  60613
# 153713  Risk 2 (Medium)    100 W RANDOLPH ST  CHICAGO    IL  60601
# 153714    Risk 1 (High)      608 W BARRY AVE  CHICAGO    IL  60657
# 153715    Risk 1 (High)   5645 W BELMONT AVE  CHICAGO    IL  60634
# 153716    Risk 1 (High)      6 E CHESTNUT ST  CHICAGO    IL  60611
#
#        Inspection Date        Inspection Type    Results  \
# 0           2017-08-28                license       Pass
# 1           2017-08-28                license  Not Ready
# 2           2017-08-28  license re-inspection  Not Ready
# 3           2017-08-28                license       Pass
# 4           2017-08-28  license re-inspection       Pass
# ...                ...                    ...        ...
# 153712      2010-01-04  license re-inspection       Pass
# 153713      2010-01-04            tag removal       Pass
# 153714      2010-01-04  license re-inspection       Pass
# 153715      2010-01-04  license re-inspection       Pass
# 153716      2010-01-04                canvass       Fail
#
#                                                Violations   Latitude  \
# 0                                                     NaN  41.853651
# 1                                                     NaN  41.881572
# 2       8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...  41.886577
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.853651
# 4       18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.921675
# ...                                                   ...        ...
# 153712  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.961606
# 153713                                                NaN  41.884586
# 153714  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.938007
# 153715  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.938443
# 153716  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         Longitude
# 0      -87.620534
# 1      -87.653052
# 2      -87.665328
# 3      -87.620534
# 4      -87.776711
# ...           ...
# 153712 -87.675967
# 153713 -87.631010
# 153714 -87.644755
# 153715 -87.768318
# 153716 -87.628009
#
# [153717 rows x 16 columns]

# %% [markdown]
# **[exploration]**

# %%
num_inspection = len(input_data)
print(f"How many inspection records are there in total? {num_inspection}")
num_license = len(set(input_data['License #']))
print(f"How many unique license numbers are there? {num_license}")
num_facility = len(input_data[['License #', 'DBA Name', 'AKA Name', 'Facility Type', 'Address']].drop_duplicates())
print(f"How many unique food facilities are there? {num_facility}")
num_dates = len(set(input_data['Inspection Date']))
print(f"How many unique inspection dates are there? {num_dates}")
# Out:
# How many inspection records are there in total? 153717
# How many unique license numbers are there? 32752
# How many unique food facilities are there? 34037
# How many unique inspection dates are there? 1946

# %% [markdown]
# ## Try to better understand the data

# %% [markdown]
# **[exploration]**
# ### 1. The same License # can have multiple DBA Name:

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'DBA Name']].drop_duplicates()
temp[temp.duplicated(subset='License #', keep=False)].sort_values(by='License #')
# Out:
#        License #                                DBA Name
# 2031     1000774            RECLAIMED BAR AND RESTAURANT
# 13475    1000774                           CRABBBY  KIMS
# 112542       104                     VITO & NICKS LOUNGE
# 65434        104            MIARAS CONTL PASTRY DELI INC
# 91724    1042664                                  SPOT 6
# ...          ...                                     ...
# 15801       9648                                CAFE #10
# 134717       968                            CAFE BERNARD
# 3618         968                                CHEZ MOI
# 2002          99                            FALCOS PIZZA
# 10657         99  XANDO COFFEE & BAR / COSI SANDWICH BAR
#
# [1244 rows x 2 columns]

# %% [markdown]
# ### 2. The same License # can have multiple addresses:

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
temp[temp.duplicated(subset='License #', keep=False)].sort_values(by='License #')
# Out:
#        License #                 Address     City State    Zip   Latitude  \
# 65434        104  7051-7053 W ADDISON ST  CHICAGO    IL  60634  41.945234
# 112542       104  8433-8435 S PULASKI RD  CHICAGO    IL  60652  41.739329
# 18082    1045301      1400 W RANDOLPH ST  CHICAGO    IL  60607  41.884274
# 98090    1045301         160 N LOOMIS ST  CHICAGO    IL  60607  41.883991
# 136005   1093945     2321 W LAWRENSE AVE  CHICAGO    IL  60625  41.968527
# ...          ...                     ...      ...   ...    ...        ...
# 18290        845         11 E HUBBARD ST  CHICAGO    IL  60611  41.889964
# 99450        901       6647 S HALSTED ST  CHICAGO    IL  60621  41.772902
# 137479       901          3835 W 26TH ST  CHICAGO    IL  60623  41.844188
# 10657         99       203 N LA SALLE ST  CHICAGO    IL  60601  41.885822
# 2002          99          2806 W 40TH PL  CHICAGO    IL  60632  41.820231
#
#         Longitude
# 65434  -87.802927
# 112542 -87.721440
# 18082  -87.662433
# 98090  -87.662525
# 136005 -87.687315
# ...           ...
# 18290  -87.627507
# 99450  -87.644461
# 137479 -87.720950
# 10657  -87.632304
# 2002   -87.694875
#
# [593 rows x 7 columns]

# %% [markdown]
# Note: even the same set of 'License #', 'DBA Name', 'AKA Name', 'Facility Type' can still have different Address/Latitude/Longitude:

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'DBA Name', 'AKA Name', 'Facility Type', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Facility Type'], keep=False)].sort_values(by='License #')
# Out:
#        License #                      DBA Name                      AKA Name  \
# 3425     1142125   POTBELLY SANDWICH WORKS LLC   POTBELLY SANDWICH WORKS LLC
# 77705    1142125   POTBELLY SANDWICH WORKS LLC   POTBELLY SANDWICH WORKS LLC
# 3196       13976                  ALDI INC #64                  ALDI INC #64
# 3210       13976                  ALDI INC #64                  ALDI INC #64
# 106612   1476455          THUNDERBIRD CATERING          THUNDERBIRD CATERING
# 108307   1476455          THUNDERBIRD CATERING          THUNDERBIRD CATERING
# 120570   1743553       STARBUCKS COFFEE #10957       STARBUCKS COFFEE #10957
# 3243     1743553       STARBUCKS COFFEE #10957       STARBUCKS COFFEE #10957
# 7737      188865                   TASTY PLACE                   TASTY PLACE
# 98419     188865                   TASTY PLACE                   TASTY PLACE
# 7610     1937822       POTBELLY SANDWICH WORKS                      POTBELLY
# 28096    1937822       POTBELLY SANDWICH WORKS                      POTBELLY
# 70015     198529            LESLIES PIZZA CORP            LESLIES PIZZA CORP
# 85779     198529            LESLIES PIZZA CORP            LESLIES PIZZA CORP
# 96129    2003503                III FORKS #425                     III FORKS
# 4100     2003503                III FORKS #425                     III FORKS
# 13944    2003567    LEONIDAS CAFE CHOCOLATERIE    LEONIDAS CAFE CHOCOLATERIE
# 149758   2003567    LEONIDAS CAFE CHOCOLATERIE    LEONIDAS CAFE CHOCOLATERIE
# 153100   2008948         MICHAELS ON MAIN CAFE         MICHAELS ON MAIN CAFE
# 8746     2008948         MICHAELS ON MAIN CAFE         MICHAELS ON MAIN CAFE
# 36174    2088918          HAREER FOOD & LIQUOR          HAREER FOOD & LIQUOR
# 88808    2088918          HAREER FOOD & LIQUOR          HAREER FOOD & LIQUOR
# 10540    2146635                           KFC                           KFC
# 112092   2146635                           KFC                           KFC
# 36031    2177122       ALI BABA FISH & CHICKEN       ALI BABA FISH & CHICKEN
# 22264    2177122       ALI BABA FISH & CHICKEN       ALI BABA FISH & CHICKEN
# 64149    2290163                 HAUTE SAUSAGE                 HAUTE SAUSAGE
# 18251    2290163                 HAUTE SAUSAGE                 HAUTE SAUSAGE
# 54553    2373706              TACO BELL #27900                     TACO BELL
# 8627     2373706              TACO BELL #27900                     TACO BELL
# 25052    2423147                       LA JEFA                       LA JEFA
# 34363    2423147                       LA JEFA                       LA JEFA
# 17696    2423842                    BOB CHA II                    BOB CHA II
# 17665    2423842                    BOB CHA II                    BOB CHA II
# 28429    2442868    EAT N RUN CHICKEN AND FISH    EAT N RUN CHICKEN AND FISH
# 18906    2442868    EAT N RUN CHICKEN AND FISH    EAT N RUN CHICKEN AND FISH
# 18079    2492018            REAL GOOD JUICE CO            REAL GOOD JUICE CO
# 18059    2492018            REAL GOOD JUICE CO            REAL GOOD JUICE CO
# 2277     2535189                         CITGO                         CITGO
# 1439     2535189                         CITGO                         CITGO
# 68628       8013  TOKYO LUNCH BOXES & CATERING  TOKYO LUNCH BOXES & CATERING
# 9875        8013  TOKYO LUNCH BOXES & CATERING  TOKYO LUNCH BOXES & CATERING
#
#                Facility Type                 Address     City State    Zip  \
# 3425              restaurant       5700 S CICERO AVE  CHICAGO    IL  60638
# 77705             restaurant       5800 S CICERO AVE  CHICAGO    IL  60638
# 3196                 grocery    1753 N MILWAUKEE AVE  CHICAGO    IL  60647
# 3210                 grocery    1767 N MILWAUKEE AVE  CHICAGO    IL  60647
# 106612  mobile food preparer          1204 W 36TH PL  CHICAGO    IL  60609
# 108307  mobile food preparer            1204 W 35 ST  CHICAGO    IL  60609
# 120570            restaurant      150 N MICHIGAN AVE  CHICAGO    IL  60601
# 3243              restaurant       150 E RANDOLPH ST  CHICAGO    IL  60601
# 7737                  bakery    2339 S WENTWORTH AVE  CHICAGO    IL  60616
# 98419                 bakery         2101 S CHINA PL  CHICAGO    IL  60616
# 7610              restaurant       2739 N ELSTON AVE  CHICAGO    IL  60647
# 28096             restaurant       2717 N ELSTON AVE  CHICAGO    IL  60647
# 70015             restaurant          3107 W 71ST ST  CHICAGO    IL  60629
# 85779             restaurant     3107 S 71ST ST BSMT  Chicago    IL  60629
# 96129             restaurant         333 E BENTON PL  CHICAGO    IL  60601
# 4100              restaurant        180 N FIELD BLVD  CHICAGO    IL  60601
# 13944             restaurant        59 E CHICAGO AVE  CHICAGO    IL  60611
# 149758            restaurant           750 N RUSH ST  CHICAGO    IL  60611
# 153100            restaurant    8750 W BRYN WAWR AVE  CHICAGO    IL  60631
# 8746              restaurant    8750 W BRYN MAWR AVE  CHICAGO    IL  60631
# 36174                grocery  5450-5452 S HALSTED ST  CHICAGO    IL  60609
# 88808                grocery       5452 S HALSTED ST  CHICAGO    IL  60609
# 10540             restaurant       3927 N HARLEM AVE  CHICAGO    IL  60634
# 112092            restaurant       3937 N HARLEM AVE  CHICAGO    IL  60634
# 36031             restaurant      8958 S ASHLAND AVE  CHICAGO    IL   6062
# 22264             restaurant      8950 S ASHLAND AVE  CHICAGO    IL   6062
# 64149             restaurant       335 S FRANKLIN ST  CHICAGO    IL  60606
# 18251             restaurant       337 S FRANKLIN ST  CHICAGO    IL  60606
# 54553             restaurant     1646-1648 W 95TH ST  CHICAGO    IL  60643
# 8627              restaurant          1644 W 95TH ST  CHICAGO    IL  60643
# 25052   mobile food preparer        324 N LEAVITT ST  CHICAGO    IL  60612
# 34363   mobile food preparer        2637 S THROOP ST  CHICAGO    IL  60608
# 17696   mobile food preparer        2300 S THROOP ST  CHICAGO    IL  60608
# 17665   mobile food preparer        324 N LEAVITT ST  CHICAGO    IL  60612
# 28429             restaurant                              NaN    IL    nan
# 18906             restaurant      8233 S ASHLAND AVE  CHICAGO    IL   6062
# 18079             restaurant        2031 W FULTON ST  CHICAGO    IL  60612
# 18059             restaurant         320 N DAMEN AVE  CHICAGO    IL  60612
# 2277                 grocery  4601-4615 N PULASKI RD  CHICAGO    IL   6063
# 1439                 grocery       4603 N PULASKI RD  CHICAGO    IL   6063
# 68628             restaurant         111 E WACKER DR  CHICAGO    IL  60601
# 9875              restaurant      179 W VAN BUREN ST  CHICAGO    IL  60605
#
#          Latitude  Longitude
# 3425    41.789329 -87.741646
# 77705   41.787652 -87.741560
# 3196    41.913342 -87.681822
# 3210    41.913588 -87.682203
# 106612  41.828094 -87.655854
# 108307  41.830726 -87.656012
# 120570  41.884531 -87.624602
# 3243    41.884628 -87.622613
# 7737    41.849788 -87.631797
# 98419   41.854105 -87.634059
# 7610    41.931426 -87.686504
# 28096   41.930936 -87.685792
# 70015   41.764300 -87.700699
# 85779         NaN        NaN
# 96129   41.885390 -87.618987
# 4100    41.885504 -87.617551
# 13944   41.896600 -87.625913
# 149758  41.896455 -87.625645
# 153100        NaN        NaN
# 8746    41.981063 -87.845674
# 36174   41.794613 -87.645315
# 88808   41.794559 -87.645313
# 10540   41.951606 -87.807079
# 112092  41.951879 -87.807089
# 36031   41.730381 -87.663052
# 22264   41.730593 -87.663058
# 64149   41.877259 -87.635041
# 18251   41.877213 -87.635041
# 54553   41.721299 -87.664470
# 8627    41.721300 -87.664343
# 25052   41.887434 -87.681849
# 34363   41.844671 -87.654962
# 17696   41.850451 -87.658798
# 17665   41.887434 -87.681849
# 28429         NaN        NaN
# 18906   41.743903 -87.663129
# 18079   41.886644 -87.678049
# 18059   41.887493 -87.676959
# 2277    41.964649 -87.727782
# 1439    41.964704 -87.727784
# 68628   41.888079 -87.624047
# 9875    41.876748 -87.633286

# %% [markdown]
# ### 3. The same license number and DBA Name can have multiple AKA Names.
# For example, there are 81 distinct DBA Name/facility type combinations for license #14616 ILLINOIS SPORTSERVICE INC:

# %%
temp = input_data[['License #', 'DBA Name', 'AKA Name', 'Facility Type']].drop_duplicates().groupby(
    by=['License #', 'DBA Name'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False).reset_index(drop=True)
temp.head(20)
# Out:
#    License #                           DBA Name  count
# 0      14616          ILLINOIS SPORTSERVICE INC     81
# 1    1974745                  THE UNITED CENTER     45
# 2    1354323         SPORTSERVICE SOLDIER FIELD     45
# 3    1574001  LEVY RESTAURANTS AT WRIGLEY FIELD     19
# 4    1932251                    MCCORMICK PLACE     16
# 5    2013962                    KENDALL COLLEGE     13
# 6      20481               THE GREAT STATE FARE      8
# 7    1354323        SPORT SERVICE SOLDIER FIELD      6
# 8    1574002  LEVY RESTAURANTS AT WRIGLEY FIELD      5
# 9    1932257                    MCCORMICK PLACE      5
# 10     37979        BISMARCK ENTERPRISES/UNITED      4
# 11   1354323       SPORTS SERVICE SOLDIER FIELD      4
# 12   1974985                  THE UNITED CENTER      4
# 13   1932259                    LAKESIDE CENTER      3
# 14   1543382        POTBELLY SANDWICH WORKS LLC      2
# 15   1802208                        UMAIYA CAFE      2
# 16   2060558     BERGSTEINS NY DELICATESSEN LLC      2
# 17   2309057                CHEESIES PUB & GRUB      2
# 18   2423633                        THE REVIVAL      2
# 19   2202445                K & G FOOD MART INC      2

# %% [markdown]
# There are 178 such License #/DBA Name combinations that have more than 1 DBA Name/facility type combinations:

# %%
len(temp[temp['count']>1])
# Out:
# 178

# %% [markdown]
# Take a closer look at license #14616:

# %%
input_data[(input_data['License #']=='14616') & (input_data['DBA Name']=='ILLINOIS SPORTSERVICE INC')][
    ['License #', 'DBA Name', 'AKA Name', 'Facility Type']].drop_duplicates()
# Out:
#        License #                   DBA Name  \
# 2209       14616  ILLINOIS SPORTSERVICE INC
# 123192     14616  ILLINOIS SPORTSERVICE INC
# 123200     14616  ILLINOIS SPORTSERVICE INC
# 128176     14616  ILLINOIS SPORTSERVICE INC
# 128419     14616  ILLINOIS SPORTSERVICE INC
# ...          ...                        ...
# 149924     14616  ILLINOIS SPORTSERVICE INC
# 149950     14616  ILLINOIS SPORTSERVICE INC
# 149955     14616  ILLINOIS SPORTSERVICE INC
# 149973     14616  ILLINOIS SPORTSERVICE INC
# 149982     14616  ILLINOIS SPORTSERVICE INC
#
#                                                  AKA Name Facility Type
# 2209                                GUARANTEED RATE FIELD       stadium
# 123192                                    MAIN COMMISSARY    commissary
# 123200    SHERM LOLLARS GUARD THE PLATE GRILLE STAND #524    restaurant
# 128176                           TEX-MEX 3 - STEAK (#544)         kiosk
# 128419                                BBQ BRISKET  (#531)         kiosk
# ...                                                   ...           ...
# 149924                            DIPPING DOTS (SEC #132)    restaurant
# 149950                                    GO GO WHITE SOX    restaurant
# 149955                                     NACHO 8 (#544)    restaurant
# 149973                       HOT DOG VIENNA BEEF 7 (#557)    restaurant
# 149982  SWEET SPOT (BIG ED WALSHS ITALIAN BEEF AND PIZZA)    restaurant
#
# [81 rows x 4 columns]

# %% [markdown]
# ### 4. The same address can have multiple license numbers

# %%
temp = input_data[(input_data['License #']!='') & (input_data['License #']!='nan') & (~pd.isnull(input_data['License #']))][[
    'License #', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']].drop_duplicates()
temp[temp.duplicated(subset=['Address', 'City', 'State', 'Zip', 'Latitude','Longitude'], keep=False)].sort_values(by='Address')
# Out:
#        License #                Address     City State    Zip   Latitude  \
# 10019    2215538           1 E 113TH ST  CHICAGO    IL  60628  41.688848
# 116232     21702           1 E 113TH ST  CHICAGO    IL  60628  41.688848
# 116234   1800876           1 E 113TH ST  CHICAGO    IL  60628  41.688848
# 1704     1904686        1 E DELAWARE PL  CHICAGO    IL  60611  41.899031
# 23599    2397758        1 E DELAWARE PL  CHICAGO    IL  60611  41.899031
# ...          ...                    ...      ...   ...    ...        ...
# 88096    2013312       9917 S EWING AVE  CHICAGO    IL  60617  41.715244
# 9089     3247017  9928 S CRANDON AVE FL  CHICAGO    IL  60617  41.714402
# 75412    2046663  9928 S CRANDON AVE FL  CHICAGO    IL  60617  41.714402
# 83366    2093742      9939 S HALSTED ST  CHICAGO    IL  60628  41.713035
# 15763    1998729      9939 S HALSTED ST  CHICAGO    IL  60628  41.713035
#
#         Longitude
# 10019  -87.622894
# 116232 -87.622894
# 116234 -87.622894
# 1704   -87.628192
# 23599  -87.628192
# ...           ...
# 88096  -87.535130
# 9089   -87.567167
# 75412  -87.567167
# 83366  -87.642832
# 15763  -87.642832
#
# [23929 rows x 7 columns]

# %% [markdown]
# ### 5. Even the same (?) food facility can have different license numbers!

# %%
temp = input_data[[
    'DBA Name','AKA Name','License #','Facility Type','Address','City','State','Zip',
    'Latitude','Longitude']].drop_duplicates()
facility_counts = temp.groupby(
    by=['DBA Name','AKA Name','Facility Type','Address','City','State','Zip','Latitude','Longitude'], dropna=False)\
    .size().rename('count').reset_index().sort_values(by='count', ascending=False)
facility_counts.head(20)
# Out:
#                                                 DBA Name  \
# 27185                              TRIPLE A SERVICES INC
# 19441  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 27676                                      VHC LOWER LLC
# 23291                                         SOHO HOUSE
# 19383                                PALETERIA AZTECA #2
# 27899                            WALDORF ASTORIA CHICAGO
# 9517                                      FLAT TOP GRILL
# 19327                PACIFIC LANGHAM CHICAGO CORPORATION
# 19380                                PALETERIA AZTECA #2
# 16670                            MARRIOT MARQUIS CHICAGO
# 24833                                   SUPREME CATERING
# 19748                               PARS ICECREAM CO INC
# 1687                                             ARAMARK
# 5027                 CHICAGO BORN LOSERS MOTORCYCLE CLUB
# 19634                                   PAPA TS ITALIANO
# 15387                  LEVY RESTAURANTS AT UNITED CENTER
# 26804                               THUNDERBIRD CATERING
# 5161                        CHICAGO MARRIOTT OHARE HOTEL
# 26153                                           THE GRAY
# 22385                                SAN LUIS FREEZE INC
#
#                                             AKA Name         Facility Type  \
# 27185                          TRIPLE A SERVICES INC  mobile food preparer
# 19441                        LA MEXICANA TAMALE CART  mobile food preparer
# 27676  3RD FLOOR - BANQUET/MEETING ROOMS(LL KITCHEN)            restaurant
# 23291                                     SOHO HOUSE            restaurant
# 19383                                            NaN  mobile food preparer
# 27899                        WALDORF ASTORIA CHICAGO            restaurant
# 9517                                  FLAT TOP GRILL            restaurant
# 19327                            THE LANGHAM CHICAGO            restaurant
# 19380                            PALETERIA AZTECA #2  mobile food preparer
# 16670                        MARRIOT MARQUIS CHICAGO            restaurant
# 24833                               SUPREME CATERING  mobile food preparer
# 19748                                            NaN  mobile food preparer
# 1687                                         ARAMARK         special event
# 5027             CHICAGO BORN LOSERS MOTORCYCLE CLUB            restaurant
# 19634                                            NaN  mobile food preparer
# 15387              LEVY RESTAURANTS AT UNITED CENTER            restaurant
# 26804                           THUNDERBIRD CATERING                   NaN
# 5161                    CHICAGO MARRIOTT OHARE HOTEL            restaurant
# 26153                                  VOL 39/ BOLEO            restaurant
# 22385                                SAN LUIS FREEZE  mobile food preparer
#
#                     Address      City State    Zip   Latitude  Longitude  \
# 27185   2637 S THROOP ST FL   CHICAGO    IL  60608  41.844671 -87.654962
# 19441     4171 S ARCHER AVE   CHICAGO    IL  60632  41.817618 -87.698258
# 27676      203 N WABASH AVE   CHICAGO    IL  60601  41.885828 -87.626138
# 23291    113-125 N GREEN ST   CHICAGO    IL  60607  41.883557 -87.648432
# 19383      3119 W CERMAK RD   CHICAGO    IL  60623  41.851676 -87.703696
# 27899        11 E WALTON ST   CHICAGO    IL  60611  41.899835 -87.627799
# 9517        30 S WABASH AVE   CHICAGO    IL  60603  41.881335 -87.626335
# 19327      330 N WABASH AVE   CHICAGO    IL  60611  41.887939 -87.627036
# 19380      3119 W CERMAK RD   CHICAGO    IL  60623  41.851676 -87.703696
# 16670    2121 S PRAIRIE AVE   CHICAGO    IL  60616  41.853651 -87.620534
# 24833       1900 MAYWOOD DR   MAYWOOD    IL  60153        NaN        NaN
# 19748  4825 W ARTHINGTON ST   CHICAGO    IL  60644  41.869236 -87.745893
# 1687   1300 S LYNN WHITE DR   CHICAGO    IL  60605  41.866310 -87.610270
# 5027      4420 W MADISON ST   CHICAGO    IL  60624  41.880710 -87.736361
# 19634        2843 W 63RD ST  INACTIVE    IL  60629  41.778981 -87.695090
# 15387    1901 W MADISON AVE   CHICAGO    IL  60612  41.881241 -87.674283
# 26804        1204 W 36TH PL   CHICAGO    IL  60609  41.828094 -87.655854
# 5161      8535 W HIGGINS RD   CHICAGO    IL  60631  41.986789 -87.840124
# 26153      39 S LA SALLE ST   CHICAGO    IL  60603  41.880932 -87.632189
# 22385   4241 W ARMITAGE AVE   CHICAGO    IL  60639  41.916971 -87.733118
#
#        count
# 27185     43
# 19441     16
# 27676     15
# 23291     10
# 19383     10
# 27899      9
# 9517       8
# 19327      7
# 19380      7
# 16670      7
# 24833      7
# 19748      7
# 1687       6
# 5027       6
# 19634      6
# 15387      6
# 26804      6
# 5161       6
# 26153      6
# 22385      6

# %%
print(f"{len(facility_counts[facility_counts['count']>1])} such facilities are involved!")
print(f"That's {round(100*len(facility_counts[facility_counts['count']>1])/len(facility_counts), 2)}% of all facilities!!")
# Out:
# 4015 such facilities are involved!
# That's 13.83% of all facilities!!

# %% [markdown]
# Note that some of them have the facility type of "Mobile Prepared Food Vendor". Some of the "Restaurant" facilities seem to be hotels, or within a complex.
# In the following example, most of them have the facility type of "Mobile Prepared Food Vendor":

# %%
input_data[input_data['AKA Name']=='LA MEXICANA TAMALE CART'][
    ['License #', 'DBA Name','AKA Name','Facility Type','Address','City','State','Zip',
     'Latitude','Longitude','Inspection Date']
].drop_duplicates()
# Out:
#       License #                                           DBA Name  \
# 5099    2506389  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11717   2506388  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11720   2506235  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11721   2506234  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11725   2506233  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11727   2506231  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11729    250623  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11731   2506222  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11735    250622  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11737   2506221  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11740   2506215  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11743   2506213  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11747   2506212  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11752   2506211  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11753   2506209  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 11778   2500986  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
# 14041   2495679  PALETERIA Y NEVERIA LA MEXICANA YOGURT AND CHURRO
#
#                       AKA Name         Facility Type            Address  \
# 5099   LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11717  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11720  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11721  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11725  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11727  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11729  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11731  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11735  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11737  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11740  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11743  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11747  LA MEXICANA TAMALE CART            restaurant  4171 S ARCHER AVE
# 11752  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11753  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 11778  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
# 14041  LA MEXICANA TAMALE CART  mobile food preparer  4171 S ARCHER AVE
#
#           City State    Zip   Latitude  Longitude Inspection Date
# 5099   CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11717  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11720  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11721  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11725  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11727  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11729  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11731  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11735  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11737  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11740  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11743  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11747  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11752  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11753  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 11778  CHICAGO    IL  60632  41.817618 -87.698258      2017-01-10
# 14041  CHICAGO    IL  60632  41.817618 -87.698258      2016-11-22

# %% [markdown]
# **[exploration]**
# ### 6. Are there any redundant inspection entries on the same day for the same facility?

# %%
temp2 = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type']]
inspection_counts2 = temp2.groupby(by=['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Inspection Type'], dropna=False).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False)
inspection_counts2.head(10)
# Out:
#        License #                      DBA Name  \
# 12931    1354323    SPORTSERVICE SOLDIER FIELD
# 12933    1354323    SPORTSERVICE SOLDIER FIELD
# 12892    1354323    SPORTSERVICE SOLDIER FIELD
# 12899    1354323    SPORTSERVICE SOLDIER FIELD
# 16591      14616     ILLINOIS SPORTSERVICE INC
# 23926     157883                 BUFFET CASTLE
# 24426    1592201                     6 DEGREES
# 66801    2048785     TRUMP INTERNATIONAL HOTEL
# 137502      3727     ALL AMERICAN NURSING HOME
# 139166     40155  POPEYES CHICKEN/INDIAN SWAAD
#
#                                 AKA Name Inspection Date  \
# 12931                     GRIDIRON GRILL      2010-06-07
# 12933                     GRIDIRON GRILL      2011-05-23
# 12892                    1ST DOWN FRANKS      2010-06-07
# 12899                     2ND CITY PIZZA      2010-06-07
# 16591   MOOSES DOGS AND POLISH 10 (#538)      2010-03-25
# 23926                      BUFFET CASTLE      2013-04-18
# 24426                          6 DEGREES      2016-09-09
# 66801                            SIXTEEN      2017-05-09
# 137502         ALL AMERICAN NURSING HOME      2010-02-25
# 139166      POPEYES CHICKEN/INDIAN SWAAD      2010-05-20
#
#                 Inspection Type  count
# 12931                   canvass      5
# 12933                   canvass      3
# 12892                   canvass      3
# 12899                   canvass      3
# 16591                   canvass      2
# 23926                   canvass      2
# 24426                   canvass      2
# 66801                   canvass      2
# 137502                  canvass      2
# 139166  complaint re-inspection      2

# %%
print("How many unique food facilities/inspection date combinations have multiple inspections on that date?")
num_facility_date_multiple_inspections = len(inspection_counts2[inspection_counts2['count']>1])
num_facility_date_comb = len(inspection_counts2)
print(f"{num_facility_date_multiple_inspections} out of {num_facility_date_comb} ({round(100*num_facility_date_multiple_inspections/num_facility_date_comb, 2)}%)")

print("How many inspection records are involved ?")
num_inspection_involved = inspection_counts2[inspection_counts2['count']>1]['count'].sum()
print(f"{num_inspection_involved} out of {num_inspection} ({round(100*num_inspection_involved/num_inspection, 2)}%)")

print("How many unique license numbers are involved?")
num_license_involved = len(inspection_counts2[inspection_counts2['count']>1][['License #']].drop_duplicates())
print(f"{num_license_involved} out of {num_license} ({round(100*num_license_involved/num_license, 2)}%)")

print("How many unique food facilities are involved?")
num_facility_involved = len(inspection_counts2[inspection_counts2['count']>1][['License #', 'AKA Name']].drop_duplicates())
print(f"{num_facility_involved} out of {num_facility} ({round(100*num_facility_involved/num_facility, 2)}%)")

print("How many unique inspection dates are involved?")
num_dates_involved = len(inspection_counts2[inspection_counts2['count']>1][['Inspection Date']].drop_duplicates())
print(f"{num_dates_involved} out of {num_dates} ({round(100*num_dates_involved/num_dates, 2)}%)")
# Out:
# How many unique food facilities/inspection date combinations have multiple inspections on that date?
# 393 out of 153318 (0.26%)
# How many inspection records are involved ?
# 792 out of 153717 (0.52%)
# How many unique license numbers are involved?
# 370 out of 32752 (1.13%)
# How many unique food facilities are involved?
# 381 out of 34037 (1.12%)
# How many unique inspection dates are involved?
# 336 out of 1946 (17.27%)

# %% [markdown]
# What's happening there? Take one example to look into the details:

# %%
input_data[(input_data['License #']=='1354323') & (input_data['AKA Name']=='GRIDIRON GRILL') & (input_data['Inspection Date']=='2010-06-07')]
# Out:
#        Inspection ID                    DBA Name        AKA Name License #  \
# 146342        250633  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146350        197469  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146358        112420  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146363        160390  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
# 146406        197476  SPORTSERVICE SOLDIER FIELD  GRIDIRON GRILL   1354323
#
#        Facility Type             Risk                  Address     City State  \
# 146342    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146350    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146358    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146363    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
# 146406    restaurant  Risk 2 (Medium)  1410 S MUSEUM CAMPUS DR  CHICAGO    IL
#
#           Zip Inspection Date Inspection Type Results  \
# 146342  60605      2010-06-07         canvass    Pass
# 146350  60605      2010-06-07         canvass    Pass
# 146358  60605      2010-06-07         canvass    Pass
# 146363  60605      2010-06-07         canvass    Pass
# 146406  60605      2010-06-07         canvass    Pass
#
#                                                Violations   Latitude  \
# 146342  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.862628
# 146350  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.862628
# 146358  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.862628
# 146363  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.862628
# 146406  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.862628
#
#         Longitude
# 146342 -87.615031
# 146350 -87.615031
# 146358 -87.615031
# 146363 -87.615031
# 146406 -87.615031

# %% [markdown]
# OK. It looks like there are indeed multiple inspections on the same date. Although the results are the same ("Pass"), the detailed "Violations" notes are different! In this case, **we will need to collapse these inspections**. (We'll do this in a later section!)
# Also note that some of the violations have different comments although they share the same violation code:

# %%
input_data.loc[146428, 'Violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \n \nMUST DETAIL CLEAN FLOORS UNDER GRILL AND REMOVE FOOD DEBRIS AND GREASE BUILD UP.  '

# %%
input_data.loc[146493, 'Violations']
# Out:
# '34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: The floors shall be constructed per code, be smooth and easily cleaned, and be kept clean and in good repair. \nSTANDING WATER NEXT TO GREASE TRAP. INSTRUCTED TO CLEAN AND MAINTAIN. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: The walls and ceilings shall be in good repair and easily cleaned. \nPEELING PAINT NOTED ON WALL NEXT TO DEEP FRYER, INSTRUCTED MANAGER TO REMOVE AND MAINTAIN.'

# %% [markdown]
# Let's also consider address, results and violatoins:
# Now there are no duplicates!

# %%
temp = input_data[['Inspection ID', 'License #', 'DBA Name', 'AKA Name', 'Facility Type', 'Address', 'Inspection Date', 'Inspection Type', 'Results', 'Violations']]
temp.duplicated(subset=list(temp)[1:], keep=False).sum()
# Out:
# 0

# %% [markdown]
# ## 2. Further data cleanup and split into multiple tables

# %% [markdown]
# ### Facility

# %%
input_data[['DBA Name', 'AKA Name', 'License #', 'Facility Type', 'Address', 'City', 'State', 'Zip', 'Latitude','Longitude']]

# %% [markdown]
# ### Facility_Risk

# %%
temp = input_data[['DBA Name', 'AKA Name', 'Address','Zip', 'Risk', 'Inspection Date']].drop_duplicates()
temp[temp.duplicated(subset=['DBA Name', 'AKA Name', 'Address','Zip', 'Inspection Date'], keep=False)]
# Out:
#                  DBA Name           AKA Name                  Address    Zip  \
# 30      NANDO'S PERI-PERI  NANDO'S PERI-PERI           117 E LAKE ST   60601
# 33      NANDO'S PERI-PERI  NANDO'S PERI-PERI           117 E LAKE ST   60601
# 52         THE PRESS ROOM     THE PRESS ROOM  1134 W WASHINGTON BLVD   60607
# 54         THE PRESS ROOM     THE PRESS ROOM  1134 W WASHINGTON BLVD   60607
# 149        THE PRESS ROOM     THE PRESS ROOM  1134 W WASHINGTON BLVD   60607
# ...                   ...                ...                      ...    ...
# 153143        FLO & SANTO        FLO & SANTO       1310 S WABASH AVE   60605
# 153352       WISHCO, INC.       WISHCO, INC.          1546 W 35TH ST   60609
# 153353       WISHCO, INC.       WISHCO, INC.          1546 W 35TH ST   60609
# 153608   HONG KONG MARKET   HONG KONG MARKET           520 W 24TH PL   60616
# 153625   HONG KONG MARKET   HONG KONG MARKET           520 W 24TH PL   60616
#
#                  Risk Inspection Date
# 30       Risk 3 (Low)      2017-08-25
# 33      Risk 1 (High)      2017-08-25
# 52       Risk 3 (Low)      2017-08-24
# 54      Risk 1 (High)      2017-08-24
# 149      Risk 3 (Low)      2017-08-22
# ...               ...             ...
# 153143   Risk 3 (Low)      2010-01-19
# 153352   Risk 3 (Low)      2010-01-13
# 153353  Risk 1 (High)      2010-01-13
# 153608   Risk 3 (Low)      2010-01-07
# 153625  Risk 1 (High)      2010-01-07
#
# [1423 rows x 6 columns]

# %%
temp = input_data[input_data['License #']!=''][['License #', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset='License #', keep=False)].sort_values(by='License #')
# Out:
#        License #             Risk
# 65459        104    Risk 1 (High)
# 112603       104     Risk 3 (Low)
# 1729     1042664    Risk 1 (High)
# 91775    1042664     Risk 3 (Low)
# 4405        1094    Risk 1 (High)
# ...          ...              ...
# 37903       8425  Risk 2 (Medium)
# 137559       901    Risk 1 (High)
# 99502        901     Risk 3 (Low)
# 578          nan  Risk 2 (Medium)
# 113446       nan    Risk 1 (High)
#
# [471 rows x 2 columns]

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 127712                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 127627                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 33799    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 2313     1947909                      SUBWAY                      SUBWAY
# 115550   1947909                      SUBWAY                      SUBWAY
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 138772   2021346               INFUSION CAFE               INFUSION CAFE
# 138736   2021346               INFUSION CAFE               INFUSION CAFE
# 145463   2031677                 PORK SHOPPE                 PORK SHOPPE
# 145952   2031677                 PORK SHOPPE                 PORK SHOPPE
# 140399    203223               MORE CUPCAKES               MORE CUPCAKES
# 108154    203223               MORE CUPCAKES               MORE CUPCAKES
# 100153   2073639                THE SOUTHERN                THE SOUTHERN
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 36187    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
# 88857    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
# 81071    2098831                 TRENCHERMEN                 TRENCHERMEN
# 109207   2098831                 TRENCHERMEN                 TRENCHERMEN
# 122235   2113684                     WOW BAO                     WOW BAO
# 121526   2113684                     WOW BAO                     WOW BAO
# 111465   2152257                   TACO BELL                   TACO BELL
# 53947    2152257                   TACO BELL                   TACO BELL
# 79447    2240275             PARTS AND LABOR             PARTS AND LABOR
# 87760    2240275             PARTS AND LABOR             PARTS AND LABOR
# 18086    2492018          REAL GOOD JUICE CO          REAL GOOD JUICE CO
# 18066    2492018          REAL GOOD JUICE CO          REAL GOOD JUICE CO
# 4213     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
# 3143     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                    Risk
# 127712     Risk 3 (Low)
# 127627  Risk 2 (Medium)
# 33799     Risk 1 (High)
# 85087      Risk 3 (Low)
# 2313      Risk 1 (High)
# 115550     Risk 3 (Low)
# 80181   Risk 2 (Medium)
# 80180      Risk 3 (Low)
# 87107      Risk 3 (Low)
# 87109     Risk 1 (High)
# 69370      Risk 3 (Low)
# 84339     Risk 1 (High)
# 138772    Risk 1 (High)
# 138736     Risk 3 (Low)
# 145463    Risk 1 (High)
# 145952     Risk 3 (Low)
# 140399  Risk 2 (Medium)
# 108154     Risk 3 (Low)
# 100153  Risk 2 (Medium)
# 134516    Risk 1 (High)
# 36187      Risk 3 (Low)
# 88857   Risk 2 (Medium)
# 81071     Risk 1 (High)
# 109207     Risk 3 (Low)
# 122235    Risk 1 (High)
# 121526     Risk 3 (Low)
# 111465  Risk 2 (Medium)
# 53947     Risk 1 (High)
# 79447     Risk 1 (High)
# 87760      Risk 3 (Low)
# 18086     Risk 1 (High)
# 18066   Risk 2 (Medium)
# 4213                All
# 3143    Risk 2 (Medium)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Inspection Date', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Inspection Date'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85099    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 115550   1947909                      SUBWAY                      SUBWAY
# 115558   1947909                      SUBWAY                      SUBWAY
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 138736   2021346               INFUSION CAFE               INFUSION CAFE
# 138772   2021346               INFUSION CAFE               INFUSION CAFE
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 134550   2073639                THE SOUTHERN                THE SOUTHERN
# 88857    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
# 88923    2088918        HAREER FOOD & LIQUOR        HAREER FOOD & LIQUOR
#
#        Inspection Date             Risk
# 85087       2013-08-26     Risk 3 (Low)
# 85099       2013-08-26    Risk 1 (High)
# 115550      2012-02-02     Risk 3 (Low)
# 115558      2012-02-02    Risk 1 (High)
# 80180       2013-11-07     Risk 3 (Low)
# 80181       2013-11-07  Risk 2 (Medium)
# 87107       2013-07-22     Risk 3 (Low)
# 87109       2013-07-22    Risk 1 (High)
# 69370       2013-09-09     Risk 3 (Low)
# 84339       2013-09-09    Risk 1 (High)
# 138736      2010-10-28     Risk 3 (Low)
# 138772      2010-10-28    Risk 1 (High)
# 134516      2011-02-01    Risk 1 (High)
# 134550      2011-02-01  Risk 2 (Medium)
# 88857       2013-06-14  Risk 2 (Medium)
# 88923       2013-06-14     Risk 3 (Low)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Address', 'Inspection Date', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Address', 'Inspection Date'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85099    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 115550   1947909                      SUBWAY                      SUBWAY
# 115558   1947909                      SUBWAY                      SUBWAY
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 134550   2073639                THE SOUTHERN                THE SOUTHERN
#
#                        Address Inspection Date             Risk
# 85087    5605-5609 N CLARK ST       2013-08-26     Risk 3 (Low)
# 85099    5605-5609 N CLARK ST       2013-08-26    Risk 1 (High)
# 115550      6450 S PULASKI RD       2012-02-02     Risk 3 (Low)
# 115558      6450 S PULASKI RD       2012-02-02    Risk 1 (High)
# 80180         2804 N CLARK ST       2013-11-07     Risk 3 (Low)
# 80181         2804 N CLARK ST       2013-11-07  Risk 2 (Medium)
# 87107     4610 W DIVERSEY AVE       2013-07-22     Risk 3 (Low)
# 87109     4610 W DIVERSEY AVE       2013-07-22    Risk 1 (High)
# 69370   900 N NORTH BRANCH ST       2013-09-09     Risk 3 (Low)
# 84339   900 N NORTH BRANCH ST       2013-09-09    Risk 1 (High)
# 134516  1840-1842 W NORTH AVE       2011-02-01    Risk 1 (High)
# 134550  1840-1842 W NORTH AVE       2011-02-01  Risk 2 (Medium)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'AKA Name', 'Address', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name', 'AKA Name', 'Address'], keep=False)].sort_values(by='License #')
# Out:
#        License #                    DBA Name                    AKA Name  \
# 127712                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 127627                        FLAV-O-RICIOUS              FLAV-O-RICIOUS
# 33799    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 85087    1579115  TURKISH CUISINE AND BAKERY  TURKISH CUISINE AND BAKERY
# 2313     1947909                      SUBWAY                      SUBWAY
# 115550   1947909                      SUBWAY                      SUBWAY
# 80180    1954774        Wells Street Popcorn        Wells Street Popcorn
# 80181    1954774        Wells Street Popcorn        Wells Street Popcorn
# 87107    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 87109    1974918               ATINO'S PIZZA               ATINO'S PIZZA
# 69370    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 84339    2013962             KENDALL COLLEGE    LAB KITCHEN B-ROOM 120B.
# 145463   2031677                 PORK SHOPPE                 PORK SHOPPE
# 145952   2031677                 PORK SHOPPE                 PORK SHOPPE
# 108154    203223               MORE CUPCAKES               MORE CUPCAKES
# 140399    203223               MORE CUPCAKES               MORE CUPCAKES
# 100153   2073639                THE SOUTHERN                THE SOUTHERN
# 134516   2073639                THE SOUTHERN                THE SOUTHERN
# 121526   2113684                     WOW BAO                     WOW BAO
# 122235   2113684                     WOW BAO                     WOW BAO
# 79447    2240275             PARTS AND LABOR             PARTS AND LABOR
# 87760    2240275             PARTS AND LABOR             PARTS AND LABOR
# 4213     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
# 3143     2528906         PIZZA HUT SLICE BAR                   PIZZA HUT
#
#                        Address             Risk
# 127712        600 E GRAND AVE      Risk 3 (Low)
# 127627        600 E GRAND AVE   Risk 2 (Medium)
# 33799    5605-5609 N CLARK ST     Risk 1 (High)
# 85087    5605-5609 N CLARK ST      Risk 3 (Low)
# 2313        6450 S PULASKI RD     Risk 1 (High)
# 115550      6450 S PULASKI RD      Risk 3 (Low)
# 80180         2804 N CLARK ST      Risk 3 (Low)
# 80181         2804 N CLARK ST   Risk 2 (Medium)
# 87107     4610 W DIVERSEY AVE      Risk 3 (Low)
# 87109     4610 W DIVERSEY AVE     Risk 1 (High)
# 69370   900 N NORTH BRANCH ST      Risk 3 (Low)
# 84339   900 N NORTH BRANCH ST     Risk 1 (High)
# 145463     2755 W BELMONT AVE     Risk 1 (High)
# 145952     2755 W BELMONT AVE      Risk 3 (Low)
# 108154        1 E DELAWARE PL      Risk 3 (Low)
# 140399        1 E DELAWARE PL   Risk 2 (Medium)
# 100153  1840-1842 W NORTH AVE   Risk 2 (Medium)
# 134516  1840-1842 W NORTH AVE     Risk 1 (High)
# 121526     175 W JACKSON BLVD      Risk 3 (Low)
# 122235     175 W JACKSON BLVD     Risk 1 (High)
# 79447    2700 N MILWAUKEE AVE     Risk 1 (High)
# 87760    2700 N MILWAUKEE AVE      Risk 3 (Low)
# 4213         500 W MADISON ST               All
# 3143         500 W MADISON ST   Risk 2 (Medium)

# %%
temp = input_data[~pd.isnull(input_data['Risk'])][['License #', 'DBA Name', 'Risk']].drop_duplicates()
temp[temp.duplicated(subset=['License #', 'DBA Name'], keep=False)].sort_values(by='License #')
# Out:
#        License #                                DBA Name             Risk
# 127712                                    FLAV-O-RICIOUS     Risk 3 (Low)
# 127627                                    FLAV-O-RICIOUS  Risk 2 (Medium)
# 149961   1120537  LEVY RESTAURANTS AT U.S CELLULAR FIELD    Risk 1 (High)
# 127783   1120537  LEVY RESTAURANTS AT U.S CELLULAR FIELD  Risk 2 (Medium)
# 95475     135245        ILLINOIS INSTITUTE OF TECHNOLOGY    Risk 1 (High)
# ...          ...                                     ...              ...
# 47119      32394                MART PLAZA CATERING CORP    Risk 1 (High)
# 36142      37979             BISMARCK ENTERPRISES/UNITED  Risk 2 (Medium)
# 84078      37979             BISMARCK ENTERPRISES/UNITED    Risk 1 (High)
# 120491      6121                                  MACY'S  Risk 2 (Medium)
# 5122        6121                                  MACY'S    Risk 1 (High)
#
# [99 rows x 3 columns]

# %% [markdown]
# ### Inspection
# (Id, Date, Type, Result)

# %%
input_data[['Inspection ID', 'Inspection Date', 'Inspection Type', 'Results']]

# %% [markdown]
# ### Violation and  Inspection_Violation

# %%
violation_df = input_data[~pd.isnull(input_data['Violations'])][['Inspection ID', 'Violations']].reset_index(drop=True)
violation_df
# Out:
#        Inspection ID                                         Violations
# 0            2079125  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...
# 1            2079123  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 2            2079105  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 3            2079104  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 4            2079091  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# ...              ...                                                ...
# 123007         67733  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 123008         67732  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 123009         52234  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# 123010         70269  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...
# 123011        104236  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
#
# [123012 rows x 2 columns]

# %%
input_data['Violations'].values[2]
# Out:
# '8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  CLEAN, PROPER TEMPERATURE, CONCENTRATION, EXPOSURE TIME - Comments: NO DISH WASHING FACILITIES ON SITE, (NO THREE COMPARTMENT SINK, WITH GREASE TRAP, OR DISHMACHINE), INSTRUCTED TO PROVIDE, | 11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIGNED, AND MAINTAINED - Comments:  NO EXPOSED HAND SINK FOR REAR SERVICE AREA, INSTRUCTED TO PROVIDE,\n | 18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME OF INSPECTION, INSTRUCTED TO PROVIDE, UPON NEXT VISIT,'

# %%
violation_df = violation_df.assign(
    Violations=violation_df['Violations'].str.split(' \| ')).explode('Violations').reset_index(drop=True)
violation_df.head(10)
# Out:
#   Inspection ID                                         Violations
# 0       2079125  8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS...
# 1       2079125  11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...
# 2       2079125  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 3       2079123  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...
# 4       2079123  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 5       2079105  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...
# 6       2079105  31. CLEAN MULTI-USE UTENSILS AND SINGLE SERVIC...
# 7       2079105  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 8       2079105  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...
# 9       2079105  41. PREMISES MAINTAINED FREE OF LITTER, UNNECE...

# %%
violation_df.loc[0, 'Violations']
# Out:
# '8. SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  CLEAN, PROPER TEMPERATURE, CONCENTRATION, EXPOSURE TIME - Comments: NO DISH WASHING FACILITIES ON SITE, (NO THREE COMPARTMENT SINK, WITH GREASE TRAP, OR DISHMACHINE), INSTRUCTED TO PROVIDE,'

# %%
violation_df.loc[2, 'Violations']
# Out:
# '18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME OF INSPECTION, INSTRUCTED TO PROVIDE, UPON NEXT VISIT,'

# %%
violation_df.loc[5, 'Violations']
# Out:
# '18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments: VIOLATION CORRECTED'

# %%
violation_df.loc[12, 'Violations']
# Out:
# '21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED - Comments: NO ORIGINAL CHICAGO FOOD SANITATION CERTIFICATE POSTED. INSTRUCTED MANAGER TO PROVIDE ORIGINAL FOOD SANITATION CERTIFICATE. COPIES ARE NOT ACCEPTABLE. SERIOUS VIOLATION 7-38-012A'

# %%
violation_df.loc[30, 'Violations']
# Out:
# '21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED - Comments: NO CITY OF CHICAGO CERTIFIED FOOD MANAGER ON SITE DURING INITIAL INSPECTION WHILE FOODS WERE BEING PREPARED. CERTIFIED MANAGER WAS TELEPHONED AT THE INITIAL INSPECTION AND ARRIVED THIRTY MINUTES LATER. INSTRUCTED A CITY OF CHICAGO CERTIFIED MANAGER MUST BE ON SITE AT ALL TIMES WHILE FOODS ARE PREPARED. SERIOUS VIOLATION. 7-38-012.'

# %%
def split_violation(violation):
    violation, comment = violation.split(' - Comments: ')
    code, description = violation.split('. ', 1)
    return code, description, comment
violation_df['code'], violation_df['description'], violation_df['comment'] = zip(*violation_df['Violations'].apply(split_violation))
violation_df = violation_df.drop(columns='Violations').drop_duplicates().reset_index(drop=True)
violation_df
# Out:
#        Inspection ID code                                        description  \
# 0            2079125    8  SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  ...
# 1            2079125   11  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIG...
# 2            2079125   18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 3            2079123   35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4            2079123   34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# ...              ...  ...                                                ...
# 568577        104236   36  LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIG...
# 568578        104236   37  TOILET ROOM DOORS SELF CLOSING: DRESSING ROOMS...
# 568579        104236   38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 568580        104236   39            LINEN: CLEAN AND SOILED PROPERLY STORED
# 568581        104236   41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
#
#                                                   comment
# 0       NO DISH WASHING FACILITIES ON SITE, (NO THREE ...
# 1        NO EXPOSED HAND SINK FOR REAR SERVICE AREA, I...
# 2       NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME ...
# 3       MUST PROVIDE OVERHEAD PROTECTION FOR COFFEE/TE...
# 4       FLOORS AT COFFEE/TEA STATIONS MUST BE MADE SMO...
# ...                                                   ...
# 568577  All rooms in which food or drink is prepared, ...
# 568578  None of the operations connected with food est...
# 568579  The flow of air discharged from kitchen fans s...
# 568580  Soiled and clean linens, coats, and aprons sha...
# 568581  All parts of the food establishment and all pa...
#
# [568582 rows x 4 columns]

# %%
violation_df[['Inspection ID', 'code']].duplicated().sum()
# Out:
# 7599

# %%
violations = violation_df[['code', 'description']].drop_duplicates().reset_index(drop=True)
violations
# Out:
#    code                                        description
# 0     8  SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  ...
# 1    11  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIG...
# 2    18  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS...
# 3    35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4    34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 5    31  CLEAN MULTI-USE UTENSILS AND SINGLE SERVICE AR...
# 6    38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 7    41  PREMISES MAINTAINED FREE OF LITTER, UNNECESSAR...
# 8     2          FACILITIES TO MAINTAIN PROPER TEMPERATURE
# 9    21  * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIA...
# 10   22  DISH MACHINES: PROVIDED WITH ACCURATE THERMOME...
# 11   30  FOOD IN ORIGINAL CONTAINER, PROPERLY LABELED: ...
# 12   32  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 13   33  FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS C...
# 14   37  TOILET ROOM DOORS SELF CLOSING: DRESSING ROOMS...
# 15    3  POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE R...
# 16   29     PREVIOUS MINOR VIOLATION(S) CORRECTED 7-42-090
# 17   12  HAND WASHING FACILITIES: WITH SOAP AND SANITAR...
# 18   19  OUTSIDE GARBAGE WASTE GREASE AND STORAGE AREA;...
# 19   43  FOOD (ICE) DISPENSING UTENSILS, WASH CLOTHS PR...
# 20   45                      FOOD HANDLER REQUIREMENTS MET
# 21   40  REFRIGERATION AND METAL STEM THERMOMETERS PROV...
# 22   13  NO EVIDENCE OF RODENT OR INSECT INFESTATION, N...
# 23    6  HANDS WASHED AND CLEANED, GOOD HYGIENIC PRACTI...
# 24   16  FOOD PROTECTED DURING STORAGE, PREPARATION, DI...
# 25   36  LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIG...
# 26   14     PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42-090
# 27   24  DISH WASHING FACILITIES: PROPERLY DESIGNED, CO...
# 28   28  * INSPECTION REPORT SUMMARY DISPLAYED AND VISI...
# 29    9  WATER SOURCE: SAFE, HOT & COLD UNDER CITY PRES...
# 30    1  SOURCE SOUND CONDITION, NO SPOILAGE, FOODS PRO...
# 31   42  APPROPRIATE METHOD OF HANDLING OF FOOD (ICE) H...
# 32   44    ONLY AUTHORIZED PERSONNEL IN THE FOOD-PREP AREA
# 33   10  SEWAGE AND WASTE WATER DISPOSAL, NO BACK SIPHO...
# 34   17         POTENTIALLY HAZARDOUS FOOD PROPERLY THAWED
# 35   70                             NO SMOKING REGULATIONS
# 36   27  TOILET ROOMS ENCLOSED CLEAN, PROVIDED WITH HAN...
# 37   39            LINEN: CLEAN AND SOILED PROPERLY STORED
# 38   25      TOXIC ITEMS PROPERLY STORED, LABELED AND USED
# 39   20  INSIDE CONTAINERS OR RECEPTACLES: ADEQUATE NUM...
# 40    4  SOURCE OF CROSS CONTAMINATION CONTROLLED I.E. ...
# 41   26  ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, PROPE...
# 42   15  UNWRAPPED AND POTENTIALLY HAZARDOUS FOOD NOT R...
# 43    7  WASH AND RINSE WATER: CLEAN AND PROPER TEMPERA...
# 44    5  PERSONNEL WITH INFECTIONS RESTRICTED: NO OPEN ...
# 45   23       DISHES AND UTENSILS FLUSHED, SCRAPED, SOAKED

# %%
inspection_violation = violation_df[['Inspection ID', 'code', 'comment']]
inspection_violation
# Out:
#        Inspection ID code                                            comment
# 0            2079125    8  NO DISH WASHING FACILITIES ON SITE, (NO THREE ...
# 1            2079125   11   NO EXPOSED HAND SINK FOR REAR SERVICE AREA, I...
# 2            2079125   18  NO LICENSE PEST CONTROL LOG BOOK AT THIS TIME ...
# 3            2079123   35  MUST PROVIDE OVERHEAD PROTECTION FOR COFFEE/TE...
# 4            2079123   34  FLOORS AT COFFEE/TEA STATIONS MUST BE MADE SMO...
# ...              ...  ...                                                ...
# 568577        104236   36  All rooms in which food or drink is prepared, ...
# 568578        104236   37  None of the operations connected with food est...
# 568579        104236   38  The flow of air discharged from kitchen fans s...
# 568580        104236   39  Soiled and clean linens, coats, and aprons sha...
# 568581        104236   41  All parts of the food establishment and all pa...
#
# [568582 rows x 3 columns]

# %% [markdown]
# Note that a certain inspection id/violation code combination can have multiple comments. For example:

# %%
inspection_violation.groupby(by=['Inspection ID', 'code']).size().rename('count').reset_index()\
    .sort_values(by='count', ascending=False).reset_index(drop=True)
# Out:
#        Inspection ID code  count
# 0            1764036   34      9
# 1            1975476   34      8
# 2            1547061   35      7
# 3            1501481   32      7
# 4            1234494   32      6
# ...              ...  ...    ...
# 560978       1459941   28      1
# 560979       1459941   21      1
# 560980       1459940   41      1
# 560981       1459940   35      1
# 560982         98544   35      1
#
# [560983 rows x 3 columns]

# %%
inspection_violation[(inspection_violation['Inspection ID']== '1764036') & (inspection_violation['code'] == '34')]
# Out:
#       Inspection ID code                                            comment
# 99332       1764036   34  REGROUT THE FLOOR IN FOOD PREP AREA ALL THE WA...
# 99333       1764036   34  DETAIL CLEAN FLOOR INSIDE WALK-IN COOLER AT BO...
# 99334       1764036   34  OBSERVED STANDING WATER ON FLOOR  ALONG FRONT ...
# 99336       1764036   34  FLOOR ALONG WALLBASE AND IN THE CORNERS IN NEE...
# 99337       1764036   34  MUST CLEAN FLOOR ALONG WALLS AND IN THE CORNER...
# 99338       1764036   34  MUST CLEAN FLOOR ALONG WALLS AND CORNERS AT BO...
# 99341       1764036   34  OBSERVED FRONT LINE WATER STANDING ON FLOOR AL...
# 99342       1764036   34  MUST CLEAN FLOOR ALONG THE WALLS AND IN THE CO...
# 99343       1764036   34  MUST CLEAN FLOOR ALONG THE WALLS AND IN CORNER...

# %% [markdown]
# ### Inspection_Risk

# %%
risk_df = input_data[~pd.isnull(input_data['Risk'])][['Inspection ID', 'Risk']].reset_index(drop=True)
risk_df
# Out:
#        Inspection ID             Risk
# 0            2079132    Risk 1 (High)
# 1            2079129  Risk 2 (Medium)
# 2            2079125     Risk 3 (Low)
# 3            2079123    Risk 1 (High)
# 4            2079105    Risk 1 (High)
# ...              ...              ...
# 153739         67732    Risk 1 (High)
# 153740         67757  Risk 2 (Medium)
# 153741         52234    Risk 1 (High)
# 153742         70269    Risk 1 (High)
# 153743        104236    Risk 1 (High)
#
# [153744 rows x 2 columns]

# %%
risk_df['Risk'].value_counts()
# Out:
# Risk 1 (High)      107351
# Risk 2 (Medium)     31845
# Risk 3 (Low)        14529
# All                    19
# Name: Risk, dtype: int64

# %%
list(re.compile(r'Risk (\d+) \((\w+)\)').match('Risk 2 (Medium)').groups())
# Out:
# ['2', 'Medium']

# %%
def extract_risk(s):
    matched = re.compile(r'\w+ (?P<code>\d+) \((?P<level>\w+)\)').match(s)
    if matched:
        return matched.group('code'), matched.group('level')
    else:
        return '', ''
    
print(extract_risk('Risk 2 (Medium)') ) 
print(extract_risk('Risk2(Medium)') )
# Out:
# ('2', 'Medium')
# ('', '')

# %%
risk_df['code'], risk_df['level'] = zip(*risk_df['Risk'].apply(extract_risk))

# %%
risk_df
# Out:
#        Inspection ID             Risk code   level
# 0            2079132    Risk 1 (High)    1    High
# 1            2079129  Risk 2 (Medium)    2  Medium
# 2            2079125     Risk 3 (Low)    3     Low
# 3            2079123    Risk 1 (High)    1    High
# 4            2079105    Risk 1 (High)    1    High
# ...              ...              ...  ...     ...
# 153739         67732    Risk 1 (High)    1    High
# 153740         67757  Risk 2 (Medium)    2  Medium
# 153741         52234    Risk 1 (High)    1    High
# 153742         70269    Risk 1 (High)    1    High
# 153743        104236    Risk 1 (High)    1    High
#
# [153744 rows x 4 columns]

# %%
risk_df[risk_df['code']=='']
# Out:
#        Inspection ID Risk code level
# 161          2078759  All
# 201          2078685  All
# 300          2078476  All
# 391          2078260  All
# 3139         2059435  All
# 4210         2050229  All
# 4672         2049776  All
# 6243         2010064  All
# 58570        1501748  All
# 67584        1474120  All
# 75258        1383423  All
# 77505        1320006  All
# 88601        1286310  All
# 94648        1084429  All
# 94673        1322184  All
# 98442        1319296  All
# 110686       1214783  All
# 116029        660163  All
# 117134        664312  All

# %% [markdown]
# ### Inspection_Facility
